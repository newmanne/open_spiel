# %%
import re
from open_spiel.python.algorithms import cfr, outcome_sampling_mccfr, expected_game_score, exploitability, get_all_states_with_policy
import pyspiel
from open_spiel.python.algorithms.cfr import CFRSolver
import pandas as pd
import pickle
import cProfile, pstats

# %%
# GAME_PATH = '/apps/open_spiel/sats/python/odd_licenses.json'
# GAME_PATH = 'very_small_sats_complete_symmetric.json'
GAME_NAME = 'may3'
GAME_PATH = f'/apps/open_spiel/sats/python/{GAME_NAME}.json'
# GAME_PATH = '/apps/open_spiel/sats/python/mixed.json'

# %%
PYSATS = '/apps/sats/python'
# !python {PYSATS}/pysats.py --config_file {PYSATS}/{GAME_NAME}.yml --seed 777 --output_file {PYSATS}/{GAME_NAME}.json
# GAME_NAME = f'{PYSATS}/{GAME_NAME}'
# !mv {GAME_PATH} /apps/open_spiel/configs/{GAME_NAME}.json
# Out:
# {'licenses': [6], 'activity': [1], 'opening_price': [9], 'information_policy': 'show_demand', 'undersell_rule': 'undersell', 'increment': 1, 'fold_randomness': True, 'max_rounds': 5, 'license_names': ['British Columbia'], 'players': [{'type': [{'value': [0, 0, 60, 100, 120, 120, 120], 'value_format': 'full', 'budget': 120, 'prob': 1.0, 'name': 'normal', 'drop_out_heuristic': True}]}, {'type': [{'value': [0, 0, 100, 200, 250, 250, 250], 'value_format': 'full', 'budget': 250, 'prob': 1.0, 'name': 'normal', 'drop_out_heuristic': True}]}]}

# %%
seeds = range(1234, 1234 + n_seeds)
list(seeds)
# Out:
# [1234, 1235, 1236]

# %%
solver = 'mccfr'
n_seeds = 3
seeds = range(1234, 1234 + n_seeds)
# solver = 'cfrplus'
# solver = 'cfr'
for seed in seeds:
    command = f'/apps/cluster_open_spiel/open_spiel/python/examples/ubc_mccfr_cpp_example.py --filename {GAME_NAME}.json --iterations 1000 --output results/{GAME_NAME}_{seed} --game python_clock_auction --python true --solver {solver}  --seed {seed}'
    print(command)
    # !python {command}
# Out:
# /apps/cluster_open_spiel/open_spiel/python/examples/ubc_mccfr_cpp_example.py --filename may3.json --iterations 1000 --output results/may3_0 --game python_clock_auction --python true --solver mccfr  --seed 0
# I0503 22:40:26.017676 140380243996800 clock_auction_parser.py:14] Reading from env variable CLOCK_AUCTION_CONFIG_DIR. If it is not set, there will be trouble.
# I0503 22:40:26.017814 140380243996800 clock_auction_parser.py:18] CLOCK_AUCTION_CONFIG_DIR=/apps/open_spiel/configs
# I0503 22:40:26.017864 140380243996800 clock_auction_parser.py:21] Parsing configuration from /apps/open_spiel/configs/may3.json
# I0503 22:40:26.018085 140380243996800 clock_auction_parser.py:100] Done config parsing
# I0503 22:40:26.018162 140380243996800 clock_auction.py:133] Folding randomnesss...
# I0503 22:40:26.018344 140380243996800 ubc_mccfr_cpp_example.py:168] Using python implementations
# I0503 22:40:26.018460 140380243996800 ubc_mccfr_cpp_example.py:179] Using MCCFR solver
# I0503 22:40:26.018524 140380243996800 ubc_mccfr_cpp_example.py:184] Using external sampling
# I0503 22:40:26.018702 140380243996800 ubc_mccfr_cpp_example.py:224] Starting iteration 0
# I0503 22:40:29.687618 140380243996800 ubc_mccfr_cpp_example.py:256] Iteration 0
# I0503 22:40:29.687820 140380243996800 ubc_mccfr_cpp_example.py:260] walltime=0.135186
# I0503 22:40:29.690127 140380243996800 ubc_mccfr_cpp_example.py:227] Done iteration 1. Took 3.67 seconds
# I0503 22:40:29.705740 140380243996800 ubc_mccfr_cpp_example.py:227] Done iteration 2. Took 3.69 seconds
# I0503 22:40:29.723223 140380243996800 ubc_mccfr_cpp_example.py:227] Done iteration 3. Took 3.71 seconds
# I0503 22:40:31.133100 140380243996800 ubc_mccfr_cpp_example.py:224] Starting iteration 100
# I0503 22:40:32.210089 140380243996800 ubc_mccfr_cpp_example.py:256] Iteration 100
# I0503 22:40:32.210286 140380243996800 ubc_mccfr_cpp_example.py:260] walltime=5.133432
# I0503 22:40:33.877304 140380243996800 ubc_mccfr_cpp_example.py:224] Starting iteration 200
# I0503 22:40:34.948436 140380243996800 ubc_mccfr_cpp_example.py:256] Iteration 200
# I0503 22:40:34.948639 140380243996800 ubc_mccfr_cpp_example.py:260] walltime=7.878350
# I0503 22:40:36.628956 140380243996800 ubc_mccfr_cpp_example.py:224] Starting iteration 300
# I0503 22:40:37.696834 140380243996800 ubc_mccfr_cpp_example.py:256] Iteration 300
# I0503 22:40:37.697033 140380243996800 ubc_mccfr_cpp_example.py:260] walltime=10.626996
# I0503 22:40:39.393505 140380243996800 ubc_mccfr_cpp_example.py:224] Starting iteration 400
# I0503 22:40:40.465451 140380243996800 ubc_mccfr_cpp_example.py:256] Iteration 400
# I0503 22:40:40.465659 140380243996800 ubc_mccfr_cpp_example.py:260] walltime=13.392204
# I0503 22:40:42.149790 140380243996800 ubc_mccfr_cpp_example.py:224] Starting iteration 500
# I0503 22:40:43.218717 140380243996800 ubc_mccfr_cpp_example.py:256] Iteration 500
# I0503 22:40:43.218920 140380243996800 ubc_mccfr_cpp_example.py:260] walltime=16.147252
# I0503 22:40:44.918046 140380243996800 ubc_mccfr_cpp_example.py:224] Starting iteration 600
# I0503 22:40:45.988782 140380243996800 ubc_mccfr_cpp_example.py:256] Iteration 600
# I0503 22:40:45.988996 140380243996800 ubc_mccfr_cpp_example.py:260] walltime=18.916692
# I0503 22:40:47.695767 140380243996800 ubc_mccfr_cpp_example.py:224] Starting iteration 700
# I0503 22:40:48.765833 140380243996800 ubc_mccfr_cpp_example.py:256] Iteration 700
# I0503 22:40:48.766029 140380243996800 ubc_mccfr_cpp_example.py:260] walltime=21.695605
# I0503 22:40:50.502824 140380243996800 ubc_mccfr_cpp_example.py:224] Starting iteration 800
# I0503 22:40:51.580009 140380243996800 ubc_mccfr_cpp_example.py:256] Iteration 800
# I0503 22:40:51.580210 140380243996800 ubc_mccfr_cpp_example.py:260] walltime
140353440542848 ubc_mccfr_cpp_example.py:224] Starting iteration 100
# I0503 22:43:51.934702 140353440542848 ubc_mccfr_cpp_example.py:256] Iteration 100
# I0503 22:43:51.934911 140353440542848 ubc_mccfr_cpp_example.py:260] walltime=4.956741
# I0503 22:43:53.115019 140353440542848 ubc_mccfr_cpp_example.py:224] Starting iteration 200
# I0503 22:43:54.180129 140353440542848 ubc_mccfr_cpp_example.py:256] Iteration 200
# I0503 22:43:54.180361 140353440542848 ubc_mccfr_cpp_example.py:260] walltime=7.201060
# I0503 22:43:55.371164 140353440542848 ubc_mccfr_cpp_example.py:224] Starting iteration 300
# I0503 22:43:56.433162 140353440542848 ubc_mccfr_cpp_example.py:256] Iteration 300
# I0503 22:43:56.433379 140353440542848 ubc_mccfr_cpp_example.py:260] walltime=9.455875
# I0503 22:43:57.631500 140353440542848 ubc_mccfr_cpp_example.py:224] Starting iteration 400
# I0503 22:43:58.695446 140353440542848 ubc_mccfr_cpp_example.py:256] Iteration 400
# I0503 22:43:58.695662 140353440542848 ubc_mccfr_cpp_example.py:260] walltime=11.716462
# I0503 22:43:59.897798 140353440542848 ubc_mccfr_cpp_example.py:224] Starting iteration 500
# I0503 22:44:00.962599 140353440542848 ubc_mccfr_cpp_example.py:256] Iteration 500
# I0503 22:44:00.962810 140353440542848 ubc_mccfr_cpp_example.py:260] walltime=13.983423
# I0503 22:44:02.173956 140353440542848 ubc_mccfr_cpp_example.py:224] Starting iteration 600
# I0503 22:44:03.245290 140353440542848 ubc_mccfr_cpp_example.py:256] Iteration 600
# I0503 22:44:03.245497 140353440542848 ubc_mccfr_cpp_example.py:260] walltime=16.258787
# I0503 22:44:04.476150 140353440542848 ubc_mccfr_cpp_example.py:224] Starting iteration 700
# I0503 22:44:05.540655 140353440542848 ubc_mccfr_cpp_example.py:256] Iteration 700
# I0503 22:44:05.540865 140353440542848 ubc_mccfr_cpp_example.py:260] walltime=18.562394
# I0503 22:44:06.795110 140353440542848 ubc_mccfr_cpp_example.py:224] Starting iteration 800
# I0503 22:44:07.865492 140353440542848 ubc_mccfr_cpp_example.py:256] Iteration 800
# I0503 22:44:07.865712 140353440542848 ubc_mccfr_cpp_example.py:260] walltime=20.881219
# I0503 22:44:09.124912 140353440542848 ubc_mccfr_cpp_example.py:224] Starting iteration 900
# I0503 22:44:10.195752 140353440542848 ubc_mccfr_cpp_example.py:256] Iteration 900
# I0503 22:44:10.195962 140353440542848 ubc_mccfr_cpp_example.py:260] walltime=23.211098
# I0503 22:44:12.528564 140353440542848 ubc_mccfr_cpp_example.py:256] Iteration 999
# I0503 22:44:12.528785 140353440542848 ubc_mccfr_cpp_example.py:260] walltime=25.538784
# I0503 22:44:12.530380 140353440542848 ubc_mccfr_cpp_example.py:135] Persisting the model...
# Max Depth: 10
# I0503 22:44:13.500130 140353440542848 ubc_mccfr_cpp_example.py:328] Saving strategy to results/may3_6/strategy.csv
# /apps/cluster_open_spiel/open_spiel/python/examples/ubc_mccfr_cpp_example.py --filename may3.json --iterations 1000 --output results/may3_7 --game python_clock_auction --python true --solver mccfr  --seed 7
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# File ~/.pyenv/versions/3.8.2/envs/venv/lib/python3.8/site-packages/IPython/utils/_process_posix.py:153, in ProcessHandler.system(self, cmd)
#     150 while True:
#     151     # res is the index of the pattern that caused the match, so we
#     152     # know whether we've finished (if we matched EOF) or not
# --> 153     res_idx = child.expect_list(patterns, self.read_timeout)
#     154     print(child.before[out_size:].decode(enc, 'replace'), end='')
#
# File ~/.pyenv/versions/3.8.2/envs/venv/lib/python3.8/site-packages/pexpect/spawnbase.py:372, in SpawnBase.expect_list(self, pattern_list, timeout, searchwindowsize, async_, **kw)
#     371 else:
# --> 372     return exp.expect_loop(timeout)
#
# File ~/.pyenv/versions/3.8.2/envs/venv/lib/python3.8/site-packages/pexpect/expect.py:169, in Expecter.expect_loop(self, timeout)
#     168 # Still have time left, so read more data
# --> 169 incoming = spawn.read_nonblocking(spawn.maxread, timeout)
#     170 if self.spawn.delayafterread is not None:
#
# File ~/.pyenv/versions/3.8.2/envs/venv/lib/python3.8/site-packages/pexpect/pty_spawn.py:500, in spawn.read_nonblocking(self, size, timeout)
#     497 # Because of the select(0) check above, we know that no data
#     498 # is available right now. But if a non-zero timeout is given
#     499 # (possibly timeout=None), we call select() with a timeout.
# --> 500 if (timeout != 0) and select(timeout):
#     501     return super(spawn, self).read_nonblocking(size)
#
# File ~/.pyenv/versions/3.8.2/envs/venv/lib/python3.8/site-packages/pexpect/pty_spawn.py:450, in spawn.read_nonblocking.<locals>.select(timeout)
#     449 def select(timeout):
# --> 450     return select_ignore_interrupts([self.child_fd], [], [], timeout)[0]
#
# File ~/.pyenv/versions/3.8.2/envs/venv/lib/python3.8/site-packages/pexpect/utils.py:143, in select_ignore_interrupts(iwtd, owtd, ewtd, timeout)
#     142 try:
# --> 143     return select.select(iwtd, owtd, ewtd, timeout)
#     144 except InterruptedError:
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [8], in <module>
#       7 command = f'/apps/cluster_open_spiel/open_spiel/python/examples/ubc_mccfr_cpp_example.py --filename {GAME_NAME}.json --iterations 1000 --output results/{GAME_NAME}_{seed} --game python_clock_auction --python true --solver {solver}  --seed {seed}'
#       8 print(command)
# ----> 9 get_ipython().system('python {command}')
#
# File ~/.pyenv/versions/3.8.2/envs/venv/lib/python3.8/site-packages/ipykernel/zmqshell.py:636, in ZMQInteractiveShell.system_piped(self, cmd)
#     634         self.user_ns['_exit_code'] = system(cmd)
#     635 else:
# --> 636     self.user_ns['_exit_code'] = system(self.var_expand(cmd, depth=1))
#
# File ~/.pyenv/versions/3.8.2/envs/venv/lib/python3.8/site-packages/IPython/utils/_process_posix.py:164, in ProcessHandler.system(self, cmd)
#     159         out_size = len(child.before)
#     160 except KeyboardInterrupt:
#     161     # We need to send ^C to the process.  The ascii code for '^C' is 3
#     162     # (the character is known as ETX for 'End of Text', see
#     163     # curses.ascii.ETX).
# --> 164     child.sendline(chr(3))
#     165     # Read and print any more output the program might produce on its
#     166     # way out.
#     167     try:
#
# File ~/.pyenv/versions/3.8.2/envs/venv/lib/python3.8/site-packages/pexpect/pty_spawn.py:578, in spawn.sendline(self, s)
#     572 '''Wraps send(), sending string ``s`` to child process, with
#     573 ``os.linesep`` automatically appended. Returns number of bytes
#     574 written.  Only a limited number of bytes may be sent for each
#     575 line in the default terminal mode, see docstring of :meth:`send`.
#     576 '''
#     577 s = self._coerce_send_string(s)
# --> 578 return self.send(s + self.linesep)
#
# File ~/.pyenv/versions/3.8.2/envs/venv/lib/python3.8/site-packages/pexpect/pty_spawn.py:563, in spawn.send(self, s)
#     528 '''Sends string ``s`` to the child process, returning the number of
#     529 bytes written. If a logfile is specified, a copy is written to that
#     530 log.
#    (...)
#     559     >>> bash.sendline('x' * 5000)
#     560 '''
#     562 if self.delaybeforesend is not None:
# --> 563     time.sleep(self.delaybeforesend)
#     565 s = self._coerce_send_string(s)
#     566 self._log(s, 'send')
#
# KeyboardInterrupt:

# %%
# def prof():
#     game = pyspiel.load_game("python_clock_auction", dict(filename='april6_t1.json'))
#     num_iterations = 500
#     cfr_solver = CFRSolver(game)
#     for i in range(num_iterations):
#         cfr_solver.evaluate_and_update_policy()


# profiler = cProfile.Profile()
# profiler.enable()
# prof()
# profiler.disable()

# %%
stats = pstats.Stats(profiler).sort_stats('cumtime')
stats.print_stats()

# %%
game = pyspiel.load_game("python_clock_auction", dict(filename='april6_t1.json'))


def state_to_final_python(game, s):
    '''Convert a state into unique final outcomes (but not caring about bidding being different in the middle). i.e., the allocation and the types and the price are all the same'''
    info_state_string = f'Price: {s.posted_prices[-1]}\n'
    info_state_string += f'Final bids: {s.get_allocation()}\n'
    info_state_string += f'Round: {s.round}\n'
    return info_state_string


all_states = get_all_states_with_policy.get_all_info_states_with_policy(
    game,
    depth_limit=-1,
    include_terminals=True,
    policy=None,
    to_string=lambda s: state_to_final_python(game, s)
)

# %%
game = pyspiel.load_game("python_clock_auction", dict(filename='april6_t1.json'))
solver = pickle.load(open('april6_t1/cfr_9.pkl', 'rb'))
policy = solver.average_policy()

all_states = get_all_states_with_policy.get_all_info_states_with_policy(
    game,
    depth_limit=-1,
    include_terminals=True,
    policy=policy,
    to_string=lambda s: state_to_final_python(game, s)
)

# %%
game.new_initial_state().get_game()

# %%
import pprofile
profiler = pprofile.Profile()
with profiler:
    prof()
profiler.dump_stats('output_april17.prof')

# %%
game = pyspiel.load_game("python_clock_auction", dict(filename='april6_t1.json'))

# %%
game.make_py_observer().string_from.cache_info()
