# %%
import os
os.environ["DJANGO_ALLOW_ASYNC_UNSAFE"] = "true"

# %%
import sys
sys.path
# Out:
# ['/apps/open_spiel/open_spiel/python/examples/notebooks',
#  '/apps/open_spiel',
#  '/apps/open_spiel/build/python',
#  '/apps/open_spiel/web/auctions',
#  '/home/ubuntu/.pyenv/versions/3.8.2/lib/python38.zip',
#  '/home/ubuntu/.pyenv/versions/3.8.2/lib/python3.8',
#  '/home/ubuntu/.pyenv/versions/3.8.2/lib/python3.8/lib-dynload',
#  '',
#  '/home/ubuntu/.pyenv/versions/venv/lib/python3.8/site-packages']

# %%
# !python /apps/open_spiel/web/auctions/manage.py flush --no-input

# %%
# overrides = '--num_training_episodes 5_000_000 --eval_every 500_000 --iterate_br true --br_overrides "--num_training_episodes 2_000_000"'

# %%
# !python /apps/open_spiel/web/auctions/manage.py nfsp --filename small_game_2.json --network_config_file feb2/mlp --experiment_name test --job_name test_run --dispatch_br true --num_training_episodes 5000 --eval_every 500 --eval_zero false --iterate_br true --br_overrides "--num_training_episodes 5_000" --br_portfolio_path feb2
# Out:
# [2022-02-22 08:03:27,153] {ubc_utils.py:100} INFO - Setting numpy and torch seed to 1234
# [2022-02-22 08:03:27,154] {ubc_utils.py:361} INFO - Reading config from /apps/open_spiel/notebooks/configs/feb2/mlp.yml
# ...

# %%
# !python /apps/open_spiel/web/auctions/manage.py bestrespond --experiment_name test --run_name mlp --t 4500 --num_training_episodes 1000  --br_name hello --br_player 1 --config feb2/mlp

# %%
BestResponse.objects.all()
# Out:
# ---------------------------------------------------------------------------
# UndefinedTable                            Traceback (most recent call last)
# File ~/.pyenv/versions/venv/lib/python3.8/site-packages/django/db/backends/utils.py:85, in CursorWrapper._execute(self, sql, params, *ignored_wrapper_args)
#      84 else:
# ---> 85     return self.cursor.execute(sql, params)
#
# UndefinedTable: relation "auctions_bestresponse" does not exist
# LINE 1: ...ponse"."config", "auctions_bestresponse"."t" FROM "auctions_...
#                                                              ^
#
#
# The above exception was the direct cause of the following exception:
#
# ProgrammingError                          Traceback (most recent call last)
# File ~/.pyenv/versions/venv/lib/python3.8/site-packages/IPython/core/formatters.py:707, in PlainTextFormatter.__call__(self, obj)
#     700 stream = StringIO()
#     701 printer = pretty.RepresentationPrinter(stream, self.verbose,
# ...
