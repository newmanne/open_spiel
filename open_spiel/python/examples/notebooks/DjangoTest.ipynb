# %%
import os
os.environ["DJANGO_ALLOW_ASYNC_UNSAFE"] = "true"

# %%
# !python /apps/open_spiel/web/auctions/manage.py flush --no-input

# %%
overrides = '--num_training_episodes 5_000_000 --eval_every 500_000 --iterate_br true --br_overrides "--num_training_episodes 2_000_000"'

# %%
# !python /apps/open_spiel/web/auctions/manage.py nfsp --filename small_game_2.json --network_config_file feb2/mlp --experiment_name test --job_name test_run --dispatch_br true --num_training_episodes 5000 --eval_every 500 --eval_zero false --iterate_br true --br_overrides "--num_training_episodes 5_000" --br_portfolio_path feb2
# Out:
# [2022-02-19 19:45:45,092] {ubc_utils.py:100} INFO - Setting numpy and torch seed to 1234
# [2022-02-19 19:45:45,093] {ubc_utils.py:361} INFO - Reading config from /apps/open_spiel/notebooks/configs/feb2/mlp.yml
# [2022-02-19 19:45:45,095] {nfsp.py:75} INFO - Network params: {'add_explore_transitions': False, 'anticipatory_param': 0.1, 'batch_size': 1024, 'epsilon_end': 0.05, 'epsilon_start': 0.9, 'learn_every': 16, 'loss_str': 'mse', 'min_buffer_size_to_learn': 1000, 'optimizer_str': 'sgd', 'replay_buffer_capacity': 50000, 'reservoir_buffer_capacity': 2000000, 'rl_learning_rate': 1e-06, 'rl_model': 'mlp', 'rl_model_args': {'hidden_sizes': [128, 128]}, 'sl_learning_rate': 0.0001, 'sl_model': 'mlp', 'sl_model_args': {'hidden_sizes': [128, 128]}, 'update_target_network_every': 1000, 'filename': 'small_game_2.json', 'network_config_file': 'feb2/mlp', 'job_name': 'test_run', 'eval_every': 500, 'eval_zero': 0, 'dispatch_br': 1, 'br_portfolio_path': 'feb2', 'br_overrides': '--num_training_episodes 5_000', 'num_training_episodes': 5000, 'iterate_br': 1, 'experiment_name': 'test'}
# Reading from env variable CLOCK_AUCTION_CONFIG_DIR. If it is not set, there will be trouble.
# CLOCK_AUCTION_CONFIG_DIR=/apps/open_spiel/configs
# Parsing configuration from /apps/open_spiel/configs/small_game_2.json
# Done config parsing
# Reading from env variable CLOCK_AUCTION_CONFIG_DIR. If it is not set, there will be trouble.
# CLOCK_AUCTION_CONFIG_DIR=/apps/open_spiel/configs
# Parsing configuration from /apps/open_spiel/configs/small_game_2.json
# Done config parsing
# [2022-02-19 19:45:45,118] {rl_environment.py:195} INFO - Using game instance: turn_based_simultaneous_game
# [2022-02-19 19:45:45,119] {ubc_nfsp_example.py:121} INFO - Game has a state size of 226, 4 distinct actions, and 2 players
# [2022-02-19 19:45:45,119] {ubc_nfsp_example.py:122} INFO - Game has 2 products
# [2022-02-19 19:45:45,716] {ubc_nfsp.py:92} INFO - Creating NFSP using device: cuda for player 0
# [2022-02-19 19:45:45,716] {ubc_dqn.py:247} INFO - Double DQN activated for player 0
# [2022-02-19 19:45:45,717] {ubc_dqn.py:281} INFO - Creating DQN using device: cuda for player 0
# [2022-02-19 19:45:49,841] {ubc_nfsp.py:92} INFO - Creating NFSP using device: cuda for player 1
# [2022-02-19 19:45:49,841] {ubc_dqn.py:247} INFO - Double DQN activated for player 1
# [2022-02-19 19:45:49,841] {ubc_dqn.py:281} INFO - Creating DQN using device: cuda for player 1
# [2022-02-19 19:45:49,850] {ubc_nfsp_example.py:287} INFO - Iterating best responses
# [2022-02-19 19:45:50,244] {ubc_nfsp_example.py:253} INFO - ----Episode 500 ---
# [2022-02-19 19:45:50,247] {ubc_nfsp_example.py:254} INFO - Episode length stats:
# count    500.000000
# mean       3.548000
# std        2.012908
# min        2.000000
# 25%        2.000000
# 50%        2.000000
# 75%        4.000000
# max       14.000000
# dtype: float64
# [2022-02-19 19:45:50,247] {ubc_nfsp_example.py:256} INFO - PLAYER 0
# [2022-02-19 19:45:50,248] {ubc_nfsp_example.py:259} INFO - {'Bid for 0,0 licenses @ $0 with activity 0': tensor(17.1991), 'Bid for 0,1 licenses @ $50 with activity 50': tensor(-1.6537), 'Bid for 1,0 licenses @ $75 with activity 75': tensor(-17.6690), 'Bid for 1,1 licenses @ $125 with activity 125': tensor(-4.0715)}
# [2022-02-19 19:45:50,250] {ubc_nfsp_example.py:260} INFO - Train time 0 seconds
# [2022-02-19 19:45:50,250] {ubc_nfsp_example.py:261} INFO - Total time 0.40 seconds
# [2022-02-19 19:45:50,250] {ubc_nfsp_example.py:262} INFO - Training the DQN for player 0 is a 0.00 fraction
# [2022-02-19 19:45:50,250] {ubc_nfsp_example.py:263} INFO - Loss (Supervised, RL): (None, tensor([0]))
# [2022-02-19 19:45:50,250] {ubc_nfsp_example.py:256} INFO - PLAYER 1
# [2022-02-19 19:45:50,251] {ubc_nfsp_example.py:259} INFO - {'Bid for 0,0 licenses @ $0 with activity 0': tensor(26.7420), 'Bid for 0,1 licenses @ $50 with activity 50': tensor(2.6898), 'Bid for 1,0 licenses @ $75 with activity 75': tensor(-23.4331), 'Bid for 1,1 licenses @ $125 with activity 125': tensor(12.0200)}
# [2022-02-19 19:45:50,252] {ubc_nfsp_example.py:260} INFO - Train time 0 seconds
# [2022-02-19 19:45:50,252] {ubc_nfsp_example.py:261} INFO - Total time 0.40 seconds
# [2022-02-19 19:45:50,253] {ubc_nfsp_example.py:262} INFO - Training the DQN for player 1 is a 0.00 fraction
# [2022-02-19 19:45:50,253] {ubc_nfsp_example.py:263} INFO - Loss (Supervised, RL): (None, tensor([0]))
# [2022-02-19 19:45:50,253] {ubc_nfsp_example.py:266} INFO - EVALUATION AT ITERATION 500
# [2022-02-19 19:45:50,253] {nfsp.py:23} INFO - Saving episode 500 to DB
# Submitted batch job 23217
# Dispatched experiment!
# Submitted batch job 23218
# Dispatched experiment!
# Submitted batch job 23219
# Dispatched experiment!
# Submitted batch job 23220
# Dispatched experiment!
# Submitted batch job 23221
# Dispatched experiment!
# Submitted batch job 23222
# Dispatched experiment!
# Submitted batch job 23223
# Dispatched experiment!
# [2022-02-19 19:45:51,135] {ubc_nfsp_example.py:253} INFO - ----Episode 1000 ---
# [2022-02-19 19:45:51,140] {ubc_nfsp_example.py:254} INFO - Episode length stats:
# count    1000.000000
# mean        3.518000
# std         1.932721
# min         2.000000
# 25%         2.000000
# 50%         4.000000
# 75%         4.000000
# max        14.000000
# dtype: float64
# [2022-02-19 19:45:51,140] {ubc_nfsp_example.py:256} INFO - PLAYER 0
# [2022-02-19 19:45:51,141] {ubc_nfsp_example.py:259} INFO - {'Bid for 0,0 licenses @ $0 with activity 0': tensor(17.1991), 'Bid for 0,1 licenses @ $50 with activity 50': tensor(-1.6537), 'Bid for 1,0 licenses @ $75 with activity 75': tensor(-17.6690), 'Bid for 1,1 licenses @ $125 with activity 125': tensor(-4.0715)}
# [2022-02-19 19:45:51,142] {ubc_nfsp_example.py:260} INFO - Train time 0 seconds
# [2022-02-19 19:45:51,142] {ubc_nfsp_example.py:261} INFO - Total time 1.29 seconds
# [2022-02-19 19:45:51,143] {ubc_nfsp_example.py:262} INFO - Training the DQN for player 0 is a 0.00 fraction
# [2022-02-19 19:45:51,143] {ubc_nfsp_example.py:263} INFO - Loss (Supervised, RL): (None, tensor([0]))
# [2022-02-19 19:45:51,143] {ubc_nfsp_example.py:256} INFO - PLAYER 1
# [2022-02-19 19:45:51,143] {ubc_nfsp_example.py:259} INFO - {'Bid for 0,0 licenses @ $0 with activity 0': tensor(26.7420), 'Bid for 0,1 licenses @ $50 with activity 50': tensor(2.6898), 'Bid for 1,0 licenses @ $75 with activity 75': tensor(-23.4331), 'Bid for 1,1 licenses @ $125 with activity 125': tensor(12.0200)}
# [2022-02-19 19:45:51,145] {ubc_nfsp_example.py:260} INFO - Train time 0 seconds
# [2022-02-19 19:45:51,145] {ubc_nfsp_example.py:261} INFO - Total time 1.29 seconds
# [2022-02-19 19:45:51,145] {ubc_nfsp_example.py:262} INFO - Training the DQN for player 1 is a 0.00 fraction
# [2022-02-19 19:45:51,145] {ubc_nfsp_example.py:263} INFO - Loss (Supervised, RL): (None, tensor([0]))
# [2022-02-19 19:45:51,145] {ubc_nfsp_example.py:266} INFO - EVALUATION AT ITERATION 1000
# [2022-02-19 19:45:51,145] {nfsp.py:23} INFO - Saving episode 1000 to DB
# Submitted batch job 23224
# Dispatched experiment!
# Submitted batch job 23225
# Dispatched experiment!
# Submitted batch job 23226
# Dispatched experiment!
# Submitted batch job 23227
# Dispatched experiment!
# Submitted batch job 23228
# Dispatched experiment!
# Submitted batch job 23229
# Dispatched experiment!
# Submitted batch job 23230
# Dispatched experiment!
# [2022-02-19 19:45:52,223] {ubc_nfsp_example.py:253} INFO - ----Episode 1500 ---
# [2022-02-19 19:45:52,227] {ubc_nfsp_example.py:254} INFO - Episode length stats:
# count    1500.000000
# mean        3.490667
# std         1.901313
# min         2.000000
# 25%         2.000000
# 50%         4.000000
# 75%         4.000000
# max        14.000000
# dtype: float64
# [2022-02-19 19:45:52,228] {ubc_nfsp_example.py:256} INFO - PLAYER 0
# [2022-02-19 19:45:52,228] {ubc_nfsp_example.py:259} INFO - {'Bid for 0,0 licenses @ $0 with activity 0': tensor(9.4958), 'Bid for 0,1 licenses @ $50 with activity 50': tensor(3.9020), 'Bid for 1,0 licenses @ $75 with activity 75': tensor(-7.2573), 'Bid for 1,1 licenses @ $125 with activity 125': tensor(4.1041)}
# [2022-02-19 19:45:52,230] {ubc_nfsp_example.py:260} INFO - Train time 0.08 seconds
# [2022-02-19 19:45:52,230] {ubc_nfsp_example.py:261} INFO - Total time 2.38 seconds
# [2022-02-19 19:45:52,230] {ubc_nfsp_example.py:262} INFO - Training the DQN for player 0 is a 0.03 fraction
# [2022-02-19 19:45:52,231] {ubc_nfsp_example.py:263} INFO - Loss (Supervised, RL): (None, tensor(433.2114))
# [2022-02-19 19:45:52,231] {ubc_nfsp_example.py:256} INFO - PLAYER 1
# [2022-02-19 19:45:52,231] {ubc_nfsp_example.py:259} INFO - {'Bid for 0,0 licenses @ $0 with activity 0': tensor(7.0009), 'Bid for 0,1 licenses @ $50 with activity 50': tensor(14.8750), 'Bid for 1,0 licenses @ $75 with activity 75': tensor(-3.0824), 'Bid for 1,1 licenses @ $125 with activity 125': tensor(24.8707)}
# [2022-02-19 19:45:52,233] {ubc_nfsp_example.py:260} INFO - Train time 0.08 seconds
# [2022-02-19 19:45:52,233] {ubc_nfsp_example.py:261} INFO - Total time 2.38 seconds
# [2022-02-19 19:45:52,233] {ubc_nfsp_example.py:262} INFO - Training the DQN for player 1 is a 0.03 fraction
# [2022-02-19 19:45:52,233] {ubc_nfsp_example.py:263} INFO - Loss (Supervised, RL): (None, tensor(491.8073))
# [2022-02-19 19:45:52,233] {ubc_nfsp_example.py:266} INFO - EVALUATION AT ITERATION 1500
# [2022-02-19 19:45:52,234] {nfsp.py:23} INFO - Saving episode 1500 to DB
# Submitted batch job 23231
# Dispatched experiment!
# Submitted batch job 23232
# Dispatched experiment!
# Submitted batch job 23233
# Dispatched experiment!
# Submitted batch job 23234
# Dispatched experiment!
# Submitted batch job 23235
# Dispatched experiment!
# Submitted batch job 23236
# Dispatched experiment!
# Submitted batch job 23237
# Dispatched experiment!
# [2022-02-19 19:45:53,457] {ubc_nfsp_example.py:253} INFO - ----Episode 2000 ---
# [2022-02-19 19:45:53,461] {ubc_nfsp_example.py:254} INFO - Episode length stats:
# count    2000.000000
# mean        3.609000
# std         1.979666
# min         2.000000
# 25%         2.000000
# 50%         4.000000
# 75%         4.000000
# max        14.000000
# dtype: float64
# [2022-02-19 19:45:53,462] {ubc_nfsp_example.py:256} INFO - PLAYER 0
# [2022-02-19 19:45:53,462] {ubc_nfsp_example.py:259} INFO - {'Bid for 0,0 licenses @ $0 with activity 0': tensor(4.2466), 'Bid for 0,1 licenses @ $50 with activity 50': tensor(6.6668), 'Bid for 1,0 licenses @ $75 with activity 75': tensor(2.1300), 'Bid for 1,1 licenses @ $125 with activity 125': tensor(11.4606)}
# [2022-02-19 19:45:53,464] {ubc_nfsp_example.py:260} INFO - Train time 0.20 seconds
# [2022-02-19 19:45:53,464] {ubc_nfsp_example.py:261} INFO - Total time 3.61 seconds
# [2022-02-19 19:45:53,464] {ubc_nfsp_example.py:262} INFO - Training the DQN for player 0 is a 0.06 fraction
# [2022-02-19 19:45:53,464] {ubc_nfsp_example.py:263} INFO - Loss (Supervised, RL): (None, tensor(249.7803))
# [2022-02-19 19:45:53,465] {ubc_nfsp_example.py:256} INFO - PLAYER 1
# [2022-02-19 19:45:53,465] {ubc_nfsp_example.py:259} INFO - {'Bid for 0,0 licenses @ $0 with activity 0': tensor(-2.7301), 'Bid for 0,1 licenses @ $50 with activity 50': tensor(23.2888), 'Bid for 1,0 licenses @ $75 with activity 75': tensor(-0.6695), 'Bid for 1,1 licenses @ $125 with activity 125': tensor(18.6743)}
# [2022-02-19 19:45:53,466] {ubc_nfsp_example.py:260} INFO - Train time 0.21 seconds
# [2022-02-19 19:45:53,467] {ubc_nfsp_example.py:261} INFO - Total time 3.62 seconds
# [2022-02-19 19:45:53,467] {ubc_nfsp_example.py:262} INFO - Training the DQN for player 1 is a 0.06 fraction
# [2022-02-19 19:45:53,467] {ubc_nfsp_example.py:263} INFO - Loss (Supervised, RL): (None, tensor(185.6038))
# [2022-02-19 19:45:53,467] {ubc_nfsp_example.py:266} INFO - EVALUATION AT ITERATION 2000
# [2022-02-19 19:45:53,467] {nfsp.py:23} INFO - Saving episode 2000 to DB
# Submitted batch job 23238
# Dispatched experiment!
# Submitted batch job 23239
# Dispatched experiment!
# Submitted batch job 23240
# Dispatched experiment!
# Submitted batch job 23241
# Dispatched experiment!
# Submitted batch job 23242
# Dispatched experiment!
# Submitted batch job 23243
# Dispatched experiment!
# Submitted batch job 23244
# Dispatched experiment!
# [2022-02-19 19:45:54,775] {ubc_nfsp_example.py:253} INFO - ----Episode 2500 ---
# [2022-02-19 19:45:54,779] {ubc_nfsp_example.py:254} INFO - Episode length stats:
# count    2500.000000
# mean        3.768000
# std         2.165745
# min         2.000000
# 25%         2.000000
# 50%         4.000000
# 75%         4.000000
# max        14.000000
# dtype: float64
# [2022-02-19 19:45:54,779] {ubc_nfsp_example.py:256} INFO - PLAYER 0
# [2022-02-19 19:45:54,780] {ubc_nfsp_example.py:259} INFO - {'Bid for 0,0 licenses @ $0 with activity 0': tensor(2.6455), 'Bid for 0,1 licenses @ $50 with activity 50': tensor(9.1140), 'Bid for 1,0 licenses @ $75 with activity 75': tensor(6.2717), 'Bid for 1,1 licenses @ $125 with activity 125': tensor(15.3707)}
# [2022-02-19 19:45:54,782] {ubc_nfsp_example.py:260} INFO - Train time 0.33 seconds
# [2022-02-19 19:45:54,782] {ubc_nfsp_example.py:261} INFO - Total time 4.93 seconds
# [2022-02-19 19:45:54,782] {ubc_nfsp_example.py:262} INFO - Training the DQN for player 0 is a 0.07 fraction
# [2022-02-19 19:45:54,782] {ubc_nfsp_example.py:263} INFO - Loss (Supervised, RL): (None, tensor(179.0165))
# [2022-02-19 19:45:54,783] {ubc_nfsp_example.py:256} INFO - PLAYER 1
# [2022-02-19 19:45:54,783] {ubc_nfsp_example.py:259} INFO - {'Bid for 0,0 licenses @ $0 with activity 0': tensor(-4.0121), 'Bid for 0,1 licenses @ $50 with activity 50': tensor(25.1909), 'Bid for 1,0 licenses @ $75 with activity 75': tensor(8.9230), 'Bid for 1,1 licenses @ $125 with activity 125': tensor(24.7509)}
# [2022-02-19 19:45:54,784] {ubc_nfsp_example.py:260} INFO - Train time 0.34 seconds
# [2022-02-19 19:45:54,785] {ubc_nfsp_example.py:261} INFO - Total time 4.93 seconds
# [2022-02-19 19:45:54,785] {ubc_nfsp_example.py:262} INFO - Training the DQN for player 1 is a 0.07 fraction
# [2022-02-19 19:45:54,785] {ubc_nfsp_example.py:263} INFO - Loss (Supervised, RL): (None, tensor(188.5843))
# [2022-02-19 19:45:54,785] {ubc_nfsp_example.py:266} INFO - EVALUATION AT ITERATION 2500
# [2022-02-19 19:45:54,785] {nfsp.py:23} INFO - Saving episode 2500 to DB
# Submitted batch job 23245
# Dispatched experiment!
# Submitted batch job 23246
# Dispatched experiment!
# Submitted batch job 23247
# Dispatched experiment!
# Submitted batch job 23248
# Dispatched experiment!
# Submitted batch job 23249
# Dispatched experiment!
# Submitted batch job 23250
# Dispatched experiment!
# Submitted batch job 23251
# Dispatched experiment!
# [2022-02-19 19:45:56,088] {ubc_nfsp_example.py:253} INFO - ----Episode 3000 ---
# [2022-02-19 19:45:56,092] {ubc_nfsp_example.py:254} INFO - Episode length stats:
# count    3000.000000
# mean        3.882000
# std         2.303587
# min         2.000000
# 25%         2.000000
# 50%         4.000000
# 75%         4.000000
# max        18.000000
# dtype: float64
# [2022-02-19 19:45:56,092] {ubc_nfsp_example.py:256} INFO - PLAYER 0
# [2022-02-19 19:45:56,093] {ubc_nfsp_example.py:259} INFO - {'Bid for 0,0 licenses @ $0 with activity 0': tensor(2.0554), 'Bid for 0,1 licenses @ $50 with activity 50': tensor(10.3934), 'Bid for 1,0 licenses @ $75 with activity 75': tensor(8.5474), 'Bid for 1,1 licenses @ $125 with activity 125': tensor(17.3152)}
# [2022-02-19 19:45:56,096] {ubc_nfsp_example.py:260} INFO - Train time 0.44 seconds
# [2022-02-19 19:45:56,096] {ubc_nfsp_example.py:261} INFO - Total time 6.25 seconds
# [2022-02-19 19:45:56,096] {ubc_nfsp_example.py:262} INFO - Training the DQN for player 0 is a 0.07 fraction
# [2022-02-19 19:45:56,097] {ubc_nfsp_example.py:263} INFO - Loss (Supervised, RL): (None, tensor(220.6474))
# [2022-02-19 19:45:56,097] {ubc_nfsp_example.py:256} INFO - PLAYER 1
# [2022-02-19 19:45:56,097] {ubc_nfsp_example.py:259} INFO - {'Bid for 0,0 licenses @ $0 with activity 0': tensor(-3.9538), 'Bid for 0,1 licenses @ $50 with activity 50': tensor(25.7203), 'Bid for 1,0 licenses @ $75 with activity 75': tensor(12.0518), 'Bid for 1,1 licenses @ $125 with activity 125': tensor(27.1989)}
# [2022-02-19 19:45:56,099] {ubc_nfsp_example.py:260} INFO - Train time 0.46 seconds
# [2022-02-19 19:45:56,099] {ubc_nfsp_example.py:261} INFO - Total time 6.25 seconds
# [2022-02-19 19:45:56,099] {ubc_nfsp_example.py:262} INFO - Training the DQN for player 1 is a 0.07 fraction
# [2022-02-19 19:45:56,099] {ubc_nfsp_example.py:263} INFO - Loss (Supervised, RL): (None, tensor(136.8307))
# [2022-02-19 19:45:56,099] {ubc_nfsp_example.py:266} INFO - EVALUATION AT ITERATION 3000
# [2022-02-19 19:45:56,100] {nfsp.py:23} INFO - Saving episode 3000 to DB
# Submitted batch job 23252
# Dispatched experiment!
# Submitted batch job 23253
# Dispatched experiment!
# Submitted batch job 23254
# Dispatched experiment!
# Submitted batch job 23255
# Dispatched experiment!
# Submitted batch job 23256
# Dispatched experiment!
# Submitted batch job 23257
# Dispatched experiment!
# Submitted batch job 23258
# Dispatched experiment!
# [2022-02-19 19:45:57,421] {ubc_nfsp_example.py:253} INFO - ----Episode 3500 ---
# [2022-02-19 19:45:57,425] {ubc_nfsp_example.py:254} INFO - Episode length stats:
# count    3500.000000
# mean        3.961714
# std         2.386424
# min         2.000000
# 25%         2.000000
# 50%         4.000000
# 75%         4.000000
# max        18.000000
# dtype: float64
# [2022-02-19 19:45:57,426] {ubc_nfsp_example.py:256} INFO - PLAYER 0
# [2022-02-19 19:45:57,426] {ubc_nfsp_example.py:259} INFO - {'Bid for 0,0 licenses @ $0 with activity 0': tensor(1.6096), 'Bid for 0,1 licenses @ $50 with activity 50': tensor(11.1788), 'Bid for 1,0 licenses @ $75 with activity 75': tensor(9.9649), 'Bid for 1,1 licenses @ $125 with activity 125': tensor(18.8554)}
# [2022-02-19 19:45:57,428] {ubc_nfsp_example.py:260} INFO - Train time 0.57 seconds
# [2022-02-19 19:45:57,428] {ubc_nfsp_example.py:261} INFO - Total time 7.58 seconds
# [2022-02-19 19:45:57,428] {ubc_nfsp_example.py:262} INFO - Training the DQN for player 0 is a 0.08 fraction
# [2022-02-19 19:45:57,428] {ubc_nfsp_example.py:263} INFO - Loss (Supervised, RL): (None, tensor(220.0242))
# [2022-02-19 19:45:57,429] {ubc_nfsp_example.py:256} INFO - PLAYER 1
# [2022-02-19 19:45:57,429] {ubc_nfsp_example.py:259} INFO - {'Bid for 0,0 licenses @ $0 with activity 0': tensor(-3.6829), 'Bid for 0,1 licenses @ $50 with activity 50': tensor(25.7005), 'Bid for 1,0 licenses @ $75 with activity 75': tensor(14.0265), 'Bid for 1,1 licenses @ $125 with activity 125': tensor(28.5126)}
# [2022-02-19 19:45:57,430] {ubc_nfsp_example.py:260} INFO - Train time 0.60 seconds
# [2022-02-19 19:45:57,430] {ubc_nfsp_example.py:261} INFO - Total time 7.58 seconds
# [2022-02-19 19:45:57,431] {ubc_nfsp_example.py:262} INFO - Training the DQN for player 1 is a 0.08 fraction
# [2022-02-19 19:45:57,431] {ubc_nfsp_example.py:263} INFO - Loss (Supervised, RL): (None, tensor(133.6859))
# [2022-02-19 19:45:57,431] {ubc_nfsp_example.py:266} INFO - EVALUATION AT ITERATION 3500
# [2022-02-19 19:45:57,431] {nfsp.py:23} INFO - Saving episode 3500 to DB
# Submitted batch job 23259
# Dispatched experiment!
# Submitted batch job 23260
# Dispatched experiment!
# Submitted batch job 23261
# Dispatched experiment!
# Submitted batch job 23262
# Dispatched experiment!
# Submitted batch job 23263
# Dispatched experiment!
# Submitted batch job 23264
# Dispatched experiment!
# Submitted batch job 23265
# Dispatched experiment!
# [2022-02-19 19:45:58,885] {ubc_nfsp_example.py:253} INFO - ----Episode 4000 ---
# [2022-02-19 19:45:58,889] {ubc_nfsp_example.py:254} INFO - Episode length stats:
# count    4000.000000
# mean        3.976500
# std         2.415762
# min         2.000000
# 25%         2.000000
# 50%         4.000000
# 75%         4.000000
# max        18.000000
# dtype: float64
# [2022-02-19 19:45:58,889] {ubc_nfsp_example.py:256} INFO - PLAYER 0
# [2022-02-19 19:45:58,890] {ubc_nfsp_example.py:259} INFO - {'Bid for 0,0 licenses @ $0 with activity 0': tensor(1.4114), 'Bid for 0,1 licenses @ $50 with activity 50': tensor(11.6016), 'Bid for 1,0 licenses @ $75 with activity 75': tensor(10.9645), 'Bid for 1,1 licenses @ $125 with activity 125': tensor(19.8884)}
# [2022-02-19 19:45:58,891] {ubc_nfsp_example.py:260} INFO - Train time 0.69 seconds
# [2022-02-19 19:45:58,891] {ubc_nfsp_example.py:261} INFO - Total time 9.04 seconds
# [2022-02-19 19:45:58,891] {ubc_nfsp_example.py:262} INFO - Training the DQN for player 0 is a 0.08 fraction
# [2022-02-19 19:45:58,892] {ubc_nfsp_example.py:263} INFO - Loss (Supervised, RL): (tensor(2.6619), tensor(228.1127))
# [2022-02-19 19:45:58,892] {ubc_nfsp_example.py:256} INFO - PLAYER 1
# [2022-02-19 19:45:58,893] {ubc_nfsp_example.py:259} INFO - {'Bid for 0,0 licenses @ $0 with activity 0': tensor(-3.4770), 'Bid for 0,1 licenses @ $50 with activity 50': tensor(25.4129), 'Bid for 1,0 licenses @ $75 with activity 75': tensor(15.1669), 'Bid for 1,1 licenses @ $125 with activity 125': tensor(28.9507)}
# [2022-02-19 19:45:58,894] {ubc_nfsp_example.py:260} INFO - Train time 0.72 seconds
# [2022-02-19 19:45:58,894] {ubc_nfsp_example.py:261} INFO - Total time 9.04 seconds
# [2022-02-19 19:45:58,894] {ubc_nfsp_example.py:262} INFO - Training the DQN for player 1 is a 0.08 fraction
# [2022-02-19 19:45:58,895] {ubc_nfsp_example.py:263} INFO - Loss (Supervised, RL): (tensor(2.1382), tensor(195.3545))
# [2022-02-19 19:45:58,895] {ubc_nfsp_example.py:266} INFO - EVALUATION AT ITERATION 4000
# [2022-02-19 19:45:58,895] {nfsp.py:23} INFO - Saving episode 4000 to DB
# Submitted batch job 23266
# Dispatched experiment!
# Submitted batch job 23267
# Dispatched experiment!
# Submitted batch job 23268
# Dispatched experiment!
# Submitted batch job 23269
# Dispatched experiment!
# Submitted batch job 23270
# Dispatched experiment!
# Submitted batch job 23271
# Dispatched experiment!
# Submitted batch job 23272
# Dispatched experiment!
# [2022-02-19 19:46:00,295] {ubc_nfsp_example.py:253} INFO - ----Episode 4500 ---
# [2022-02-19 19:46:00,300] {ubc_nfsp_example.py:254} INFO - Episode length stats:
# count    4500.000000
# mean        3.976000
# std         2.387146
# min         2.000000
# 25%         2.000000
# 50%         4.000000
# 75%         4.000000
# max        18.000000
# dtype: float64
# [2022-02-19 19:46:00,300] {ubc_nfsp_example.py:256} INFO - PLAYER 0
# [2022-02-19 19:46:00,301] {ubc_nfsp_example.py:259} INFO - {'Bid for 0,0 licenses @ $0 with activity 0': tensor(1.3642), 'Bid for 0,1 licenses @ $50 with activity 50': tensor(12.7019), 'Bid for 1,0 licenses @ $75 with activity 75': tensor(13.6934), 'Bid for 1,1 licenses @ $125 with activity 125': tensor(23.0973)}
# [2022-02-19 19:46:00,303] {ubc_nfsp_example.py:260} INFO - Train time 0.82 seconds
# [2022-02-19 19:46:00,303] {ubc_nfsp_example.py:261} INFO - Total time 10.45 seconds
# [2022-02-19 19:46:00,303] {ubc_nfsp_example.py:262} INFO - Training the DQN for player 0 is a 0.08 fraction
# [2022-02-19 19:46:00,303] {ubc_nfsp_example.py:263} INFO - Loss (Supervised, RL): (tensor(1.6890), tensor(204.4029))
# [2022-02-19 19:46:00,303] {ubc_nfsp_example.py:256} INFO - PLAYER 1
# [2022-02-19 19:46:00,304] {ubc_nfsp_example.py:259} INFO - {'Bid for 0,0 licenses @ $0 with activity 0': tensor(-2.5881), 'Bid for 0,1 licenses @ $50 with activity 50': tensor(25.6009), 'Bid for 1,0 licenses @ $75 with activity 75': tensor(18.9983), 'Bid for 1,1 licenses @ $125 with activity 125': tensor(32.7989)}
# [2022-02-19 19:46:00,305] {ubc_nfsp_example.py:260} INFO - Train time 0.86 seconds
# [2022-02-19 19:46:00,305] {ubc_nfsp_example.py:261} INFO - Total time 10.46 seconds
# [2022-02-19 19:46:00,305] {ubc_nfsp_example.py:262} INFO - Training the DQN for player 1 is a 0.08 fraction
# [2022-02-19 19:46:00,306] {ubc_nfsp_example.py:263} INFO - Loss (Supervised, RL): (tensor(1.1810), tensor(151.9230))
# [2022-02-19 19:46:00,306] {ubc_nfsp_example.py:266} INFO - EVALUATION AT ITERATION 4500
# [2022-02-19 19:46:00,306] {nfsp.py:23} INFO - Saving episode 4500 to DB
# Submitted batch job 23273
# Dispatched experiment!
# Submitted batch job 23274
# Dispatched experiment!
# Submitted batch job 23275
# Dispatched experiment!
# Submitted batch job 23276
# Dispatched experiment!
# Submitted batch job 23277
# Dispatched experiment!
# Submitted batch job 23278
# Dispatched experiment!
# Submitted batch job 23279
# Dispatched experiment!
# [2022-02-19 19:46:01,827] {ubc_nfsp_example.py:253} INFO - ----Episode 5000 ---
# [2022-02-19 19:46:01,833] {ubc_nfsp_example.py:254} INFO - Episode length stats:
# count    5000.000000
# mean        4.005600
# std         2.362601
# min         2.000000
# 25%         2.000000
# 50%         4.000000
# 75%         4.000000
# max        18.000000
# dtype: float64
# [2022-02-19 19:46:01,833] {ubc_nfsp_example.py:256} INFO - PLAYER 0
# [2022-02-19 19:46:01,834] {ubc_nfsp_example.py:259} INFO - {'Bid for 0,0 licenses @ $0 with activity 0': tensor(1.5628), 'Bid for 0,1 licenses @ $50 with activity 50': tensor(13.8088), 'Bid for 1,0 licenses @ $75 with activity 75': tensor(16.1488), 'Bid for 1,1 licenses @ $125 with activity 125': tensor(24.4664)}
# [2022-02-19 19:46:01,836] {ubc_nfsp_example.py:260} INFO - Train time 0.95 seconds
# [2022-02-19 19:46:01,836] {ubc_nfsp_example.py:261} INFO - Total time 11.99 seconds
# [2022-02-19 19:46:01,836] {ubc_nfsp_example.py:262} INFO - Training the DQN for player 0 is a 0.08 fraction
# [2022-02-19 19:46:01,837] {ubc_nfsp_example.py:263} INFO - Loss (Supervised, RL): (tensor(1.2663), tensor(238.9779))
# [2022-02-19 19:46:01,837] {ubc_nfsp_example.py:256} INFO - PLAYER 1
# [2022-02-19 19:46:01,837] {ubc_nfsp_example.py:259} INFO - {'Bid for 0,0 licenses @ $0 with activity 0': tensor(-2.2444), 'Bid for 0,1 licenses @ $50 with activity 50': tensor(25.4067), 'Bid for 1,0 licenses @ $75 with activity 75': tensor(20.9252), 'Bid for 1,1 licenses @ $125 with activity 125': tensor(35.1435)}
# [2022-02-19 19:46:01,839] {ubc_nfsp_example.py:260} INFO - Train time 1.00 seconds
# [2022-02-19 19:46:01,839] {ubc_nfsp_example.py:261} INFO - Total time 11.99 seconds
# [2022-02-19 19:46:01,839] {ubc_nfsp_example.py:262} INFO - Training the DQN for player 1 is a 0.08 fraction
# [2022-02-19 19:46:01,839] {ubc_nfsp_example.py:263} INFO - Loss (Supervised, RL): (tensor(1.4498), tensor(151.8689))
# [2022-02-19 19:46:01,839] {ubc_nfsp_example.py:266} INFO - EVALUATION AT ITERATION 5000
# [2022-02-19 19:46:01,840] {nfsp.py:23} INFO - Saving episode 5000 to DB
# Submitted batch job 23280
# Dispatched experiment!
# Submitted batch job 23281
# Dispatched experiment!
# Submitted batch job 23282
# Dispatched experiment!
# Submitted batch job 23283
# Dispatched experiment!
# Submitted batch job 23284
# Dispatched experiment!
# Submitted batch job 23285
# Dispatched experiment!
# Submitted batch job 23286
# Dispatched experiment!
# [2022-02-19 19:46:02,347] {ubc_nfsp_example.py:339} INFO - Walltime: 12.50 seconds
# [2022-02-19 19:46:02,348] {ubc_nfsp_example.py:340} INFO - All done. Goodbye!

# %%
# !python /apps/open_spiel/web/auctions/manage.py bestrespond --experiment_name test --run_name mlp --t 4500 --num_training_episodes 1000  --br_name hello --br_player 1 --config feb2/mlp
# Out:
# Reading from env variable CLOCK_AUCTION_CONFIG_DIR. If it is not set, there will be trouble.
# CLOCK_AUCTION_CONFIG_DIR=/apps/open_spiel/configs
# Parsing configuration from /apps/open_spiel/configs/small_game_2.json
# Done config parsing
# [2022-02-18 02:41:19,085] {rl_environment.py:195} INFO - Using game instance: turn_based_simultaneous_game
# [2022-02-18 02:41:19,085] {ubc_nfsp_example.py:109} INFO - Game has a state size of 226, 4 distinct actions, and 2 players
# [2022-02-18 02:41:19,085] {ubc_nfsp_example.py:110} INFO - Game has 2 products
# [2022-02-18 02:41:19,675] {ubc_nfsp.py:92} INFO - Creating NFSP using device: cuda for player 0
# [2022-02-18 02:41:19,675] {ubc_dqn.py:247} INFO - Double DQN activated for player 0
# [2022-02-18 02:41:19,675] {ubc_dqn.py:281} INFO - Creating DQN using device: cuda for player 0
# [2022-02-18 02:41:23,671] {ubc_nfsp.py:92} INFO - Creating NFSP using device: cuda for player 1
# [2022-02-18 02:41:23,671] {ubc_dqn.py:247} INFO - Double DQN activated for player 1
# [2022-02-18 02:41:23,671] {ubc_dqn.py:281} INFO - Creating DQN using device: cuda for player 1
# [2022-02-18 02:41:23,682] {ubc_utils.py:355} INFO - Reading BR config from feb2/mlp
# [2022-02-18 02:41:23,685] {ubc_utils.py:98} INFO - Setting numpy and torch seed to 1234
# [2022-02-18 02:41:23,685] {rl_environment.py:195} INFO - Using game instance: turn_based_simultaneous_game
# [2022-02-18 02:41:23,685] {ubc_dqn.py:247} INFO - Double DQN activated for player 1
# [2022-02-18 02:41:23,685] {ubc_dqn.py:281} INFO - Creating DQN using device: cuda for player 1
# [2022-02-18 02:41:23,691] {ubc_br.py:196} INFO - Training for 1000 episodes
# [2022-02-18 02:41:23,694] {ubc_br.py:234} INFO - Walltime: 0.01 seconds
# Traceback (most recent call last):
#   File "/apps/open_spiel/venv/lib/python3.8/site-packages/django/db/backends/utils.py", line 85, in _execute
#     return self.cursor.execute(sql, params)
# psycopg2.errors.UndefinedColumn: column "t" of relation "auctions_bestresponse" does not exist
# LINE 1: ...r_player", "name", "walltime", "model", "config", "t") VALUE...
#                                                              ^
#
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/apps/open_spiel/web/auctions/manage.py", line 22, in <module>
#     main()
#   File "/apps/open_spiel/web/auctions/manage.py", line 18, in main
#     execute_from_command_line(sys.argv)
#   File "/apps/open_spiel/venv/lib/python3.8/site-packages/django/core/management/__init__.py", line 425, in execute_from_command_line
#     utility.execute()
#   File "/apps/open_spiel/venv/lib/python3.8/site-packages/django/core/management/__init__.py", line 419, in execute
#     self.fetch_command(subcommand).run_from_argv(self.argv)
#   File "/apps/open_spiel/venv/lib/python3.8/site-packages/django/core/management/base.py", line 373, in run_from_argv
#     self.execute(*args, **cmd_options)
#   File "/apps/open_spiel/venv/lib/python3.8/site-packages/django/core/management/base.py", line 417, in execute
#     output = self.handle(*args, **options)
#   File "/apps/open_spiel/web/auctions/auctions/management/commands/bestrespond.py", line 70, in handle
#     run_br(result_saver, opts.report_freq, env_and_model, opts.num_training_episodes, opts.br_player, opts.dry_run, opts.seed, opts.compute_exact_br, config)
#   File "/apps/open_spiel/open_spiel/python/examples/ubc_br.py", line 237, in run_br
#     result_saver.save(checkpoint)
#   File "/apps/open_spiel/web/auctions/auctions/management/commands/bestrespond.py", line 23, in save
#     BestResponse.objects.create(
#   File "/apps/open_spiel/venv/lib/python3.8/site-packages/django/db/models/manager.py", line 85, in manager_method
#     return getattr(self.get_queryset(), name)(*args, **kwargs)
#   File "/apps/open_spiel/venv/lib/python3.8/site-packages/django/db/models/query.py", line 457, in create
#     obj.save(force_insert=True, using=self.db)
#   File "/apps/open_spiel/venv/lib/python3.8/site-packages/django_extensions/db/models.py", line 22, in save
#     super().save(**kwargs)
#   File "/apps/open_spiel/venv/lib/python3.8/site-packages/django/db/models/base.py", line 743, in save
#     self.save_base(using=using, force_insert=force_insert,
#   File "/apps/open_spiel/venv/lib/python3.8/site-packages/django/db/models/base.py", line 780, in save_base
#     updated = self._save_table(
#   File "/apps/open_spiel/venv/lib/python3.8/site-packages/django/db/models/base.py", line 885, in _save_table
#     results = self._do_insert(cls._base_manager, using, fields, returning_fields, raw)
#   File "/apps/open_spiel/venv/lib/python3.8/site-packages/django/db/models/base.py", line 923, in _do_insert
#     return manager._insert(
#   File "/apps/open_spiel/venv/lib/python3.8/site-packages/django/db/models/manager.py", line 85, in manager_method
#     return getattr(self.get_queryset(), name)(*args, **kwargs)
#   File "/apps/open_spiel/venv/lib/python3.8/site-packages/django/db/models/query.py", line 1301, in _insert
#     return query.get_compiler(using=using).execute_sql(returning_fields)
#   File "/apps/open_spiel/venv/lib/python3.8/site-packages/django/db/models/sql/compiler.py", line 1441, in execute_sql
#     cursor.execute(sql, params)
#   File "/apps/open_spiel/venv/lib/python3.8/site-packages/django/db/backends/utils.py", line 99, in execute
#     return super().execute(sql, params)
#   File "/apps/open_spiel/venv/lib/python3.8/site-packages/django/db/backends/utils.py", line 67, in execute
#     return self._execute_with_wrappers(sql, params, many=False, executor=self._execute)
#   File "/apps/open_spiel/venv/lib/python3.8/site-packages/django/db/backends/utils.py", line 76, in _execute_with_wrappers
#     return executor(sql, params, many, context)
#   File "/apps/open_spiel/venv/lib/python3.8/site-packages/django/db/backends/utils.py", line 85, in _execute
#     return self.cursor.execute(sql, params)
#   File "/apps/open_spiel/venv/lib/python3.8/site-packages/django/db/utils.py", line 90, in __exit__
#     raise dj_exc_value.with_traceback(traceback) from exc_value
#   File "/apps/open_spiel/venv/lib/python3.8/site-packages/django/db/backends/utils.py", line 85, in _execute
#     return self.cursor.execute(sql, params)
# django.db.utils.ProgrammingError: column "t" of relation "auctions_bestresponse" does not exist
# LINE 1: ...r_player", "name", "walltime", "model", "config", "t") VALUE...
#                                                              ^

# %%
BestResponse.objects.all()
# Out:
# <QuerySet [<BestResponse: Player 0 BR (hello) to mlp Iteration 4500>, <BestResponse: Player 1 BR (hello) to mlp Iteration 4500>]>
