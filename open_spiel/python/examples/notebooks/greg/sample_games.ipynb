# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
SAMPLER = '/global/scratch/open_spiel/open_spiel/open_spiel/python/examples/notebooks/greg/sample_games.py'
WRITER = '/global/scratch/open_spiel/open_spiel/open_spiel/python/examples/notebooks/greg/write_configs.py'

CONFIG_DIR = '/global/scratch/open_spiel/open_spiel/open_spiel/python/examples/notebooks/greg/configs'

# %% [markdown]
# # Sampling

# %% [markdown]
# ## jan12 (agrees on first 3 seeds)

# %%
# !python sample_games.py --n_configs 5 --licenses 1 4 --action_prefix 3 3 --min_mccfr_iters 100 --seed 1234 --output configs/jan12_repro.pkl
# Out:
# Sampling games with args: {'n_configs': 5, 'map_name': 'BCEncumbered', 'licenses': [1, 4], 'action_prefix': [3, 3], 'clock_increment': 0.05, 'max_rounds': 15, 'heuristic_deviations': 1000, 'min_types': 3, 'max_types': 3, 'min_bidders': 2, 'max_bidders': 2, 'min_value_per_subscriber': 20, 'max_value_per_subscriber': 35, 'min_market_share': 0.35, 'max_market_share': 0.5, 'z_spread': 0.1, 'max_straightforward_rounds': 20, 'max_straightforward_rounds_alternating': 25, 'min_mccfr_iters': 100, 'use_external_mccfr': True, 'seed': 1234, 'output': 'configs/jan12_repro.pkl', 'delete_if_exists': False, 'report_interval': 30}
# Prefix bids:
#  [[0 3]
#  [0 3]]
# Accepted 0.00000%: : 37it [00:08,  3.49it/s]MCCFR: speed of 125.32 iters/s
# SUCCESS
# ...

# %%
original_seeds = [870414972, 226683104, 536566236, 720663555, 499961888]
    
with open('configs/jan12_repro.pkl', 'rb') as f:
    configs_repro = pickle.load(f)
   
print(f"Original seeds:   {original_seeds}")
print(f"Reproduced seeds: {[c['sats_seed'] for c in configs_repro]}")
# Out:
# Original seeds:   [870414972, 226683104, 536566236, 720663555, 499961888]
# Reproduced seeds: [870414972, 226683104, 536566236, 887086973, 246543539]

# %% [markdown]
# ## jan19_boring

# %%
# !python sample_games.py --n_configs 5 --map_name BCEncumbered40 --licenses 2 4 --action_prefix 10 10 --min_mccfr_iters 100 --seed 1234 --min_market_share 0.3 --max_market_share 0.45 --output configs/jan19_boring.pkl --delete_if_exists
# Out:
# /global/scratch/newmanne/anaconda3NEW/envs/py38/lib/python3.8/site-packages/torch/cuda/__init__.py:107: UserWarning: CUDA initialization: The NVIDIA driver on your system is too old (found version 6050). Please update your GPU driver by downloading and installing a new version from the URL: http://www.nvidia.com/Download/index.aspx Alternatively, go to: https://pytorch.org to install a PyTorch version that has been compiled with your version of the CUDA driver. (Triggered internally at ../c10/cuda/CUDAFunctions.cpp:109.)
#   return torch._C._cuda_getDeviceCount() > 0
# ...

# %% [markdown]
# ## jan12/feb4: 2 players, varying types

# %%
# 4 types
# !python /global/scratch/open_spiel/open_spiel/open_spiel/python/examples/notebooks/greg/sample_games.py --n_configs 5 --licenses 1 4 --action_prefix 3 3 --min_mccfr_iters 100 --seed 1234 --output configs/jan12_repro_4t.pkl --min_types 4 --max_types 4
# !python /global/scratch/open_spiel/open_spiel/open_spiel/python/examples/notebooks/greg/write_configs.py --sats_fnames /global/scratch/open_spiel/open_spiel/notebooks/greg/configs/jan12_repro_4t.pkl --prefix feb4_4t
# Out:
# Loaded 5 samples.
# Created 20 modified configs for 5 base games.
# Running SATS...
# 100%|█████████████████████████████████████████████| 5/5 [00:31<00:00,  6.24s/it]
# All done, goodbye!

# %%
# 3 types
# !python /global/scratch/open_spiel/open_spiel/open_spiel/python/examples/notebooks/greg/sample_games.py --n_configs 5 --licenses 1 4 --action_prefix 3 3 --min_mccfr_iters 100 --seed 1234 --output configs/jan12_repro_3t.pkl --min_types 3 --max_types 3
# !python /global/scratch/open_spiel/open_spiel/open_spiel/python/examples/notebooks/greg/write_configs.py --sats_fnames /global/scratch/open_spiel/open_spiel/notebooks/greg/configs/jan12_repro_3t.pkl --prefix feb4_3t
# Out:
# Loaded 5 samples.
# Created 20 modified configs for 5 base games.
# Running SATS...
# 100%|█████████████████████████████████████████████| 5/5 [00:30<00:00,  6.06s/it]
# All done, goodbye!

# %%
# 2 types
# !python /global/scratch/open_spiel/open_spiel/open_spiel/python/examples/notebooks/greg/sample_games.py --n_configs 5 --licenses 1 4 --action_prefix 3 3 --min_mccfr_iters 100 --seed 1234 --output configs/jan12_repro_2t.pkl --min_types 2 --max_types 2
# !python /global/scratch/open_spiel/open_spiel/open_spiel/python/examples/notebooks/greg/write_configs.py --sats_fnames /global/scratch/open_spiel/open_spiel/notebooks/greg/configs/jan12_repro_2t.pkl --prefix feb4_2t
# Out:
# Loaded 5 samples.
# Created 20 modified configs for 5 base games.
# Running SATS...
# 100%|█████████████████████████████████████████████| 5/5 [00:30<00:00,  6.10s/it]
# All done, goodbye!

# %%
# 1 type
# !python /global/scratch/open_spiel/open_spiel/open_spiel/python/examples/notebooks/greg/sample_games.py --n_configs 5 --licenses 1 4 --action_prefix 3 3 --min_mccfr_iters 100 --seed 1234 --output configs/jan12_repro_1t.pkl --min_types 1 --max_types 1
# !python /global/scratch/open_spiel/open_spiel/open_spiel/python/examples/notebooks/greg/write_configs.py --sats_fnames /global/scratch/open_spiel/open_spiel/notebooks/greg/configs/jan12_repro_1t.pkl --prefix feb4_1t
# Out:
# Loaded 5 samples.
# Created 20 modified configs for 5 base games.
# Running SATS...
# 100%|█████████████████████████████████████████████| 5/5 [00:30<00:00,  6.08s/it]
# All done, goodbye!

# %% [markdown]
# ## 3-player games

# %%
# !python {SAMPLER} --help
# Out:
# usage: sample_games.py [-h] [--n_configs N_CONFIGS] [--map_name MAP_NAME]
#                        [--licenses [LICENSES [LICENSES ...]]]
#                        [--action_prefix [ACTION_PREFIX [ACTION_PREFIX ...]]]
#                        [--clock_increment CLOCK_INCREMENT]
#                        [--max_rounds MAX_ROUNDS]
#                        [--heuristic_deviations HEURISTIC_DEVIATIONS]
#                        [--min_types MIN_TYPES] [--max_types MAX_TYPES]
#                        [--min_bidders MIN_BIDDERS] [--max_bidders MAX_BIDDERS]
#                        [--min_value_per_subscriber MIN_VALUE_PER_SUBSCRIBER]
#                        [--max_value_per_subscriber MAX_VALUE_PER_SUBSCRIBER]
#                        [--min_market_share MIN_MARKET_SHARE]
#                        [--max_market_share MAX_MARKET_SHARE]
#                        [--z_spread Z_SPREAD]
#                        [--max_straightforward_rounds MAX_STRAIGHTFORWARD_ROUNDS]
# ...

# %%
# !python {SAMPLER} --output {CONFIG_DIR}/feb8_3p_7supply.pkl --n_configs 5 --seed 1234 --min_bidders 3 --max_bidders 3 --licenses 1 7 --action_prefix 3 3 --min_mccfr_iters 100 --min_market_share 0.15 --max_market_share 0.2 --z_spread 0.1 --min_value_per_subscriber 35 --max_value_per_subscriber 50 --allow_float_values
# Out:
# 20516.69s - pydevd: Sending message related to process being replaced timed-out after 5 seconds
# Sampling games with args: {'n_configs': 5, 'map_name': 'BCEncumbered', 'licenses': [1, 7], 'action_prefix': [3, 3], 'clock_increment': 0.05, 'max_rounds': 15, 'heuristic_deviations': 1000, 'min_types': 3, 'max_types': 3, 'min_bidders': 3, 'max_bidders': 3, 'min_value_per_subscriber': 35, 'max_value_per_subscriber': 50, 'min_market_share': 0.15, 'max_market_share': 0.2, 'z_spread': 0.1, 'allow_float_values': True, 'max_straightforward_rounds': 20, 'max_straightforward_rounds_alternating': 25, 'min_mccfr_iters': 100, 'use_external_mccfr': True, 'seed': 1234, 'output': '/global/scratch/open_spiel/open_spiel/open_spiel/python/examples/notebooks/greg/configs/feb8_3p_7supply.pkl', 'delete_if_exists': False, 'report_interval': 30, 'plot_values': False}
# Prefix bids:
#  [[0 3]
#  [0 3]]
# 0it [00:00, ?it/s]MCCFR: speed of 82.58 iters/s
# SUCCESS
# ...

# %%
# !python {WRITER} --sats_fnames {CONFIG_DIR}/feb8_3p_7supply.pkl --prefix feb8_3p_7supply
# Out:
# 20685.09s - pydevd: Sending message related to process being replaced timed-out after 5 seconds
# Loaded 5 samples.
# Created 20 modified configs for 5 base games.
# Running SATS...
# 100%|█████████████████████████████████████████████| 5/5 [00:31<00:00,  6.28s/it]
# All done, goodbye!

# %%
# !python {SAMPLER} --output {CONFIG_DIR}/feb8_3p_5supply.pkl --n_configs 5 --seed 1234 --min_bidders 3 --max_bidders 3 --licenses 1 5 --action_prefix 3 3 --min_mccfr_iters 1 --min_market_share 0.2 --max_market_share 0.3 --z_spread 0.1 --min_value_per_subscriber 35 --max_value_per_subscriber 45 --allow_float_values --clock_increment 0.2
# Out:
# 24548.19s - pydevd: Sending message related to process being replaced timed-out after 5 seconds
# Sampling games with args: {'n_configs': 5, 'map_name': 'BCEncumbered', 'licenses': [1, 5], 'action_prefix': [3, 3], 'clock_increment': 0.2, 'max_rounds': 15, 'heuristic_deviations': 1000, 'min_types': 3, 'max_types': 3, 'min_bidders': 3, 'max_bidders': 3, 'min_value_per_subscriber': 35, 'max_value_per_subscriber': 45, 'min_market_share': 0.2, 'max_market_share': 0.3, 'z_spread': 0.1, 'allow_float_values': True, 'max_straightforward_rounds': 20, 'max_straightforward_rounds_alternating': 25, 'min_mccfr_iters': 1, 'use_external_mccfr': True, 'seed': 1234, 'output': '/global/scratch/open_spiel/open_spiel/open_spiel/python/examples/notebooks/greg/configs/feb8_3p_5supply.pkl', 'delete_if_exists': False, 'report_interval': 30, 'plot_values': False}
# Prefix bids:
#  [[0 3]
#  [0 3]]
# Accepted 0.00000%: : 1it [00:01,  1.96s/it]MCCFR: speed of 0.90 iters/s
# ...

# %%
# !python {WRITER} --sats_fnames {CONFIG_DIR}/feb8_3p_5supply.pkl --prefix feb8_3p_5supply
# Out:
# 27619.83s - pydevd: Sending message related to process being replaced timed-out after 5 seconds
# Loaded 5 samples.
# Created 20 modified configs for 5 base games.
# Running SATS...
# 100%|█████████████████████████████████████████████| 5/5 [00:28<00:00,  5.79s/it]
# All done, goodbye!

# %% [markdown]
# # harder 2p games
# not working; here's my attempt

# %%
# !python {SAMPLER} --output {CONFIG_DIR}/feb10_2p_8supply.pkl --n_configs 5 --seed 1234 --min_bidders 2 --max_bidders 2 --licenses 1 4 --action_prefix 4 4 --min_mccfr_iters 10 --min_market_share 0.45 --max_market_share 0.55 --z_spread 0.1 --min_value_per_subscriber 25 --max_value_per_subscriber 35 --allow_float_values --clock_increment 0.2
# Out:
# 113003.25s - pydevd: Sending message related to process being replaced timed-out after 5 seconds
# Sampling games with args: {'n_configs': 5, 'map_name': 'BCEncumbered', 'licenses': [1, 4], 'action_prefix': [4, 4], 'clock_increment': 0.2, 'max_rounds': 15, 'heuristic_deviations': 1000, 'min_types': 3, 'max_types': 3, 'min_bidders': 2, 'max_bidders': 2, 'min_value_per_subscriber': 25, 'max_value_per_subscriber': 35, 'min_market_share': 0.45, 'max_market_share': 0.55, 'z_spread': 0.1, 'allow_float_values': True, 'max_straightforward_rounds': 20, 'max_straightforward_rounds_alternating': 25, 'min_mccfr_iters': 10, 'use_external_mccfr': True, 'seed': 1234, 'output': '/global/scratch/open_spiel/open_spiel/open_spiel/python/examples/notebooks/greg/configs/feb10_2p_8supply.pkl', 'delete_if_exists': False, 'report_interval': 30, 'plot_values': False}
# Prefix bids:
#  [[0 4]
#  [0 4]]
# 0it [00:00, ?it/s]MCCFR: speed of 0.23 iters/s
# Failure reasons:
# - Slow MCCFR iters: 1
# ...

# %% [markdown]
# # 2 player games: 5/10 types

# %%
# !python {SAMPLER} --output {CONFIG_DIR}/feb10_2p_1type.pkl --n_configs 5 --seed 1234 --min_bidders 2 --max_bidders 2 --min_types 1 --max_types 1 --action_prefix 3 3 --min_mccfr_iters 20 --min_value_per_subscriber 20 --max_value_per_subscriber 30 --allow_float_values
# Out:
# 171516.06s - pydevd: Sending message related to process being replaced timed-out after 5 seconds
# Sampling games with args: {'n_configs': 5, 'map_name': 'BCEncumbered', 'licenses': [1, 4], 'action_prefix': [3, 3], 'clock_increment': 0.05, 'max_rounds': 15, 'heuristic_deviations': 1000, 'min_types': 1, 'max_types': 1, 'min_bidders': 2, 'max_bidders': 2, 'min_value_per_subscriber': 20, 'max_value_per_subscriber': 30, 'min_market_share': 0.35, 'max_market_share': 0.5, 'z_spread': 0.1, 'allow_float_values': True, 'max_straightforward_rounds': 20, 'max_straightforward_rounds_alternating': 25, 'min_mccfr_iters': 20, 'use_external_mccfr': True, 'seed': 1234, 'output': '/global/scratch/open_spiel/open_spiel/open_spiel/python/examples/notebooks/greg/configs/feb10_2p_1type.pkl', 'delete_if_exists': False, 'report_interval': 30, 'plot_values': False}
# Prefix bids:
#  [[0 3]
#  [0 3]]
# 0it [00:00, ?it/s]MCCFR: speed of 263.81 iters/s
# SUCCESS
# ...

# %%
# !python {WRITER} --sats_fnames {CONFIG_DIR}/feb10_2p_1type.pkl --prefix feb10_2p_1type
# Out:
# 171547.67s - pydevd: Sending message related to process being replaced timed-out after 5 seconds
# Loaded 5 samples.
# Created 20 modified configs for 5 base games.
# Running SATS...
# 100%|█████████████████████████████████████████████| 5/5 [00:25<00:00,  5.00s/it]
# All done, goodbye!

# %%
# !python {SAMPLER} --output {CONFIG_DIR}/feb10_2p_2type.pkl --n_configs 5 --seed 1234 --min_bidders 2 --max_bidders 2 --min_types 2 --max_types 2 --action_prefix 3 3 --min_mccfr_iters 20 --min_value_per_subscriber 20 --max_value_per_subscriber 30 --allow_float_values
# Out:
# 171423.54s - pydevd: Sending message related to process being replaced timed-out after 5 seconds
# Sampling games with args: {'n_configs': 5, 'map_name': 'BCEncumbered', 'licenses': [1, 4], 'action_prefix': [3, 3], 'clock_increment': 0.05, 'max_rounds': 15, 'heuristic_deviations': 1000, 'min_types': 2, 'max_types': 2, 'min_bidders': 2, 'max_bidders': 2, 'min_value_per_subscriber': 20, 'max_value_per_subscriber': 30, 'min_market_share': 0.35, 'max_market_share': 0.5, 'z_spread': 0.1, 'allow_float_values': True, 'max_straightforward_rounds': 20, 'max_straightforward_rounds_alternating': 25, 'min_mccfr_iters': 20, 'use_external_mccfr': True, 'seed': 1234, 'output': '/global/scratch/open_spiel/open_spiel/open_spiel/python/examples/notebooks/greg/configs/feb10_2p_2type.pkl', 'delete_if_exists': False, 'report_interval': 30, 'plot_values': False}
# Prefix bids:
#  [[0 3]
#  [0 3]]
# Accepted 0.00000%: : 1it [00:00,  4.38it/s]MCCFR: speed of 91.89 iters/s
# SUCCESS
# ...

# %%
# !python {WRITER} --sats_fnames {CONFIG_DIR}/feb10_2p_2type.pkl --prefix feb10_2p_2type
# Out:
# 171469.67s - pydevd: Sending message related to process being replaced timed-out after 5 seconds
# Loaded 5 samples.
# Created 20 modified configs for 5 base games.
# Running SATS...
# 100%|█████████████████████████████████████████████| 5/5 [00:25<00:00,  5.06s/it]
# All done, goodbye!

# %%
# !python {SAMPLER} --output {CONFIG_DIR}/feb10_2p_3type.pkl --n_configs 5 --seed 1234 --min_bidders 2 --max_bidders 2 --min_types 3 --max_types 3 --action_prefix 3 3 --min_mccfr_iters 20 --min_value_per_subscriber 20 --max_value_per_subscriber 30 --allow_float_values
# Out:
# 170888.68s - pydevd: Sending message related to process being replaced timed-out after 5 seconds
# Sampling games with args: {'n_configs': 5, 'map_name': 'BCEncumbered', 'licenses': [1, 4], 'action_prefix': [3, 3], 'clock_increment': 0.05, 'max_rounds': 15, 'heuristic_deviations': 1000, 'min_types': 3, 'max_types': 3, 'min_bidders': 2, 'max_bidders': 2, 'min_value_per_subscriber': 20, 'max_value_per_subscriber': 30, 'min_market_share': 0.35, 'max_market_share': 0.5, 'z_spread': 0.1, 'allow_float_values': True, 'max_straightforward_rounds': 20, 'max_straightforward_rounds_alternating': 25, 'min_mccfr_iters': 20, 'use_external_mccfr': True, 'seed': 1234, 'output': '/global/scratch/open_spiel/open_spiel/open_spiel/python/examples/notebooks/greg/configs/feb10_2p_3type.pkl', 'delete_if_exists': False, 'report_interval': 30, 'plot_values': False}
# Prefix bids:
#  [[0 3]
#  [0 3]]
# Accepted 0.00000%: : 4it [00:02,  1.45it/s]MCCFR: speed of 80.28 iters/s
# SUCCESS
# ...

# %%
# !python {WRITER} --sats_fnames {CONFIG_DIR}/feb10_2p_3type.pkl --prefix feb10_2p_3type
# Out:
# 170939.53s - pydevd: Sending message related to process being replaced timed-out after 5 seconds
# Loaded 5 samples.
# Created 20 modified configs for 5 base games.
# Running SATS...
# 100%|█████████████████████████████████████████████| 5/5 [00:25<00:00,  5.05s/it]
# All done, goodbye!

# %%
# !python {SAMPLER} --output {CONFIG_DIR}/feb10_2p_5type.pkl --n_configs 5 --seed 1234 --min_bidders 2 --max_bidders 2 --min_types 5 --max_types 5 --action_prefix 3 3 --min_mccfr_iters 20 --min_value_per_subscriber 20 --max_value_per_subscriber 30 --allow_float_values
# Out:
# 170742.05s - pydevd: Sending message related to process being replaced timed-out after 5 seconds
# Sampling games with args: {'n_configs': 5, 'map_name': 'BCEncumbered', 'licenses': [1, 4], 'action_prefix': [3, 3], 'clock_increment': 0.05, 'max_rounds': 15, 'heuristic_deviations': 1000, 'min_types': 5, 'max_types': 5, 'min_bidders': 2, 'max_bidders': 2, 'min_value_per_subscriber': 20, 'max_value_per_subscriber': 30, 'min_market_share': 0.35, 'max_market_share': 0.5, 'z_spread': 0.1, 'allow_float_values': True, 'max_straightforward_rounds': 20, 'max_straightforward_rounds_alternating': 25, 'min_mccfr_iters': 20, 'use_external_mccfr': True, 'seed': 1234, 'output': '/global/scratch/open_spiel/open_spiel/open_spiel/python/examples/notebooks/greg/configs/feb10_2p_5type.pkl', 'delete_if_exists': False, 'report_interval': 30, 'plot_values': False}
# Prefix bids:
#  [[0 3]
#  [0 3]]
# Accepted 0.00000%: : 7it [00:07,  1.15it/s]MCCFR: speed of 29.79 iters/s
# SUCCESS
# ...

# %%
# !python {WRITER} --sats_fnames {CONFIG_DIR}/feb10_2p_5type.pkl --prefix feb10_2p_5type
# Out:
# 170842.87s - pydevd: Sending message related to process being replaced timed-out after 5 seconds
# Loaded 5 samples.
# Created 20 modified configs for 5 base games.
# Running SATS...
# 100%|█████████████████████████████████████████████| 5/5 [00:25<00:00,  5.07s/it]
# All done, goodbye!

# %%
# !python {SAMPLER} --output {CONFIG_DIR}/feb10_2p_7type.pkl --n_configs 5 --seed 1234 --min_bidders 2 --max_bidders 2 --min_types 7 --max_types 7 --action_prefix 3 3 --min_mccfr_iters 20 --min_value_per_subscriber 20 --max_value_per_subscriber 30 --allow_float_values
# Out:
# 169557.10s - pydevd: Sending message related to process being replaced timed-out after 5 seconds
# Sampling games with args: {'n_configs': 5, 'map_name': 'BCEncumbered', 'licenses': [1, 4], 'action_prefix': [3, 3], 'clock_increment': 0.05, 'max_rounds': 15, 'heuristic_deviations': 1000, 'min_types': 7, 'max_types': 7, 'min_bidders': 2, 'max_bidders': 2, 'min_value_per_subscriber': 20, 'max_value_per_subscriber': 30, 'min_market_share': 0.35, 'max_market_share': 0.5, 'z_spread': 0.1, 'allow_float_values': True, 'max_straightforward_rounds': 20, 'max_straightforward_rounds_alternating': 25, 'min_mccfr_iters': 20, 'use_external_mccfr': True, 'seed': 1234, 'output': '/global/scratch/open_spiel/open_spiel/open_spiel/python/examples/notebooks/greg/configs/feb10_2p_7type.pkl', 'delete_if_exists': False, 'report_interval': 30, 'plot_values': False}
# Prefix bids:
#  [[0 3]
#  [0 3]]
# Accepted 0.00000%: : 13it [00:17,  1.36s/it]MCCFR: speed of 31.33 iters/s
# SUCCESS
# ...

# %%
# !python {WRITER} --sats_fnames {CONFIG_DIR}/feb10_2p_7type.pkl --prefix feb10_2p_7type
# Out:
# 170526.32s - pydevd: Sending message related to process being replaced timed-out after 5 seconds
# Loaded 5 samples.
# Created 20 modified configs for 5 base games.
# Running SATS...
# 100%|█████████████████████████████████████████████| 5/5 [00:25<00:00,  5.11s/it]
# All done, goodbye!

# %% [markdown]
# # Plots

# %%
import sys; import os; sys.path.append(os.path.dirname(SAMPLER))
from sample_games import visualize_values
import pickle

def load_pickle(fname): 
    with open(fname, 'rb') as f: return pickle.load(f)

# %%
configs = load_pickle(f'{CONFIG_DIR}/feb10_2p_5type.pkl')
for config in configs:
    visualize_values(config)
