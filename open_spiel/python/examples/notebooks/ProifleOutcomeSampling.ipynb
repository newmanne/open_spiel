# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

import sys
import glob
import pandas as pd
import os
import seaborn as sns

from tqdm import tqdm
from statsmodels.distributions.empirical_distribution import ECDF
from collections import defaultdict
import pickle
import re
import json
from pathlib import Path


from open_spiel.python.algorithms.exploitability import nash_conv, best_response
from open_spiel.python.algorithms.ubc_exploitability import game_tree_size

from open_spiel.python.examples.ubc_plotting_utils import *
from open_spiel.python.examples.ubc_sample_game_tree import sample_game_tree, flatten_trees, flatten_tree
from open_spiel.python.examples.ubc_sample_game_tree import NodeType

from auctions.webutils import *

from open_spiel.python.algorithms.random_agent import RandomAgent
import bokeh
from bokeh.layouts import row, column
from bokeh.plotting import figure, show, output_file, save
from bokeh.io import output_notebook
from bokeh.models import HoverTool, ColumnDataSource, ColorBar, LogColorMapper, LinearColorMapper
from bokeh.transform import linear_cmap, log_cmap
from bokeh.palettes import Category10_10, Magma256, Spectral10, Category20_20
os.environ["DJANGO_ALLOW_ASYNC_UNSAFE"] = "true"
from collections import defaultdict
from open_spiel.python.examples.ppo_eval import run_eval
from open_spiel.python.examples.ppo_utils import run_ppo, read_ppo_config

output_notebook()

from open_spiel.python.examples.cfr_utils import read_cfr_config
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1003">Loading BokehJS ...</span>
#     </div>

# %%
# Or, if you want to do it "dry"
config = read_cfr_config('cfr_may31_23/mccfr')
config['seed'] = 12
game = pyspiel.load_game('python_clock_auction', dict(filename='may31_outcome/may31_outcome_3_base'))
# Out:
# {'solver_type': 'cfr', 'solver': 'mccfr', 'sampling_method': 'outcome'}
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Input In [4], in <module>
#       2 config = read_cfr_config('cfr_may31_23/mccfr')
#       3 config['seed'] = 12
# ----> 4 game = pyspiel.load_game('python_clock_auction', dict(filename='may31_outcome/may31_outcome_3_base'))
#
# File /apps/open_spiel/open_spiel/python/games/clock_auction.py:127, in ClockAuctionGame.__init__(self, params)
#     125 def __init__(self, params=None):
#     126   file_name = params.get('filename', 'parameters.json')
# --> 127   self.auction_params = parse_auction_params(file_name)
#     129   if self.auction_params.fold_randomness:
#     130     # Maps from a state to a set of outcomes, with probs
#     131     # How to determine a unique entry? If I face the same vector of (activity, processed demands, submitted demand), that implies same lottery mapping to new processed demands regardless of all else!
#     132     # Note that you could imagine pickling this
#     133     logging.info("Folding randomnesss...")
#
# File /apps/open_spiel/open_spiel/python/games/clock_auction_parser.py:22, in parse_auction_params(file_name)
#      19   full_path = f'{config_dir}/{file_name}'
#      21 logging.info(f"Parsing configuration from {full_path}")
# ---> 22 with open(full_path, 'r') as f:
#      23   game_params = json.load(f)
#      25   players = game_params['players']
#
# FileNotFoundError: [Errno 2] No such file or directory: '/apps/open_spiel/configs/may31_outcome/may31_outcome_3_base'

# %%
def prof():
    return run_eval(env_and_policy, num_samples=10_000, report_freq=1000)

def prof_training():
    timesteps = 100_000
    return run_ppo(env_and_policy, 10_000)

# %%
prof_training()

# %%
import cProfile, pstats
profiler = cProfile.Profile()
profiler.enable()
# eval_output = prof()
eval_output = prof_training()
profiler.disable()

# %%
stats = pstats.Stats(profiler).sort_stats('cumtime')
stats.print_stats()
# Out:
#          13257682 function calls (13044325 primitive calls) in 45.810 seconds
#
#    Ordered by: cumulative time
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         2    0.000    0.000   45.852   22.926 /home/ubuntu/.pyenv/versions/3.8.2/envs/venv/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3215(run_code)
#         2    0.000    0.000   45.852   22.926 {built-in method builtins.exec}
#         1    0.000    0.000   45.852   45.852 /tmp/ipykernel_19787/2878371160.py:5(<module>)
#         1    0.000    0.000   45.852   45.852 /tmp/ipykernel_19787/360000782.py:4(prof_training)
#         1    0.000    0.000   45.852   45.852 /apps/open_spiel/open_spiel/python/examples/ppo_utils.py:351(run_ppo)
#         1    0.239    0.239   45.852   45.852 /apps/open_spiel/open_spiel/python/examples/ppo_utils.py:250(training_loop)
#      2304    0.017    0.000   31.146    0.014 /apps/open_spiel/open_spiel/python/vector_env.py:20(step)
#     55304    2.946    0.000   23.196    0.000 /apps/open_spiel/open_spiel/python/rl_environment.py:237(get_time_step)
#      2304    0.132    0.000   20.031    0.009 /apps/open_spiel/open_spiel/python/vector_env.py:27(<listcomp>)
#     18432    0.043    0.000   19.898    0.001 /apps/open_spiel/open_spiel/python/env_decorator.py:29(step)
#     36872    1.241    0.000   17.450    0.000 /apps/open_spiel/open_spiel/python/env_decorator.py:48(get_time_step)
#    118450    8.150    0.000   15.775    0.000 /apps/open_spiel/open_spiel/python/games/clock_auction.py:901(set_from)
#      2305    0.008    0.000   11.088    0.005 /apps/open_spiel/open_spiel/python/vector_env.py:37(reset)
#      2305    0.052    0.000   11.080    0.005 /apps/open_spiel/open_spiel/python/vector_env.py:41(<listcomp>)
#     18432    0.247    0.000   11.019    0.001 /apps/open_spiel/open_spiel/python/rl_environment.py:302(step)
#        18    1.132    0.063    9.563    0.531 /apps/open_spiel/open_spiel/python/pytorch/ppo.py:302(learn)
#      3488    1.109    0.000    5.866    0.002 /apps/open_spiel/open_spiel/python/pytorch/auction_nets.py:163(get_action_and_value)
#      3474    0.023    0.000    5.823    0.002 /apps/open_spiel/open_spiel/python/pytorch/ppo.py:251(get_action_and_value)
#      2304    0.258    0.000    4.523    0.002 /apps/open_spiel/open_spiel/python/pytorch/ppo.py:254(step)
#      3921    0.008    0.000    3.983    0.001 /apps/open_spiel/open_spiel/python/env_decorator.py:33(reset)
#     51399    1.459    0.000    2.839    0.000 /apps/open_spiel/open_spiel/python/games/clock_auction.py:333(_legal_actions)
#      3506    0.033    0.000    2.599    0.001 /apps/open_spiel/open_spiel/python/pytorch/auction_nets.py:138(forward)
#      3488    0.009    0.000    2.594    0.001 /apps/open_spiel/open_spiel/python/pytorch/auction_nets.py:160(actor_and_critic)
# 77132/10518    0.162    0.000    2.510    0.000 /home/ubuntu/.pyenv/versions/3.8.2/envs/venv/lib/python3.8/site-packages/torch/nn/modules/module.py:1124(_call_impl)
#      3921    0.287    0.000    2.406    0.001 /apps/open_spiel/open_spiel/python/rl_environment.py:344(reset)
#      7012    0.043    0.000    2.355    0.000 /home/ubuntu/.pyenv/versions/3.8.2/envs/venv/lib/python3.8/site-packages/torch/nn/modules/container.py:137(forward)
#     22353    0.502    0.000    2.319    0.000 /apps/open_spiel/open_spiel/python/rl_environment.py:398(_sample_external_events)
#      1152    0.005    0.000    2.208    0.002 /home/ubuntu/.pyenv/versions/3.8.2/envs/venv/lib/python3.8/site-packages/torch/_tensor.py:340(backward)
#      1152    0.006    0.000    2.204    0.002 /home/ubuntu/.pyenv/versions/3.8.2/envs/venv/lib/python3.8/site-packages/torch/autograd/__init__.py:85(backward)
#      1152    2.170    0.002    2.170    0.002 {method 'run_backward' of 'torch._C._EngineBase' objects}
#    236900    1.292    0.000    1.889    0.000 /apps/open_spiel/open_spiel/python/games/clock_auction.py:840(get_history)
#      1152    0.010    0.000    1.720    0.001 /home/ubuntu/.pyenv/versions/3.8.2/envs/venv/lib/python3.8/site-packages/torch/optim/optimizer.py:108(wrapper)
#      1152    0.005    0.000    1.668    0.001 /home/ubuntu/.pyenv/versions/3.8.2/envs/venv/lib/python3.8/site-packages/torch/autograd/grad_mode.py:24(decorate_context)
#      1152    0.044    0.000    1.647    0.001 /home/ubuntu/.pyenv/versions/3.8.2/envs/venv/lib/python3.8/site-packages/torch/optim/adam.py:105(step)
#     17530    0.132    0.000    1.641    0.000 /apps/open_spiel/open_spiel/python/pytorch/auction_nets.py:55(forward)
#    118450    0.182    0.000    1.615    0.000 /apps/open_spiel/open_spiel/python/rl_environment.py:60(fastcopy)
#      7012    0.069    0.000    1.556    0.000 /apps/open_spiel/open_spiel/python/pytorch/auction_nets.py:81(forward)
#      1152    0.004    0.000    1.555    0.001 /home/ubuntu/.pyenv/versions/3.8.2/envs/venv/lib/python3.8/site-packages/torch/optim/adam.py:176(adam)
#      1152    0.460    0.000    1.545    0.001 /home/ubuntu/.pyenv/versions/3.8.2/envs/venv/lib/python3.8/site-packages/torch/optim/adam.py:229(_single_tensor_adam)
#     31575    0.411    0.000    1.534    0.000 /apps/open_spiel/open_spiel/python/games/clock_auction.py:381(_apply_action)
#    118450    1.182    0.000    1.523    0.000 /apps/open_spiel/open_spiel/python/games/clock_auction.py:867(get_sor_bundle_prices_history)
#    118450    0.482    0.000    1.408    0.000 /apps/open_spiel/open_spiel/python/rl_environment.py:62(<dictcomp>)
#    236900    0.476    0.000    1.282    0.000 /apps/open_spiel/open_spiel/python/games/clock_auction.py:828(prev_getter_wrapper)
#    314926    1.184    0.000    1.184    0.000 {method 'reduce' of 'numpy.ufunc' objects}
#    215937    0.202    0.000    1.101    0.000 {method 'any' of 'numpy.ndarray' objects}
#    118450    0.636    0.000    1.093    0.000 /apps/open_spiel/open_spiel/python/games/clock_auction.py:850(get_agg_demand_history)
#      1152    0.076    0.000    1.057    0.001 /home/ubuntu/.pyenv/versions/3.8.2/envs/venv/lib/python3.8/site-packages/torch/nn/utils/clip_grad.py:9(clip_grad_norm_)
#   1393985    0.995    0.000    0.995    0.000 {method 'copy' of 'numpy.ndarray' objects}
#     24542    0.050    0.000    0.951    0.000 /home/ubuntu/.pyenv/versions/3.8.2/envs/venv/lib/python3.8/site-packages/torch/nn/modules/linear.py:113(forward)
#    769700    0.933    0.000    0.933    0.000 {built-in method numpy.zeros}
#      3488    0.016    0.000    0.905    0.000 /apps/open_spiel/open_spiel/python/pytorch/auction_nets.py:11(__init__)
#    215937    0.120    0.000    0.899    0.000 /home/ubuntu/.pyenv/versions/3.8.2/envs/venv/lib/python3.8/site-packages/numpy/core/_methods.py:54(_any)
#     24542    0.878    0.000    0.878    0.000 {built-in method torch._C._nn.linear}
#     13143    0.162    0.000    0.868    0.000 /apps/open_spiel/open_spiel/python/examples/ubc_utils.py:154(__call__)
#     41526    0.851    0.000    0.851    0.000 {built-in method torch.tensor}
#    478443    0.824    0.000    0.824    0.000 {built-in method numpy.array}
#      3488    0.090    0.000    0.796    0.000 /home/ubuntu/.pyenv/versions/3.8.2/envs/venv/lib/python3.8/site-packages/torch/distributions/categorical.py:49(__init__)
# 136789/110441    0.298    0.000    0.742    0.000 {built-in method numpy.core._multiarray_umath.implement_array_function}
#      3488    0.051    0.000    0.694    0.000 /home/ubuntu/.pyenv/versions/3.8.2/envs/venv/lib/python3.8/site-packages/torch/distributions/categorical.py:119(log_prob)
#      5301    0.229    0.000    0.653    0.000 /apps/open_spiel/open_spiel/python/games/clock_auction.py:592(_process_bids)
#      7826    0.220    0.000    0.611    0.000 /apps/open_spiel/open_spiel/python/games/clock_auction.py:465(returns)
#    118450    0.602    0.000    0.602    0.000 /apps/open_spiel/open_spiel/python/games/clock_auction.py:808(<lambda>)
#     13143    0.128    0.000    0.567    0.000 /apps/open_spiel/open_spiel/python/examples/ubc_math_utils.py:4(fast_choice)
#      9216    0.287    0.000    0.485    0.000 /apps/open_spiel/open_spiel/python/games/clock_auction.py:523(_post_process)
#      1152    0.034    0.000    0.475    0.000 /home/ubuntu/.pyenv/versions/3.8.2/envs/venv/lib/python3.8/site-packages/torch/nn/utils/clip_grad.py:42(<listcomp>)
#      3488    0.093    0.000    0.474    0.000 /home/ubuntu/.pyenv/versions/3.8.2/envs/venv/lib/python3.8/site-packages/torch/distributions/distribution.py:255(_validate_sample)
#     48510    0.439    0.000    0.439    0.000 {method 'mul_' of 'torch._C._TensorBase' objects}
#     36864    0.438    0.000    0.438    0.000 /apps/open_spiel/open_spiel/python/rl_environment.py:476(is_turn_based)
#     83211    0.068    0.000    0.434    0.000 {method 'sum' of 'numpy.ndarray' objects}
#     19834    0.401    0.000    0.401    0.000 {built-in method torch.max}
#     17280    0.077    0.000    0.389    0.000 /home/ubuntu/.pyenv/versions/3.8.2/envs/venv/lib/python3.8/site-packages/torch/functional.py:1345(norm)
#      2304    0.118    0.000    0.367    0.000 /apps/open_spiel/open_spiel/python/pytorch/ppo.py:294(post_step)
#     41778    0.367    0.000    0.367    0.000 {method 'to' of 'torch._C._TensorBase' objects}
#     83211    0.038    0.000    0.366    0.000 /home/ubuntu/.pyenv/versions/3.8.2/envs/venv/lib/python3.8/site-packages/numpy/core/_methods.py:46(_sum)
#      3488    0.365    0.000    0.365    0.000 {method 'logsumexp' of 'torch._C._TensorBase' objects}
#     51399    0.341    0.000    0.364    0.000 /apps/open_spiel/open_spiel/python/games/clock_auction_bidders.py:25(get_profits)
#      2304    0.328    0.000    0.354    0.000 /apps/open_spiel/open_spiel/python/pytorch/ppo.py:108(legal_actions_to_mask)
#     18432    0.015    0.000    0.334    0.000 /apps/open_spiel/open_spiel/python/rl_environment.py:471(num_actions_per_step)
#      3488    0.104    0.000    0.332    0.000 /home/ubuntu/.pyenv/versions/3.8.2/envs/venv/lib/python3.8/site-packages/torch/distributions/distribution.py:34(__init__)
#      3488    0.317    0.000    0.317    0.000 /home/ubuntu/.pyenv/versions/3.8.2/envs/venv/lib/python3.8/site-packages/torch/distributions/constraints.py:256(check)
#      9216    0.026    0.000    0.314    0.000 /apps/open_spiel/open_spiel/python/games/clock_auction.py:434(_handle_bids)
#    201424    0.312    0.000    0.312    0.000 {built-in method numpy.asarray}
#     26286    0.040    0.000    0.303    0.000 /home/ubuntu/.pyenv/versions/3.8.2/envs/venv/lib/python3.8/site-packages/numpy/core/fromnumeric.py:51(_wrapfunc)
#     13143    0.015    0.000    0.302    0.000 <__array_function__ internals>:177(cumsum)
#     17530    0.300    0.000    0.300    0.000 {built-in method torch.cat}
#     32256    0.290    0.000    0.290    0.000 {method 'add_' of 'torch._C._TensorBase' objects}
#     17280    0.283    0.000    0.283    0.000 {built-in method torch.norm}
#     76848    0.277    0.000    0.277    0.000 /apps/open_spiel/open_spiel/python/games/clock_auction.py:835(<lambda>)
#      3488    0.117    0.000    0.272    0.000 /home/ubuntu/.pyenv/versions/3.8.2/envs/venv/lib/python3.8/site-packages/torch/distributions/categorical.py:127(entropy)
#     13143    0.019    0.000    0.267    0.000 /home/ubuntu/.pyenv/versions/3.8.2/envs/venv/lib/python3.8/site-packages/numpy/core/fromnumeric.py:2495(cumsum)
#     15652    0.115    0.000    0.260    0.000 /apps/open_spiel/open_spiel/python/games/clock_auction_bidders.py:62(value_for_package)
#     67051    0.070    0.000    0.255    0.000 <__array_function__ internals>:177(where)
#     17530    0.013    0.000    0.254    0.000 /home/ubuntu/.pyenv/versions/3.8.2/envs/venv/lib/python3.8/site-packages/torch/nn/modules/activation.py:353(forward)
#     35780    0.248    0.000    0.248    0.000 {method 'item' of 'torch._C._TensorBase' objects}
#      2304    0.030    0.000    0.244    0.000 /apps/open_spiel/open_spiel/python/pytorch/ppo.py:290(<listcomp>)
#     17530    0.240    0.000    0.240    0.000 {built-in method torch.tanh}
#    118450    0.238    0.000    0.238    0.000 {method 'fill' of 'numpy.ndarray' objects}
#      1152    0.042    0.000    0.227    0.000 /home/ubuntu/.pyenv/versions/3.8.2/envs/venv/lib/python3.8/site-packages/torch/optim/optimizer.py:216(zero_grad)
#        18    0.001    0.000    0.222    0.012 /apps/open_spiel/open_spiel/python/pytorch/ppo.py:455(test_convergence)
#     13143    0.046    0.000    0.214    0.000 /home/ubuntu/.pyenv/versions/3.8.2/envs/venv/lib/python3.8/site-packages/numpy/core/fromnumeric.py:38(_wrapit)
#     13129    0.016    0.000    0.204    0.000 <__array_function__ internals>:177(zeros_like)
#   1303004    0.197    0.000    0.197    0.000 {built-in method builtins.callable}
#     59225    0.196    0.000    0.196    0.000 /apps/open_spiel/open_spiel/python/rl_environment.py:467(num_players)
#      1152    0.009    0.000    0.191    0.000 /home/ubuntu/.pyenv/versions/3.8.2/envs/venv/lib/python3.8/site-packages/torch/nn/utils/clip_grad.py:32(<listcomp>)
#      2304    0.022    0.000    0.175    0.000 /home/ubuntu/.pyenv/versions/3.8.2/envs/venv/lib/python3.8/site-packages/torch/distributions/categorical.py:112(sample)
#     17280    0.006    0.000    0.171    0.000 /home/ubuntu/.pyenv/versions/3.8.2/envs/venv/lib/python3.8/site-packages/torch/nn/modules/module.py:1621(parameters)
#     13129    0.042    0.000    0.166    0.000 /home/ubuntu/.pyenv/versions/3.8.2/envs/venv/lib/python3.8/site-packages/numpy/core/numeric.py:76(zeros_like)
#     16128    0.165    0.000    0.165    0.000 {method 'sqrt' of 'torch._C._TensorBase' objects}
#     17280    0.006    0.000    0.165    0.000 /home/ubuntu/.pyenv/versions/3.8.2/envs/venv/lib/python3.8/site-packages/torch/nn/modules/module.py:1645(named_parameters)
#    510983    0.159    0.000    0.159    0.000 /apps/open_spiel/open_spiel/python/games/clock_auction.py:320(current_player)
#     17280    0.033    0.000    0.159    0.000 /home/ubuntu/.pyenv/versions/3.8.2/envs/venv/lib/python3.8/site-packages/torch/nn/modules/module.py:1608(_named_members)
#      3488    0.028    0.000    0.158    0.000 /home/ubuntu/.pyenv/versions/3.8.2/envs/venv/lib/python3.8/site-packages/torch/distributions/constraints.py:208(check)
#     76848    0.154    0.000    0.154    0.000 /apps/open_spiel/open_spiel/python/games/clock_auction.py:836(<lambda>)
#      3921    0.008    0.000    0.152    0.000 /apps/open_spiel/open_spiel/python/games/clock_auction.py:278(new_initial_state)
#     16128    0.149    0.000    0.149    0.000 {method 'addcdiv_' of 'torch._C._TensorBase' objects}
#     10464    0.145    0.000    0.145    0.000 {method 'all' of 'torch._C._TensorBase' objects}
#      3921    0.078    0.000    0.143    0.000 /apps/open_spiel/open_spiel/python/games/clock_auction.py:301(__init__)
#     16128    0.142    0.000    0.142    0.000 {method 'addcmul_' of 'torch._C._TensorBase' objects}
#     13143    0.118    0.000    0.132    0.000 /apps/open_spiel/open_spiel/python/games/clock_auction.py:509(chance_outcomes)
#     68435    0.125    0.000    0.132    0.000 /apps/open_spiel/open_spiel/python/games/clock_auction.py:565(_apply_bid)
#        18    0.000    0.000    0.129    0.007 /apps/open_spiel/open_spiel/python/pytorch/ppo.py:211(<lambda>)
#    118450    0.096    0.000    0.126    0.000 /apps/open_spiel/open_spiel/python/games/clock_auction.py:816(<lambda>)
# 626267/626266    0.118    0.000    0.118    0.000 {built-in method builtins.len}
#      6944    0.116    0.000    0.116    0.000 {built-in method torch.clamp}
#      6976    0.022    0.000    0.115    0.000 /home/ubuntu/.pyenv/versions/3.8.2/envs/venv/lib/python3.8/site-packages/torch/distributions/utils.py:106(__get__)
#        18    0.001    0.000    0.115    0.006 /apps/open_spiel/open_spiel/python/pytorch/auction_nets.py:92(__init__)
#      5760    0.008    0.000    0.111    0.000 /home/ubuntu/.pyenv/versions/3.8.2/envs/venv/lib/python3.8/site-packages/torch/_tensor.py:26(wrapped)
#      8114    0.109    0.000    0.109    0.000 {method 'mean' of 'torch._C._TensorBase' objects}
#     16100    0.105    0.000    0.105    0.000 {method 'zero_' of 'torch._C._TensorBase' objects}
#     15652    0.020    0.000    0.103    0.000 {method 'all' of 'numpy.ndarray' objects}
#    113312    0.102    0.000    0.102    0.000 /home/ubuntu/.pyenv/versions/3.8.2/envs/venv/lib/python3.8/site-packages/torch/nn/modules/module.py:1194(__getattr__)
#    178728    0.078    0.000    0.102    0.000 /home/ubuntu/.pyenv/versions/3.8.2/envs/venv/lib/python3.8/site-packages/torch/_tensor.py:1071(grad)
#    687012    0.100    0.000    0.100    0.000 {method 'append' of 'list' objects}
#     13143    0.012    0.000    0.100    0.000 <__array_function__ internals>:177(searchsorted)
#    118450    0.099    0.000    0.099    0.000 {method 'transpose' of 'numpy.ndarray' objects}
#        18    0.000    0.000    0.089    0.005 /apps/open_spiel/open_spiel/python/pytorch/auction_nets.py:124(build_torso)
#     17530    0.088    0.000    0.088    0.000 {method 'expand_as' of 'torch._C._TensorBase' objects}
#      3488    0.087    0.000    0.087    0.000 {built-in method torch.where}
# 134784/26496    0.064    0.000    0.086    0.000 /home/ubuntu/.pyenv/versions/3.8.2/envs/venv/lib/python3.8/site-packages/torch/nn/modules/module.py:1775(named_modules)
#     15670    0.007    0.000    0.084    0.000 /home/ubuntu/.pyenv/versions/3.8.2/envs/venv/lib/python3.8/site-packages/numpy/core/_methods.py:60(_all)
#     36872    0.080    0.000    0.080    0.000 {method 'tolist' of 'torch._C._TensorBase' objects}
#     32556    0.080    0.000    0.080    0.000 {method 'detach' of 'torch._C._TensorBase' objects}
#        90    0.001    0.000    0.080    0.001 /apps/open_spiel/open_spiel/python/pytorch/auction_nets.py:50(__init__)
#     11304    0.036    0.000    0.078    0.000 /home/ubuntu/.pyenv/versions/3.8.2/envs/venv/lib/python3.8/site-packages/torch/nn/modules/module.py:1210(__setattr__)
#     13143    0.078    0.000    0.078    0.000 {method 'cumsum' of 'numpy.ndarray' objects}
#        36    0.000    0.000    0.073    0.002 /apps/open_spiel/open_spiel/python/pytorch/auction_nets.py:66(__init__)
#     13143    0.015    0.000    0.071    0.000 /home/ubuntu/.pyenv/versions/3.8.2/envs/venv/lib/python3.8/site-packages/numpy/core/fromnumeric.py:1319(searchsorted)
#      3488    0.003    0.000    0.070    0.000 /home/ubuntu/.pyenv/versions/3.8.2/envs/venv/lib/python3.8/site-packages/torch/distributions/categorical.py:92(probs)
#      3488    0.070    0.000    0.070    0.000 {method 'gather' of 'torch._C._TensorBase' objects}
#     17050    0.020    0.000    0.067    0.000 <__array_function__ internals>:177(copyto)
#      3488    0.005    0.000    0.067    0.000 /home/ubuntu/.pyenv/versions/3.8.2/envs/venv/lib/python3.8/site-packages/torch/distributions/utils.py:65(logits_to_probs)
#      5301    0.034    0.000    0.067    0.000 /apps/open_spiel/open_spiel/python/examples/ubc_utils.py:204(permute_array)
#     10580    0.064    0.000    0.064    0.000 {method 'reshape' of 'torch._C._TensorBase' objects}
#      4608    0.010    0.000    0.063    0.000 /home/ubuntu/.pyenv/versions/3.8.2/envs/venv/lib/python3.8/site-packages/torch/_tensor.py:713(__iter__)
#      3488    0.005    0.000    0.062    0.000 /home/ubuntu/.pyenv/versions/3.8.2/envs/venv/lib/python3.8/site-packages/torch/nn/functional.py:1804(softmax)
#     13129    0.019    0.000    0.060    0.000 <__array_function__ internals>:177(empty_like)
#      2304    0.059    0.000    0.059    0.000 {built-in method torch.multinomial}
#      3506    0.058    0.000    0.058    0.000 {method 'sum' of 'torch._C._TensorBase' objects}
#      3488    0.058    0.000    0.058    0.000 {method 'any' of 'torch._C._TensorBase' objects}
#      3488    0.021    0.000    0.058    0.000 /home/ubuntu/.pyenv/versions/3.8.2/envs/venv/lib/python3.8/site-packages/torch/functional.py:44(broadcast_tensors)
#     51399    0.057    0.000    0.057    0.000 {method 'nonzero' of 'numpy.ndarray' objects}
# 124159/113093    0.037    0.000    0.057    0.000 {built-in method builtins.isinstance}
#      3488    0.056    0.000    0.056    0.000 {method 'softmax' of 'torch._C._TensorBase' objects}
#      3488    0.055    0.000    0.055    0.000 {built-in method torch.isnan}
#       126    0.001    0.000    0.053    0.000 /apps/open_spiel/open_spiel/python/pytorch/auction_nets.py:28(layer_init)
#    229058    0.053    0.000    0.053    0.000 /apps/open_spiel/open_spiel/python/games/clock_auction.py:461(is_terminal)
#     81740    0.053    0.000    0.053    0.000 {built-in method torch._C._get_tracing_state}
#      5301    0.049    0.000    0.052    0.000 /apps/open_spiel/open_spiel/python/games/clock_auction.py:424(_generate_processing_queue)
#     77965    0.051    0.000    0.051    0.000 {built-in method __new__ of type object at 0x55cb8fabbfc0}
#       126    0.003    0.000    0.049    0.000 /home/ubuntu/.pyenv/versions/3.8.2/envs/venv/lib/python3.8/site-packages/torch/nn/init.py:454(orthogonal_)
#      3488    0.048    0.000    0.048    0.000 /home/ubuntu/.pyenv/versions/3.8.2/envs/venv/lib/python3.8/site-packages/torch/distributions/constraints.py:307(check)
#      4608    0.045    0.000    0.045    0.000 {method 'unbind' of 'torch._C._TensorBase' objects}
#     76848    0.045    0.000    0.045    0.000 /apps/open_spiel/open_spiel/python/games/clock_auction.py:875(<lambda>)
#      4608    0.044    0.000    0.044    0.000 {built-in method torch.zeros}
#    169849    0.042    0.000    0.042    0.000 /apps/open_spiel/open_spiel/python/games/clock_auction_bidders.py:22(get_values)
#     13143    0.041    0.000    0.041    0.000 {method 'searchsorted' of 'numpy.ndarray' objects}
#      4608    0.005    0.000    0.041    0.000 /home/ubuntu/.pyenv/versions/3.8.2/envs/venv/lib/python3.8/site-packages/torch/_ops.py:138(__call__)
#    118450    0.039    0.000    0.039    0.000 /apps/open_spiel/open_spiel/python/games/clock_auction.py:807(<lambda>)
#      3921    0.009    0.000    0.039    0.000 /home/ubuntu/.pyenv/versions/3.8.2/envs/venv/lib/python3.8/site-packages/numpy/core/numeric.py:149(ones)
#     13143    0.037    0.000    0.037    0.000 {method 'rand' of 'numpy.random.mtrand.RandomState' objects}
#      6994    0.037    0.000    0.037    0.000 {method 'squeeze' of 'torch._C._TensorBase' objects}
#     70227    0.024    0.000    0.037    0.000 {built-in method builtins.getattr}
#      2304    0.037    0.000    0.037    0.000 {method 'pow' of 'torch._C._TensorBase' objects}
#      2304    0.009    0.000    0.036    0.000 /home/ubuntu/.pyenv/versions/3.8.2/envs/venv/lib/python3.8/site-packages/torch/autograd/profiler.py:445(__enter__)
#     41834    0.026    0.000    0.035    0.000 {method 'add' of 'set' objects}
#     76848    0.035    0.000    0.035    0.000 /apps/open_spiel/open_spiel/python/games/clock_auction.py:877(<lambda>)
#      5810    0.035    0.000    0.035    0.000 {method 'flatten' of 'torch._C._TensorBase' objects}
#       126    0.001    0.000    0.034    0.000 /home/ubuntu/.pyenv/versions/3.8.2/envs/venv/lib/python3.8/site-packages/torch/nn/modules/linear.py:90(__init__)
#    249060    0.034    0.000    0.034    0.000 {built-in method torch._C._has_torch_function_unary}
#      2304    0.001    0.000    0.033    0.000 /home/ubuntu/.pyenv/versions/3.8.2/envs/venv/lib/python3.8/site-packages/torch/_tensor.py:637(__rsub__)
#      1152    0.018    0.000    0.032    0.000 /home/ubuntu/.pyenv/versions/3.8.2/envs/venv/lib/python3.8/site-packages/torch/_tensor.py:641(__rdiv__)
#      5760    0.031    0.000    0.031    0.000 {method 'view' of 'torch._C._TensorBase' objects}
#      1152    0.031    0.000    0.031    0.000 {built-in method torch.stack}
#      2304    0.031    0.000    0.031    0.000 {built-in method torch.rsub}
#      3488    0.031    0.000    0.031    0.000 {built-in method torch.broadcast_tensors}
#     48412    0.018    0.000    0.031    0.000 /home/ubuntu/.pyenv/versions/3.8.2/envs/venv/lib/python3.8/site-packages/torch/_tensor.py:731(__hash__)
#       126    0.029    0.000    0.029    0.000 {built-in method torch._C._linalg.linalg_qr}
#      5628    0.012    0.000    0.026    0.000 /home/ubuntu/.pyenv/versions/3.8.2/envs/venv/lib/python3.8/site-packages/torch/autograd/grad_mode.py:131(__enter__)
#       378    0.004    0.000    0.026    0.000 /home/ubuntu/.pyenv/versions/3.8.2/envs/venv/lib/python3.8/site-packages/torch/nn/modules/module.py:254(__init__)
#      1152    0.006    0.000    0.026    0.000 /home/ubuntu/.pyenv/versions/3.8.2/envs/venv/lib/python3.8/site-packages/torch/autograd/__init__.py:30(_make_grads)
#      3506    0.004    0.000    0.026    0.000 /home/ubuntu/.pyenv/versions/3.8.2/envs/venv/lib/python3.8/site-packages/torch/nn/modules/flatten.py:44(forward)
#    122581    0.026    0.000    0.026    0.000 {method 'items' of 'dict' objects}
#      2304    0.025    0.000    0.025    0.000 {built-in method torch._ops.profiler._record_function_enter}
#     11256    0.017    0.000    0.025    0.000 /home/ubuntu/.pyenv/versions/3.8.2/envs/venv/lib/python3.8/site-packages/torch/autograd/grad_mode.py:226(__init__)
#      5628    0.010    0.000    0.024    0.000 /home/ubuntu/.pyenv/versions/3.8.2/envs/venv/lib/python3.8/site-packages/torch/autograd/grad_mode.py:135(__exit__)
#      3506    0.023    0.000    0.023    0.000 {method 'permute' of 'torch._C._TensorBase' objects}
#      4672    0.023    0.000    0.023    0.000 {method 'long' of 'torch._C._TensorBase' objects}
#      2304    0.004    0.000    0.023    0.000 /home/ubuntu/.pyenv/versions/3.8.2/envs/venv/lib/python3.8/site-packages/torch/autograd/profiler.py:436(__init__)
#     11052    0.016    0.000    0.022    0.000 /home/ubuntu/.pyenv/versions/3.8.2/envs/venv/lib/python3.8/site-packages/torch/nn/parameter.py:9(__instancecheck__)
#      5628    0.018    0.000    0.020    0.000 /home/ubuntu/.pyenv/versions/3.8.2/envs/venv/lib/python3.8/site-packages/torch/autograd/grad_mode.py:126(__init__)
#      2304    0.006    0.000    0.019    0.000 /home/ubuntu/.pyenv/versions/3.8.2/envs/venv/lib/python3.8/site-packages/torch/autograd/profiler.py:449(__exit__)
#      3488    0.019    0.000    0.019    0.000 {method 'unsqueeze' of 'torch._C._TensorBase' objects}
#      1152    0.019    0.000    0.019    0.000 {built-in method torch.ones_like}
#      1152    0.019    0.000    0.019    0.000 {method 'std' of 'torch._C._TensorBase' objects}
#      5292    0.014    0.000    0.018    0.000 /apps/open_spiel/open_spiel/python/examples/ubc_utils.py:189(convert_seed_to_swaps)
#      1152    0.018    0.000    0.018    0.000 {method 'float' of 'torch._C._TensorBase' objects}
#      1188    0.017    0.000    0.017    0.000 {method 'abs' of 'torch._C._TensorBase' objects}
#     67051    0.017    0.000    0.017    0.000 /home/ubuntu/.pyenv/versions/3.8.2/envs/venv/lib/python3.8/site-packages/numpy/core/multiarray.py:341(where)
#       126    0.001    0.000    0.016    0.000 /home/ubuntu/.pyenv/versions/3.8.2/envs/venv/lib/python3.8/site-packages/torch/nn/modules/linear.py:103(reset_parameters)
#      1166    0.016    0.000    0.016    0.000 {method 'exp' of 'torch._C._TensorBase' objects}
#     20768    0.011    0.000    0.016    0.000 /home/ubuntu/.pyenv/versions/3.8.2/envs/venv/lib/python3.8/site-packages/torch/_VF.py:25(__getattr__)
#      7012    0.010    0.000    0.016    0.000 /home/ubuntu/.pyenv/versions/3.8.2/envs/venv/lib/python3.8/site-packages/torch/nn/modules/container.py:129(__iter__)
#      2304    0.007    0.000    0.015    0.000 /apps/open_spiel/open_spiel/python/vector_env.py:29(<listcomp>)
#        18    0.000    0.000    0.014    0.001 /home/ubuntu/.pyenv/versions/3.8.2/envs/venv/lib/python3.8/site-packages/torch/nn/modules/module.py:823(to)
#    378/18    0.003    0.000    0.014    0.001 /home/ubuntu/.pyenv/versions/3.8.2/envs/venv/lib/python3.8/site-packages/torch/nn/modules/module.py:577(_apply)
#      1152    0.014    0.000    0.014    0.000 {method 'reciprocal' of 'torch._C._TensorBase' objects}
#        18    0.000    0.000    0.013    0.001 /apps/open_spiel/open_spiel/python/pytorch/ppo.py:248(get_value)
#        18    0.000    0.000    0.013    0.001 /apps/open_spiel/open_spiel/python/pytorch/auction_nets.py:181(get_value)
#        18    0.000    0.000    0.013    0.001 /apps/open_spiel/open_spiel/python/pytorch/auction_nets.py:157(critic)
#        14    0.000    0.000    0.013    0.001 /home/ubuntu/.pyenv/versions/3.8.2/envs/venv/lib/python3.8/site-packages/torch/nn/modules/module.py:1534(load_state_dict)
#     25344    0.010    0.000    0.013    0.000 /home/ubuntu/.pyenv/versions/3.8.2/envs/venv/lib/python3.8/site-packages/torch/nn/modules/module.py:1666(<lambda>)
#       126    0.001    0.000    0.012    0.000 /home/ubuntu/.pyenv/versions/3.8.2/envs/venv/lib/python3.8/site-packages/torch/nn/init.py:366(kaiming_uniform_)
#     31806    0.012    0.000    0.012    0.000 {built-in method builtins.max}
#    294/14    0.001    0.000    0.012    0.001 /home/ubuntu/.pyenv/versions/3.8.2/envs/venv/lib/python3.8/site-packages/torch/nn/modules/module.py:1572(load)
#      3488    0.006    0.000    0.012    0.000 /home/ubuntu/.pyenv/versions/3.8.2/envs/venv/lib/python3.8/site-packages/torch/distributions/categorical.py:84(support)
#     18070    0.012    0.000    0.012    0.000 {method 'size' of 'torch._C._TensorBase' objects}
#      2304    0.011    0.000    0.011    0.000 {built-in method torch._ops.profiler._record_function_exit}
#       294    0.005    0.000    0.011    0.000 /home/ubuntu/.pyenv/versions/3.8.2/envs/venv/lib/python3.8/site-packages/torch/nn/modules/module.py:1440(_load_from_state_dict)
#      7842    0.010    0.000    0.010    0.000 <string>:2(__init__)
#     32856    0.010    0.000    0.010    0.000 {method 'dim' of 'torch._C._TensorBase' objects}
#      3488    0.006    0.000    0.010    0.000 /home/ubuntu/.pyenv/versions/3.8.2/envs/venv/lib/python3.8/site-packages/torch/autograd/grad_mode.py:177(__enter__)
#       288    0.009    0.000    0.009    0.000 {method 'shuffle' of 'numpy.random.mtrand.RandomState' objects}
#       252    0.009    0.000    0.009    0.000 {method 'uniform_' of 'torch._C._TensorBase' objects}
#      5292    0.006    0.000    0.009    0.000 /apps/open_spiel/open_spiel/python/examples/ubc_utils.py:186(factorial)
#     20372    0.009    0.000    0.009    0.000 {built-in method torch.is_grad_enabled}
#     16128    0.008    0.000    0.008    0.000 {method 'conj' of 'torch._C._TensorBase' objects}
#      2304    0.008    0.000    0.008    0.000 /apps/open_spiel/open_spiel/python/pytorch/ppo.py:275(<listcomp>)
#      3488    0.008    0.000    0.008    0.000 /home/ubuntu/.pyenv/versions/3.8.2/envs/venv/lib/python3.8/site-packages/torch/distributions/utils.py:121(__init__)
#       126    0.007    0.000    0.007    0.000 {method 'normal_' of 'torch._C._TensorBase' objects}
#     18432    0.007    0.000    0.007    0.000 /apps/open_spiel/open_spiel/python/rl_environment.py:94(last)
#     10593    0.007    0.000    0.007    0.000 {built-in method math.factorial}
#       270    0.000    0.000    0.007    0.000 /home/ubuntu/.pyenv/versions/3.8.2/envs/venv/lib/python3.8/site-packages/torch/nn/modules/module.py:921(convert)
#      8749    0.007    0.000    0.007    0.000 {built-in method builtins.min}
#     16100    0.007    0.000    0.007    0.000 {method 'requires_grad_' of 'torch._C._TensorBase' objects}
#      1152    0.003    0.000    0.007    0.000 /home/ubuntu/.pyenv/versions/3.8.2/envs/venv/lib/python3.8/site-packages/torch/optim/optimizer.py:84(_cuda_graph_capture_health_check)
#      6976    0.003    0.000    0.007    0.000 /home/ubuntu/.pyenv/versions/3.8.2/envs/venv/lib/python3.8/site-packages/torch/distributions/constraints.py:142(is_dependent)
#     48412    0.006    0.000    0.006    0.000 {built-in method builtins.id}
#      2304    0.006    0.000    0.006    0.000 /apps/open_spiel/open_spiel/python/pytorch/ppo.py:278(<listcomp>)
#      3921    0.006    0.000    0.006    0.000 {built-in method numpy.empty}
#      3488    0.006    0.000    0.006    0.000 {method 'bool' of 'torch._C._TensorBase' objects}
#      3488    0.006    0.000    0.006    0.000 /home/ubuntu/.pyenv/versions/3.8.2/envs/venv/lib/python3.8/site-packages/torch/distributions/constraints.py:251(__init__)
#     18232    0.006    0.000    0.006    0.000 {built-in method torch._C._set_grad_enabled}
#      2304    0.005    0.000    0.006    0.000 /home/ubuntu/.pyenv/versions/3.8.2/envs/venv/lib/python3.8/site-packages/torch/distributions/distribution.py:241(_extended_shape)
#     34602    0.006    0.000    0.006    0.000 {method 'get' of 'dict' objects}
#     53964    0.006    0.000    0.006    0.000 {method 'items' of 'collections.OrderedDict' objects}
#      7842    0.006    0.000    0.006    0.000 /apps/open_spiel/open_spiel/python/games/clock_auction.py:515(<listcomp>)
#      1152    0.003    0.000    0.005    0.000 /home/ubuntu/.pyenv/versions/3.8.2/envs/venv/lib/python3.8/site-packages/torch/optim/adam.py:198(<listcomp>)
#      1152    0.001    0.000    0.005    0.000 /home/ubuntu/.pyenv/versions/3.8.2/envs/venv/lib/python3.8/site-packages/torch/autograd/grad_mode.py:82(clone)
#     17280    0.005    0.000    0.005    0.000 /home/ubuntu/.pyenv/versions/3.8.2/envs/venv/lib/python3.8/site-packages/torch/functional.py:1450(<listcomp>)
#      7826    0.004    0.000    0.004    0.000 /apps/open_spiel/open_spiel/python/rl_environment.py:278(<listcomp>)
#     11620    0.004    0.000    0.004    0.000 {built-in method builtins.iter}
#     16758    0.004    0.000    0.004    0.000 {built-in method math.sqrt}
#     17050    0.004    0.000    0.004    0.000 /home/ubuntu/.pyenv/versions/3.8.2/envs/venv/lib/python3.8/site-packages/numpy/core/multiarray.py:1071(copyto)
#      5292    0.004    0.000    0.004    0.000 /apps/open_spiel/open_spiel/python/examples/ubc_utils.py:223(<listcomp>)
#        36    0.000    0.000    0.004    0.000 /home/ubuntu/.pyenv/versions/3.8.2/envs/venv/lib/python3.8/site-packages/torch/nn/modules/container.py:82(__init__)
#      3488    0.003    0.000    0.004    0.000 /home/ubuntu/.pyenv/versions/3.8.2/envs/venv/lib/python3.8/site-packages/torch/autograd/grad_mode.py:181(__exit__)
#     13129    0.004    0.000    0.004    0.000 /home/ubuntu/.pyenv/versions/3.8.2/envs/venv/lib/python3.8/site-packages/numpy/core/numeric.py:72(_zeros_like_dispatcher)
#      3139    0.002    0.000    0.004    0.000 {built-in method builtins.hasattr}
#      9248    0.004    0.000    0.004    0.000 {built-in method torch._C._has_torch_function}
#      5301    0.004    0.000    0.004    0.000 /apps/open_spiel/open_spiel/python/games/clock_auction.py:595(<listcomp>)
#     13143    0.004    0.000    0.004    0.000 /home/ubuntu/.pyenv/versions/3.8.2/envs/venv/lib/python3.8/site-packages/numpy/core/fromnumeric.py:1315(_searchsorted_dispatcher)
#    420/20    0.002    0.000    0.003    0.000 /home/ubuntu/.pyenv/versions/3.8.2/envs/venv/lib/python3.8/site-packages/torch/nn/modules/module.py:1316(state_dict)
#     13143    0.003    0.000    0.003    0.000 /home/ubuntu/.pyenv/versions/3.8.2/envs/venv/lib/python3.8/site-packages/numpy/core/fromnumeric.py:2491(_cumsum_dispatcher)
#        36    0.000    0.000    0.003    0.000 <__array_function__ internals>:177(var)
#       336    0.003    0.000    0.003    0.000 {method 'copy_' of 'torch._C._TensorBase' objects}
#      2304    0.003    0.000    0.003    0.000 /apps/open_spiel/open_spiel/python/examples/ppo_utils.py:274(<listcomp>)
#        36    0.000    0.000    0.003    0.000 /home/ubuntu/.pyenv/versions/3.8.2/envs/venv/lib/python3.8/site-packages/numpy/core/fromnumeric.py:3624(var)
#        36    0.002    0.000    0.003    0.000 /home/ubuntu/.pyenv/versions/3.8.2/envs/venv/lib/python3.8/site-packages/numpy/core/_methods.py:195(_var)
#        18    0.000    0.000    0.003    0.000 <__array_function__ internals>:177(allclose)
#        18    0.000    0.000    0.003    0.000 /home/ubuntu/.pyenv/versions/3.8.2/envs/venv/lib/python3.8/site-packages/numpy/core/numeric.py:2180(allclose)
#     13129    0.003    0.000    0.003    0.000 /home/ubuntu/.pyenv/versions/3.8.2/envs/venv/lib/python3.8/site-packages/numpy/core/multiarray.py:80(empty_like)
#      2304    0.003    0.000    0.003    0.000 /apps/open_spiel/open_spiel/python/vector_env.py:28(<listcomp>)
#        18    0.000    0.000    0.003    0.000 <__array_function__ internals>:177(isclose)
#     11052    0.003    0.000    0.003    0.000 {function _ParameterMeta.__instancecheck__ at 0x7f3e68568790}
#      1153    0.001    0.000    0.003    0.000 /home/ubuntu/.pyenv/versions/3.8.2/envs/venv/lib/python3.8/site-packages/torch/cuda/__init__.py:77(is_available)
#        18    0.000    0.000    0.003    0.000 /home/ubuntu/.pyenv/versions/3.8.2/envs/venv/lib/python3.8/site-packages/numpy/core/numeric.py:2259(isclose)
#      8020    0.003    0.000    0.003    0.000 {method 'values' of 'collections.OrderedDict' objects}
#       252    0.001    0.000    0.002    0.000 /home/ubuntu/.pyenv/versions/3.8.2/envs/venv/lib/python3.8/site-packages/torch/nn/modules/module.py:329(register_parameter)
#       126    0.000    0.000    0.002    0.000 /home/ubuntu/.pyenv/versions/3.8.2/envs/venv/lib/python3.8/site-packages/torch/nn/init.py:179(constant_)
#      1530    0.002    0.000    0.002    0.000 {method 'format' of 'str' objects}
#       126    0.000    0.000    0.002    0.000 /home/ubuntu/.pyenv/versions/3.8.2/envs/venv/lib/python3.8/site-packages/torch/nn/init.py:57(_no_grad_fill_)
#       126    0.000    0.000    0.002    0.000 /home/ubuntu/.pyenv/versions/3.8.2/envs/venv/lib/python3.8/site-packages/torch/nn/init.py:122(uniform_)
#       252    0.002    0.000    0.002    0.000 {built-in method torch.empty}
#       126    0.000    0.000    0.002    0.000 /home/ubuntu/.pyenv/versions/3.8.2/envs/venv/lib/python3.8/site-packages/torch/nn/init.py:12(_no_grad_uniform_)
#       420    0.001    0.000    0.002    0.000 /home/ubuntu/.pyenv/versions/3.8.2/envs/venv/lib/python3.8/site-packages/torch/nn/modules/module.py:1279(_save_to_state_dict)
#       252    0.000    0.000    0.002    0.000 /home/ubuntu/.pyenv/versions/3.8.2/envs/venv/lib/python3.8/site-packages/torch/nn/parameter.py:31(__new__)
#      3488    0.001    0.000    0.001    0.000 {built-in method builtins.setattr}
#      5628    0.001    0.000    0.001    0.000 /home/ubuntu/.pyenv/versions/3.8.2/envs/venv/lib/python3.8/site-packages/torch/_jit_internal.py:958(is_scripting)
#       738    0.001    0.000    0.001    0.000 /home/ubuntu/.pyenv/versions/3.8.2/envs/venv/lib/python3.8/site-packages/torch/nn/modules/module.py:1719(children)
#      3614    0.001    0.000    0.001    0.000 {method 'ndimension' of 'torch._C._TensorBase' objects}
#        18    0.000    0.000    0.001    0.000 /home/ubuntu/.pyenv/versions/3.8.2/envs/venv/lib/python3.8/site-packages/torch/nn/modules/flatten.py:39(__init__)
#       252    0.001    0.000    0.001    0.000 {built-in method _make_subclass}
#       126    0.001    0.000    0.001    0.000 {built-in method torch.diag}
#       252    0.001    0.000    0.001    0.000 /home/ubuntu/.pyenv/versions/3.8.2/envs/venv/lib/python3.8/site-packages/torch/nn/init.py:284(_calculate_fan_in_and_fan_out)
#        54    0.000    0.000    0.001    0.000 <__array_function__ internals>:177(all)
#       126    0.001    0.000    0.001    0.000 {method 'sign' of 'torch._C._TensorBase' objects}
#        36    0.001    0.000    0.001    0.000 {method 'cpu' of 'torch._C._TensorBase' objects}
#       126    0.000    0.000    0.001    0.000 /home/ubuntu/.pyenv/versions/3.8.2/envs/venv/lib/python3.8/site-packages/torch/nn/init.py:356(_calculate_correct_fan)
#        74    0.001    0.000    0.001    0.000 {built-in method torch.zeros_like}
#        18    0.000    0.000    0.001    0.000 /home/ubuntu/.pyenv/versions/3.8.2/envs/venv/lib/python3.8/site-packages/numpy/core/numeric.py:2340(within_tol)
#       126    0.001    0.000    0.001    0.000 {method 'view_as' of 'torch._C._TensorBase' objects}
#      4410    0.001    0.000    0.001    0.000 {method 'startswith' of 'str' objects}
#       108    0.000    0.000    0.001    0.000 /home/ubuntu/.pyenv/versions/3.8.2/envs/venv/lib/python3.8/site-packages/torch/nn/modules/module.py:371(add_module)
#      1154    0.001    0.000    0.001    0.000 {built-in method torch._C._cuda_getDeviceCount}
#      2304    0.001    0.000    0.001    0.000 {method 'numel' of 'torch.Size' objects}
#        54    0.000    0.000    0.001    0.000 /home/ubuntu/.pyenv/versions/3.8.2/envs/venv/lib/python3.8/site-packages/numpy/core/fromnumeric.py:2404(all)
#       126    0.001    0.000    0.001    0.000 {method 'new' of 'torch._C._TensorBase' objects}
#       252    0.000    0.000    0.001    0.000 /home/ubuntu/.pyenv/versions/3.8.2/envs/venv/lib/python3.8/site-packages/torch/nn/modules/module.py:581(compute_should_use_set_data)
#      1152    0.000    0.000    0.001    0.000 /home/ubuntu/.pyenv/versions/3.8.2/envs/venv/lib/python3.8/site-packages/torch/cuda/graphs.py:18(is_current_stream_capturing)
#       738    0.001    0.000    0.001    0.000 /home/ubuntu/.pyenv/versions/3.8.2/envs/venv/lib/python3.8/site-packages/torch/nn/modules/module.py:1728(named_children)
#       378    0.001    0.000    0.001    0.000 {built-in method torch._C._log_api_usage_once}
#      1152    0.001    0.000    0.001    0.000 /home/ubuntu/.pyenv/versions/3.8.2/envs/venv/lib/python3.8/site-packages/torch/autograd/__init__.py:77(_tensor_or_tensors_to_tuple)
#       126    0.001    0.000    0.001    0.000 {method 'fill_' of 'torch._C._TensorBase' objects}
#       216    0.001    0.000    0.001    0.000 {method 't_' of 'torch._C._TensorBase' objects}
#        54    0.000    0.000    0.001    0.000 /home/ubuntu/.pyenv/versions/3.8.2/envs/venv/lib/python3.8/site-packages/numpy/core/fromnumeric.py:69(_wrapreduction)
#      1404    0.001    0.000    0.001    0.000 {method 'numel' of 'torch._C._TensorBase' objects}
#       126    0.001    0.000    0.001    0.000 /home/ubuntu/.pyenv/versions/3.8.2/envs/venv/lib/python3.8/site-packages/torch/nn/init.py:67(calculate_gain)
#        18    0.001    0.000    0.001    0.000 {built-in method numpy.arange}
#      1152    0.000    0.000    0.000    0.000 {built-in method builtins.all}
#        36    0.000    0.000    0.000    0.000 /home/ubuntu/.pyenv/versions/3.8.2/envs/venv/lib/python3.8/site-packages/numpy/core/_methods.py:66(_count_reduce_items)
#         1    0.000    0.000    0.000    0.000 /apps/open_spiel/open_spiel/python/examples/ppo_utils.py:359(eval_hook)
#         1    0.000    0.000    0.000    0.000 /apps/open_spiel/open_spiel/python/examples/ppo_utils.py:334(ppo_checkpoint)
#       504    0.000    0.000    0.000    0.000 /home/ubuntu/.pyenv/versions/3.8.2/envs/venv/lib/python3.8/site-packages/torch/nn/modules/module.py:1211(remove_from)
#        36    0.000    0.000    0.000    0.000 /home/ubuntu/.pyenv/versions/3.8.2/envs/venv/lib/python3.8/site-packages/numpy/core/_ufunc_config.py:32(seterr)
#         1    0.000    0.000    0.000    0.000 /apps/open_spiel/open_spiel/python/rl_agent_policy.py:82(save)
#       252    0.000    0.000    0.000    0.000 {built-in method torch._has_compatible_shallow_copy_type}
#         2    0.000    0.000    0.000    0.000 /apps/open_spiel/open_spiel/python/pytorch/ppo.py:482(save)
#        18    0.000    0.000    0.000    0.000 /home/ubuntu/.pyenv/versions/3.8.2/envs/venv/lib/python3.8/site-packages/numpy/core/_ufunc_config.py:429(__enter__)
#        18    0.000    0.000    0.000    0.000 {method 'max' of 'torch._C._TensorBase' objects}
#      1152    0.000    0.000    0.000    0.000 {built-in method torch._C._cuda_isCurrentStreamCapturing}
#        54    0.000    0.000    0.000    0.000 /apps/open_spiel/open_spiel/python/pytorch/auction_nets.py:15(string_to_activation)
#       826    0.000    0.000    0.000    0.000 {method 'split' of 'str' objects}
#       126    0.000    0.000    0.000    0.000 {built-in method numpy.asanyarray}
#       308    0.000    0.000    0.000    0.000 <string>:1(__new__)
#       294    0.000    0.000    0.000    0.000 /home/ubuntu/.pyenv/versions/3.8.2/envs/venv/lib/python3.8/site-packages/torch/nn/modules/module.py:1478(<dictcomp>)
#        18    0.000    0.000    0.000    0.000 /home/ubuntu/.pyenv/versions/3.8.2/envs/venv/lib/python3.8/site-packages/torch/nn/modules/module.py:275(register_buffer)
#       270    0.000    0.000    0.000    0.000 {method 'is_floating_point' of 'torch._C._TensorBase' objects}
#        14    0.000    0.000    0.000    0.000 /home/ubuntu/.pyenv/versions/3.8.2/lib/python3.8/typing.py:765(__instancecheck__)
#       210    0.000    0.000    0.000    0.000 /home/ubuntu/.pyenv/versions/3.8.2/envs/venv/lib/python3.8/site-packages/torch/nn/parameter.py:153(is_lazy)
#        18    0.000    0.000    0.000    0.000 {method 'all' of 'numpy.generic' objects}
#         1    0.000    0.000    0.000    0.000 /apps/open_spiel/open_spiel/python/examples/ubc_utils.py:116(pretty_time)
#        14    0.000    0.000    0.000    0.000 /home/ubuntu/.pyenv/versions/3.8.2/lib/python3.8/typing.py:768(__subclasscheck__)
#        36    0.000    0.000    0.000    0.000 /home/ubuntu/.pyenv/versions/3.8.2/envs/venv/lib/python3.8/site-packages/numpy/core/_ufunc_config.py:131(geterr)
#       378    0.000    0.000    0.000    0.000 {built-in method torch._C._has_torch_function_variadic}
#        18    0.000    0.000    0.000    0.000 <__array_function__ internals>:177(result_type)
#         1    0.000    0.000    0.000    0.000 /home/ubuntu/.pyenv/versions/3.8.2/envs/venv/lib/python3.8/site-packages/humanize/time.py:399(precisedelta)
#        18    0.000    0.000    0.000    0.000 /home/ubuntu/.pyenv/versions/3.8.2/envs/venv/lib/python3.8/site-packages/numpy/core/_ufunc_config.py:434(__exit__)
#        18    0.000    0.000    0.000    0.000 {built-in method torch._C._nn._parse_to}
#       210    0.000    0.000    0.000    0.000 /home/ubuntu/.pyenv/versions/3.8.2/envs/venv/lib/python3.8/site-packages/torch/overrides.py:1697(is_tensor_like)
#        86    0.000    0.000    0.000    0.000 {built-in method builtins.issubclass}
#         2    0.000    0.000    0.000    0.000 /home/ubuntu/.pyenv/versions/3.8.2/lib/python3.8/codeop.py:135(__call__)
#         2    0.000    0.000    0.000    0.000 {built-in method builtins.compile}
#        18    0.000    0.000    0.000    0.000 /apps/open_spiel/open_spiel/python/pytorch/ppo.py:308(<listcomp>)
#         1    0.000    0.000    0.000    0.000 /apps/open_spiel/open_spiel/python/examples/ubc_utils.py:43(fix_seeds)
#        36    0.000    0.000    0.000    0.000 {method 'numpy' of 'torch._C._TensorBase' objects}
#        36    0.000    0.000    0.000    0.000 {built-in method builtins.abs}
#       294    0.000    0.000    0.000    0.000 /home/ubuntu/.pyenv/versions/3.8.2/envs/venv/lib/python3.8/site-packages/torch/nn/modules/module.py:1476(<dictcomp>)
#       180    0.000    0.000    0.000    0.000 {method 'lower' of 'str' objects}
#        36    0.000    0.000    0.000    0.000 {built-in method numpy.seterrobj}
#       252    0.000    0.000    0.000    0.000 /home/ubuntu/.pyenv/versions/3.8.2/envs/venv/lib/python3.8/site-packages/torch/__future__.py:18(get_overwrite_module_params_on_conversion)
#        14    0.000    0.000    0.000    0.000 /home/ubuntu/.pyenv/versions/3.8.2/lib/python3.8/abc.py:100(__subclasscheck__)
#         1    0.000    0.000    0.000    0.000 /home/ubuntu/.pyenv/versions/3.8.2/envs/venv/lib/python3.8/site-packages/torch/random.py:26(manual_seed)
#       294    0.000    0.000    0.000    0.000 {method 'keys' of 'collections.OrderedDict' objects}
#         1    0.000    0.000    0.000    0.000 /apps/open_spiel/open_spiel/python/examples/env_and_policy.py:13(make_policy)
#         1    0.000    0.000    0.000    0.000 /apps/open_spiel/open_spiel/python/rl_agent_policy.py:32(__init__)
#        54    0.000    0.000    0.000    0.000 /home/ubuntu/.pyenv/versions/3.8.2/envs/venv/lib/python3.8/site-packages/numpy/core/fromnumeric.py:70(<dictcomp>)
#        14    0.000    0.000    0.000    0.000 {built-in method _abc._abc_subclasscheck}
#        72    0.000    0.000    0.000    0.000 {built-in method numpy.geterrobj}
#         1    0.000    0.000    0.000    0.000 /home/ubuntu/.pyenv/versions/3.8.2/envs/venv/lib/python3.8/site-packages/torch/cuda/random.py:98(manual_seed_all)
#         1    0.000    0.000    0.000    0.000 /apps/open_spiel/open_spiel/python/examples/ppo_utils.py:228(__init__)
#         6    0.000    0.000    0.000    0.000 /home/ubuntu/.pyenv/versions/3.8.2/lib/python3.8/logging/__init__.py:2062(info)
#         1    0.000    0.000    0.000    0.000 /home/ubuntu/.pyenv/versions/3.8.2/envs/venv/lib/python3.8/site-packages/torch/cuda/__init__.py:154(_lazy_call)
#        54    0.000    0.000    0.000    0.000 /home/ubuntu/.pyenv/versions/3.8.2/envs/venv/lib/python3.8/site-packages/numpy/core/fromnumeric.py:2399(_all_dispatcher)
#        36    0.000    0.000    0.000    0.000 {built-in method numpy.core._multiarray_umath.normalize_axis_index}
#         1    0.000    0.000    0.000    0.000 /home/ubuntu/.pyenv/versions/3.8.2/envs/venv/lib/python3.8/site-packages/torch/cuda/random.py:108(cb)
#         1    0.000    0.000    0.000    0.000 /home/ubuntu/.pyenv/versions/3.8.2/envs/venv/lib/python3.8/site-packages/absl/logging/__init__.py:413(info)
#        18    0.000    0.000    0.000    0.000 /home/ubuntu/.pyenv/versions/3.8.2/envs/venv/lib/python3.8/site-packages/numpy/core/_ufunc_config.py:425(__init__)
#         1    0.000    0.000    0.000    0.000 /home/ubuntu/.pyenv/versions/3.8.2/envs/venv/lib/python3.8/site-packages/humanize/time.py:62(_date_and_delta)
#         1    0.000    0.000    0.000    0.000 /home/ubuntu/.pyenv/versions/3.8.2/envs/venv/lib/python3.8/site-packages/humanize/time.py:383(_suppress_lower_units)
#         1    0.000    0.000    0.000    0.000 /home/ubuntu/.pyenv/versions/3.8.2/envs/venv/lib/python3.8/site-packages/absl/logging/__init__.py:531(log)
#        36    0.000    0.000    0.000    0.000 /home/ubuntu/.pyenv/versions/3.8.2/envs/venv/lib/python3.8/site-packages/numpy/core/fromnumeric.py:3619(_var_dispatcher)
#        18    0.000    0.000    0.000    0.000 /apps/open_spiel/open_spiel/python/pytorch/ppo.py:492(get_max_policy_diff)
#         7    0.000    0.000    0.000    0.000 /home/ubuntu/.pyenv/versions/3.8.2/lib/python3.8/logging/__init__.py:1424(info)
#         5    0.000    0.000    0.000    0.000 /home/ubuntu/.pyenv/versions/3.8.2/envs/venv/lib/python3.8/site-packages/humanize/time.py:289(_quotient_and_remainder)
#         1    0.000    0.000    0.000    0.000 /home/ubuntu/.pyenv/versions/3.8.2/envs/venv/lib/python3.8/site-packages/humanize/time.py:43(_now)
#         1    0.000    0.000    0.000    0.000 /home/ubuntu/.pyenv/versions/3.8.2/envs/venv/lib/python3.8/site-packages/humanize/i18n.py:106(_ngettext)
#         2    0.000    0.000    0.000    0.000 /home/ubuntu/.pyenv/versions/3.8.2/lib/python3.8/contextlib.py:238(helper)
#         2    0.000    0.000    0.000    0.000 {method 'manual_seed' of 'torch._C.Generator' objects}
#         1    0.000    0.000    0.000    0.000 {method 'seed' of 'numpy.random.mtrand.RandomState' objects}
#         2    0.000    0.000    0.000    0.000 /home/ubuntu/.pyenv/versions/3.8.2/lib/python3.8/contextlib.py:108(__enter__)
#         1    0.000    0.000    0.000    0.000 /home/ubuntu/.pyenv/versions/3.8.2/envs/venv/lib/python3.8/site-packages/torch/cuda/__init__.py:454(device_count)
#         1    0.000    0.000    0.000    0.000 {built-in method now}
#         4    0.000    0.000    0.000    0.000 {built-in method builtins.next}
#        18    0.000    0.000    0.000    0.000 {method 'append' of 'collections.deque' objects}
#         9    0.000    0.000    0.000    0.000 /home/ubuntu/.pyenv/versions/3.8.2/lib/python3.8/enum.py:641(__hash__)
#         1    0.000    0.000    0.000    0.000 /home/ubuntu/.pyenv/versions/3.8.2/envs/venv/lib/python3.8/site-packages/absl/logging/__init__.py:1118(log)
#        18    0.000    0.000    0.000    0.000 /home/ubuntu/.pyenv/versions/3.8.2/envs/venv/lib/python3.8/site-packages/numpy/core/numeric.py:2176(_allclose_dispatcher)
#         1    0.000    0.000    0.000    0.000 /home/ubuntu/.pyenv/versions/3.8.2/envs/venv/lib/python3.8/site-packages/humanize/i18n.py:27(get_translation)
#         8    0.000    0.000    0.000    0.000 /home/ubuntu/.pyenv/versions/3.8.2/lib/python3.8/logging/__init__.py:1677(isEnabledFor)
#         2    0.000    0.000    0.000    0.000 /home/ubuntu/.pyenv/versions/3.8.2/lib/python3.8/contextlib.py:82(__init__)
#         2    0.000    0.000    0.000    0.000 /home/ubuntu/.pyenv/versions/3.8.2/lib/python3.8/contextlib.py:117(__exit__)
#         2    0.000    0.000    0.000    0.000 /home/ubuntu/.pyenv/versions/3.8.2/envs/venv/lib/python3.8/site-packages/traitlets/traitlets.py:566(__get__)
#         4    0.000    0.000    0.000    0.000 /home/ubuntu/.pyenv/versions/3.8.2/envs/venv/lib/python3.8/site-packages/IPython/core/compilerop.py:174(extra_flags)
#        18    0.000    0.000    0.000    0.000 /home/ubuntu/.pyenv/versions/3.8.2/envs/venv/lib/python3.8/site-packages/numpy/core/multiarray.py:664(result_type)
#        13    0.000    0.000    0.000    0.000 /home/ubuntu/.pyenv/versions/3.8.2/lib/python3.8/enum.py:347(<genexpr>)
#        18    0.000    0.000    0.000    0.000 {method 'discard' of 'set' objects}
#        18    0.000    0.000    0.000    0.000 /home/ubuntu/.pyenv/versions/3.8.2/envs/venv/lib/python3.8/site-packages/numpy/core/numeric.py:2255(_isclose_dispatcher)
#         1    0.000    0.000    0.000    0.000 /apps/open_spiel/open_spiel/python/examples/ppo_utils.py:366(report_hook)
#         3    0.000    0.000    0.000    0.000 /home/ubuntu/.pyenv/versions/3.8.2/envs/venv/lib/python3.8/site-packages/humanize/time.py:322(_carry)
#         2    0.000    0.000    0.000    0.000 {built-in method torch._C._cuda_isInBadFork}
#         1    0.000    0.000    0.000    0.000 {built-in method builtins.sorted}
#         2    0.000    0.000    0.000    0.000 /home/ubuntu/.pyenv/versions/3.8.2/envs/venv/lib/python3.8/site-packages/traitlets/traitlets.py:535(get)
#         1    0.000    0.000    0.000    0.000 /home/ubuntu/.pyenv/versions/3.8.2/lib/python3.8/logging/__init__.py:1485(log)
#         4    0.000    0.000    0.000    0.000 {built-in method builtins.divmod}
#         1    0.000    0.000    0.000    0.000 /tmp/ipykernel_19787/2878371160.py:6(<module>)
#         1    0.000    0.000    0.000    0.000 /home/ubuntu/.pyenv/versions/3.8.2/envs/venv/lib/python3.8/site-packages/absl/logging/converter.py:138(absl_to_standard)
#         2    0.000    0.000    0.000    0.000 /home/ubuntu/.pyenv/versions/3.8.2/lib/python3.8/enum.py:346(__iter__)
#         2    0.000    0.000    0.000    0.000 /home/ubuntu/.pyenv/versions/3.8.2/envs/venv/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3167(compare)
#         1    0.000    0.000    0.000    0.000 /home/ubuntu/.pyenv/versions/3.8.2/lib/python3.8/enum.py:343(__getitem__)
#         1    0.000    0.000    0.000    0.000 /apps/open_spiel/open_spiel/python/policy.py:109(__init__)
#         7    0.000    0.000    0.000    0.000 /home/ubuntu/.pyenv/versions/3.8.2/lib/python3.8/enum.py:366(<genexpr>)
#         1    0.000    0.000    0.000    0.000 /home/ubuntu/.pyenv/versions/3.8.2/lib/python3.8/enum.py:365(__reversed__)
#         1    0.000    0.000    0.000    0.000 /apps/open_spiel/open_spiel/python/examples/ppo_utils.py:244(add_report_hook)
#         2    0.000    0.000    0.000    0.000 /home/ubuntu/.pyenv/versions/3.8.2/envs/venv/lib/python3.8/site-packages/IPython/core/interactiveshell.py:1142(user_global_ns)
#         1    0.000    0.000    0.000    0.000 /apps/open_spiel/open_spiel/python/examples/env_and_policy.py:16(<dictcomp>)
#         1    0.000    0.000    0.000    0.000 {method 'replace' of 'str' objects}
#         1    0.000    0.000    0.000    0.000 /home/ubuntu/.pyenv/versions/3.8.2/lib/python3.8/gettext.py:290(ngettext)
#         9    0.000    0.000    0.000    0.000 {built-in method builtins.hash}
#         3    0.000    0.000    0.000    0.000 {built-in method time.time}
#         2    0.000    0.000    0.000    0.000 /home/ubuntu/.pyenv/versions/3.8.2/lib/python3.8/enum.py:349(__len__)
#         1    0.000    0.000    0.000    0.000 {built-in method math.modf}
#         1    0.000    0.000    0.000    0.000 /apps/open_spiel/open_spiel/python/vector_env.py:10(__len__)
#         1    0.000    0.000    0.000    0.000 /home/ubuntu/.pyenv/versions/3.8.2/envs/venv/lib/python3.8/site-packages/humanize/time.py:47(_abs_timedelta)
#         1    0.000    0.000    0.000    0.000 /home/ubuntu/.pyenv/versions/3.8.2/envs/venv/lib/python3.8/site-packages/torch/cuda/__init__.py:149(is_initialized)
#         1    0.000    0.000    0.000    0.000 /apps/open_spiel/open_spiel/python/examples/ppo_utils.py:247(add_eval_hook)
#         1    0.000    0.000    0.000    0.000 /apps/open_spiel/open_spiel/python/vector_env.py:39(<listcomp>)
#         1    0.000    0.000    0.000    0.000 /home/ubuntu/.pyenv/versions/3.8.2/envs/venv/lib/python3.8/site-packages/humanize/time.py:353(_suitable_minimum_unit)
#         1    0.000    0.000    0.000    0.000 {method 'upper' of 'str' objects}
#         1    0.000    0.000    0.000    0.000 /home/ubuntu/.pyenv/versions/3.8.2/envs/venv/lib/python3.8/site-packages/humanize/time.py:470(<listcomp>)
#         1    0.000    0.000    0.000    0.000 {method 'keys' of 'dict' objects}
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}

# %%
import pprofile
profiler = pprofile.Profile()
with profiler:
    prof_training()

# %%
profiler.print_stats()

# %%
profiler.dump_stats('ouptut_jan17.prof')

# %%
from collections import deque

# %%
x = deque([1,2,3], maxlen=5)

# %%
x[1]
