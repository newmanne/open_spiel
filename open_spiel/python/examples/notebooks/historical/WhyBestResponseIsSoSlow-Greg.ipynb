# %%
# %load_ext autoreload
# %autoreload 2
# %pylab inline

import sys
import glob
import pandas as pd
import os
import seaborn as sns
# from tqdm import tqdm_notebook as tqdm
from tqdm import tqdm
import pickle
from statsmodels.distributions.empirical_distribution import ECDF
from collections import defaultdict
import logging
from open_spiel.python.examples.ubc_mccfr_cpp_example import action_to_bids
from open_spiel.python.examples.ubc_nfsp_example import policy_from_checkpoint
from open_spiel.python.examples.ubc_br import BR_DIR, make_dqn_agent
from open_spiel.python.examples.ubc_utils import *
from open_spiel.python.examples.ubc_decorators import CachingAgentDecorator

from open_spiel.python.pytorch.ubc_nfsp import NFSP
import bokeh
from bokeh.plotting import figure, show
from bokeh.io import output_notebook
from bokeh.models import HoverTool, ColumnDataSource, ColorBar, LogColorMapper, LinearColorMapper
from bokeh.transform import linear_cmap, log_cmap

import yaml

output_notebook()
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# Populating the interactive namespace from numpy and matplotlib
# /apps/open_spiel/venv/lib/python3.6/site-packages/IPython/core/magics/pylab.py:160: UserWarning: pylab import has clobbered these variables: ['figure', 'random', 'logging', 'show', 'solve']
# `%matplotlib` prevents importing * from pylab and numpy
#   "\n`%matplotlib` prevents importing * from pylab and numpy"
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1003">Loading BokehJS ...</span>
#     </div>

# %%
# Why is best response not at least discovering that it can get 0 reward?

# %%
experiment_dir = '/shared/outputs/jan2_big_game_2/lstm_deep'
checkpoint_name = 'checkpoint_3000000'
br_player = 0
report_freq = 5_000

# %%
checkpoint_dir = os.path.join(experiment_dir, BR_DIR)
env_and_model = policy_from_checkpoint(experiment_dir, checkpoint_suffix=checkpoint_name)
game, policy, env, trained_agents, game_config = env_and_model.game, env_and_model.nfsp_policies, env_and_model.env, env_and_model.agents, env_and_model.game_config
config_path = f'{experiment_dir}/config.yml' 

with open(config_path, 'rb') as fh:
    config = yaml.load(fh, Loader=yaml.FullLoader)
    config['num_training_episodes'] = 500_000
num_training_episodes = config['num_training_episodes']

# %%
agents = []
for i in range(game.num_players()):
    if i == br_player:
        agents.append(make_dqn_agent(i, config, env, game, game_config))
    else:
        agent = trained_agents[i]
        agent = CachingAgentDecorator(agent)
        agents.append(agent)

logging.info(f"Training for {num_training_episodes} episodes")
# TRAINING PHASE

# %%
agents[0]

# %%
import torch

# %%
sum(list(map(lambda p: torch.prod(torch.tensor(p.shape)).item(), agents[0]._q_network.parameters())))
# Out:
# 79372

# %%
512*128
# Out:
# 65536

# %%
def check_on_q_values(agent, game):
    q_network = agent._q_network
    state = game.new_initial_state().child(1).child(0)
    legal_actions = state.legal_actions()
    it = state.information_state_tensor()
    info_state = q_network.prep_batch([q_network.reshape_infostate(it)])
    q_values = q_network(info_state).detach()[0]
    legal_q_values = q_values[legal_actions]
    legal_q_values = [agent.unmapRange(v) for v in legal_q_values]
    action_dict = get_actions(game)
    return {s: q for s,q in zip(action_dict.values(), legal_q_values)}

# %%
check_on_q_values(agents[br_player], game)
# Out:
# {'Bid for 0,0,0 licenses @ $0 with activity 0': tensor(-108.6960),
#  'Bid for 0,0,1 licenses @ $25 with activity 25': tensor(-102.2518),
#  'Bid for 0,1,0 licenses @ $50 with activity 50': tensor(-100.3396),
#  'Bid for 0,1,1 licenses @ $75 with activity 75': tensor(-87.1786),
#  'Bid for 1,0,0 licenses @ $75 with activity 75': tensor(-112.2526),
#  'Bid for 1,0,1 licenses @ $100 with activity 100': tensor(-147.0244),
#  'Bid for 1,1,0 licenses @ $125 with activity 125': tensor(-55.9490),
#  'Bid for 1,1,1 licenses @ $150 with activity 150': tensor(-53.2103),
#  'Bid for 2,0,0 licenses @ $150 with activity 150': tensor(-113.5410),
#  'Bid for 2,0,1 licenses @ $175 with activity 175': tensor(-100.8988),
#  'Bid for 2,1,0 licenses @ $200 with activity 200': tensor(-159.1750),
#  'Bid for 2,1,1 licenses @ $225 with activity 225': tensor(-96.9344)}

# %%
# fill buffer with some data with opponent dropping out
for action in range(12):
    for _ in range(10):
        time_step_1 = env.reset()
        env.step([action])
        time_step_2 = env.step([0])

        agents[br_player].add_transition(
            time_step_1, action, time_step_2
        )

# switch learning settings temporarily
min_buffer_size = agents[br_player]._min_buffer_size_to_learn
batch_size = agents[br_player]._batch_size
agents[br_player]._min_buffer_size_to_learn = 1
agents[br_player]._batch_size = 12

# train a bunch
for iteration in tqdm(range(3000)):
    agents[br_player].learn()
    
# change settings back
agents[br_player]._min_buffer_size_to_learn = min_buffer_size
agents[br_player]._batch_size = batch_size

# clear buffer
agents[br_player]._replay_buffer.clear()
# Out:
# 100%|██████████| 3000/3000 [00:09<00:00, 330.98it/s]

# %%
# for d in agents[br_player]._replay_buffer._data:
#     print(d.raw_reward)

# %%
len(agents[br_player]._replay_buffer._data)
# Out:
# 0

# %%
# agents[br_player]._min_buffer_size_to_learn = 1
# agents[br_player]._batch_size = 12
# for g in agents[br_player]._optimizer.param_groups:
#     g['lr'] = 1e-2

# %%
for iteration in range(1000):
    agents[br_player].learn()

# %%
check_on_q_values(agents[br_player], game)
# Out:
# {'Bid for 0,0,0 licenses @ $0 with activity 0': tensor(0.0282),
#  'Bid for 0,0,1 licenses @ $25 with activity 25': tensor(17.5503),
#  'Bid for 0,1,0 licenses @ $50 with activity 50': tensor(20.8990),
#  'Bid for 0,1,1 licenses @ $75 with activity 75': tensor(42.5817),
#  'Bid for 1,0,0 licenses @ $75 with activity 75': tensor(23.3687),
#  'Bid for 1,0,1 licenses @ $100 with activity 100': tensor(44.4017),
#  'Bid for 1,1,0 licenses @ $125 with activity 125': tensor(47.3201),
#  'Bid for 1,1,1 licenses @ $150 with activity 150': tensor(70.7930),
#  'Bid for 2,0,0 licenses @ $150 with activity 150': tensor(49.8554),
#  'Bid for 2,0,1 licenses @ $175 with activity 175': tensor(74.3150),
#  'Bid for 2,1,0 licenses @ $200 with activity 200': tensor(71.8852),
#  'Bid for 2,1,1 licenses @ $225 with activity 225': tensor(96.8533)}

# %%
# fill buffer with some data with opponent dropping out
for action in range(12):
    for _ in range(10):
        time_step_1 = env.reset()
        env.step([action])
        time_step_2 = env.step([0])

        agents[br_player].add_transition(
            time_step_1, action, time_step_2
        )

# switch learning settings temporarily
min_buffer_size = agents[br_player]._min_buffer_size_to_learn
batch_size = agents[br_player]._batch_size
agents[br_player]._min_buffer_size_to_learn = 1
agents[br_player]._batch_size = 12

# train a bunch
for iteration in tqdm(range(3000)):
    agents[br_player].learn()
    
# change settings back
agents[br_player]._min_buffer_size_to_learn = min_buffer_size
agents[br_player]._batch_size = batch_size

# clear buffer
agents[br_player]._replay_buffer.clear()
# Out:
# 100%|██████████| 3000/3000 [00:09<00:00, 332.14it/s]

# %%
agents[br_player]._min_buffer_size_to_learn
# Out:
# 5000

# %%
agents[br_player]._batch_size
# Out:
# 256

# %%
import pprofile
profiler = pprofile.Profile()
with profiler:
    for i in tqdm(range(5000)):
    #     if i % 1000 == 0:
    #         logging.info(f"----Episode {i} ---")
    #         if i > 1_000:
    #             loss = agents[br_player].loss
    #             logging.info(f"[P{br_player}] Loss: {loss}")
    #             print(check_on_q_values(agents[br_player], game))

        time_step = env.reset()

        while not time_step.last():
            player_id = time_step.observations["current_player"]
            agent = agents[player_id]
            agent_output = agent.step(time_step, is_evaluation=player_id != br_player)
            action_list = [agent_output.action]
            time_step = env.step(action_list)

        # Episode is over, step all agents with final info state.
        for player_id, agent in enumerate(agents):
            agent.step(time_step, is_evaluation=player_id != br_player)


# profiler.print_stats()
profiler.dump_stats("output/profile.txt")
# Out:
# 100%|██████████| 5000/5000 [01:20<00:00, 62.00it/s]

# %%
def sample_train():
    for i in tqdm(range(5000)):
    #     if i % 1000 == 0:
    #         logging.info(f"----Episode {i} ---")
    #         if i > 1_000:
    #             loss = agents[br_player].loss
    #             logging.info(f"[P{br_player}] Loss: {loss}")
    #             print(check_on_q_values(agents[br_player], game))

        time_step = env.reset()

        while not time_step.last():
            player_id = time_step.observations["current_player"]
            agent = agents[player_id]
            agent_output = agent.step(time_step, is_evaluation=player_id != br_player)
            action_list = [agent_output.action]
            time_step = env.step(action_list)

        # Episode is over, step all agents with final info state.
        for player_id, agent in enumerate(agents):
            agent.step(time_step, is_evaluation=player_id != br_player)

# %%
import cProfile
cProfile.run('sample_train()', sort='tottime')
# Out:
# 100%|██████████| 5000/5000 [01:13<00:00, 67.98it/s]
#          3044580 function calls (3039128 primitive calls) in 73.503 seconds
#
#    Ordered by: internal time
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#       305   27.685    0.091   27.685    0.091 {method 'run_backward' of 'torch._C._EngineBase' objects}
#     90238   10.568    0.000   10.568    0.000 {built-in method tensor}
#     30210    4.042    0.000    4.139    0.000 rl_environment.py:224(get_time_step)
#      2379    3.046    0.001    3.046    0.001 {built-in method lstm}
#     39893    2.788    0.000    4.102    0.000 __init__.py:91(__contains__)
#     90238    2.242    0.000    2.242    0.000 {method 'reshape' of 'torch._C._TensorBase' objects}
#     45119    2.156    0.000   16.512    0.000 ubc_rnn.py:55(reshape_infostate)
#         1    1.887    1.887   73.549   73.549 <ipython-input-345-73873dd4a314>:1(sample_train)
#      2379    1.827    0.001    2.133    0.001 ubc_rnn.py:114(<listcomp>)
#     20105    1.722    0.000   56.860    0.003 ubc_dqn.py:279(step)
#     81054    1.325    0.000    1.325    0.000 keys.py:16(__hash__)
#     20105    1.157    0.000    1.161    0.000 {method 'move_to_end' of 'collections.OrderedDict' objects}
#     19788    1.153    0.000    1.159    0.000 __init__.py:64(__getitem__)
#     26978    1.088    0.000    1.141    0.000 {method 'choice' of 'numpy.random.mtrand.RandomState' objects}
#      5000    1.011    0.000    1.656    0.000 rl_environment.py:325(reset)
#     15105    0.826    0.000   11.864    0.001 ubc_dqn.py:339(add_transition)
#       305    0.578    0.002   35.317    0.116 ubc_dqn.py:415(learn)
#     45119    0.530    0.000    0.530    0.000 {built-in method tile}
#      2379    0.435    0.000    0.435    0.000 {built-in method torch._C._nn.pad_sequence}
#     45119    0.431    0.000    0.431    0.000 {built-in method hstack}
#     60420    0.430    0.000    0.430    0.000 rl_environment.py:444(is_turn_based)
#     45119    0.392    0.000    0.392    0.000 {method 'sum' of 'torch._C._TensorBase' objects}
#     20105    0.390    0.000    7.439    0.000 ubc_decorators.py:44(step)
#      2684    0.349    0.000    0.349    0.000 {method 'unbind' of 'torch._C._TensorBase' objects}
#      9516    0.309    0.000    0.309    0.000 {method 'index_select' of 'torch._C._TensorBase' objects}
#     30210    0.308    0.000    5.287    0.000 rl_environment.py:283(step)
#      2379    0.307    0.000    0.307    0.000 {built-in method _pad_packed_sequence}
#    157929    0.306    0.000    0.306    0.000 {method 'unsqueeze' of 'torch._C._TensorBase' objects}
#     14737    0.254    0.000    2.033    0.000 ubc_dqn.py:378(_epsilon_greedy)
#     35210    0.240    0.000    1.009    0.000 rl_environment.py:370(_sample_external_events)
#     15105    0.231    0.000    0.231    0.000 ubc_dqn.py:189(mapRange)
#     45119    0.194    0.000    0.194    0.000 {built-in method permute}
#      3287    0.174    0.000    0.174    0.000 {method 'acquire' of '_thread.lock' objects}
#      2379    0.168    0.000    0.168    0.000 {built-in method cat}
#      5368    0.129    0.000    0.129    0.000 {built-in method zeros}
#    158234    0.122    0.000    0.193    0.000 _tensor.py:620(__len__)
#      2379    0.099    0.000    0.099    0.000 {built-in method torch._C._nn.linear}
#      2379    0.093    0.000    6.926    0.003 ubc_rnn.py:100(forward)
# 7137/2379    0.092    0.000    6.993    0.003 module.py:1096(_call_impl)
#     30382    0.090    0.000    0.090    0.000 {built-in method numpy.zeros}
#       172    0.088    0.001    0.437    0.003 ubc_nfsp.py:140(_act)
#      1471    0.080    0.000    0.080    0.000 socket.py:474(send)
#      2379    0.072    0.000    0.072    0.000 {built-in method _pack_padded_sequence}
#      2379    0.071    0.000    3.416    0.001 rnn.py:661(forward)
#      2379    0.069    0.000    0.577    0.000 rnn.py:253(pad_packed_sequence)
#     91159    0.066    0.000    0.066    0.000 rl_environment.py:92(last)
#     13361    0.064    0.000    0.769    0.000 rl_environment.py:133(__call__)
#      2379    0.063    0.000    0.063    0.000 {built-in method sort}
# 234777/234167    0.059    0.000    0.251    0.000 {built-in method builtins.len}
#      7137    0.057    0.000    0.125    0.000 rnn.py:156(_packed_sequence_init_args)
#    170434    0.053    0.000    0.053    0.000 {built-in method torch._C._get_tracing_state}
#       305    0.052    0.000    0.052    0.000 {built-in method numpy.array}
#     14737    0.051    0.000    0.068    0.000 ubc_dqn.py:405(_get_epsilon)
#       610    0.049    0.000    0.049    0.000 {built-in method rsub}
#     70372    0.048    0.000    0.048    0.000 {built-in method __new__ of type object at 0x9d12c0}
#       305    0.046    0.000    0.188    0.001 ubc_dqn.py:67(sample)
#     14737    0.043    0.000    0.043    0.000 {method 'rand' of 'numpy.random.mtrand.RandomState' objects}
#     35210    0.037    0.000    0.037    0.000 rl_environment.py:435(num_players)
#    300240    0.037    0.000    0.037    0.000 {method 'append' of 'list' objects}
#      2379    0.036    0.000    0.377    0.000 rnn.py:200(pack_padded_sequence)
#     20105    0.036    0.000    0.046    0.000 ubc_decorators.py:17(__getattr__)
#      2379    0.035    0.000    0.269    0.000 ubc_rnn.py:131(<listcomp>)
#     15105    0.033    0.000    0.033    0.000 rl_environment.py:95(is_simultaneous_move)
#      1830    0.033    0.000    0.033    0.000 {method 'add_' of 'torch._C._TensorBase' objects}
#     19788    0.032    0.000    3.508    0.000 __init__.py:208(__getitem__)
#     13705    0.031    0.000    0.039    0.000 getlimits.py:366(__new__)
#       305    0.026    0.000    0.026    0.000 ubc_dqn.py:435(<listcomp>)
#     15105    0.026    0.000    0.033    0.000 ubc_dqn.py:52(add)
#      4758    0.024    0.000    0.062    0.000 rnn.py:63(__new__)
#       305    0.023    0.000    0.023    0.000 ubc_dqn.py:433(<listcomp>)
#     30210    0.023    0.000    0.349    0.000 rl_environment.py:439(num_actions_per_step)
#       305    0.023    0.000    0.023    0.000 ubc_dqn.py:432(<listcomp>)
#      2379    0.022    0.000    0.022    0.000 {method 'scatter_' of 'torch._C._TensorBase' objects}
#      2684    0.022    0.000    0.022    0.000 {built-in method arange}
#     20105    0.022    0.000    1.183    0.000 __init__.py:231(__update)
#      2379    0.022    0.000    0.022    0.000 {built-in method as_tensor}
#      2379    0.022    0.000    1.111    0.000 ubc_rnn.py:121(pack_sequences)
#    163297    0.020    0.000    0.020    0.000 {method 'dim' of 'torch._C._TensorBase' objects}
#       305    0.020    0.000    0.020    0.000 ubc_dqn.py:436(<listcomp>)
#      9516    0.020    0.000    0.020    0.000 module.py:1164(__getattr__)
#       305    0.020    0.000    0.020    0.000 ubc_dqn.py:439(<listcomp>)
#     15105    0.018    0.000    0.249    0.000 ubc_dqn.py:333(mapRange)
#      1597    0.017    0.000    0.017    0.000 {built-in method argmax}
#     14738    0.017    0.000    0.017    0.000 {built-in method builtins.min}
#      1830    0.017    0.000    0.017    0.000 {method 'zero_' of 'torch._C._TensorBase' objects}
#       305    0.016    0.000    0.016    0.000 ubc_dqn.py:440(<listcomp>)
#     28007    0.016    0.000    0.016    0.000 {built-in method builtins.getattr}
#      5001    0.016    0.000    0.393    0.000 std.py:1159(__iter__)
#       305    0.016    0.000    0.016    0.000 ubc_dqn.py:437(<listcomp>)
#      2379    0.014    0.000    0.126    0.000 linear.py:102(forward)
#       366    0.014    0.000    0.038    0.000 std.py:355(format_meter)
#    173351    0.014    0.000    0.014    0.000 {built-in method torch._C._has_torch_function_unary}
#      2379    0.013    0.000    0.013    0.000 {built-in method empty_like}
#      2379    0.013    0.000    0.068    0.000 rnn.py:190(invert_permutation)
#      2684    0.013    0.000    0.370    0.000 _tensor.py:632(__iter__)
#      2379    0.013    0.000    0.013    0.000 rnn.py:209(get_expected_hidden_size)
#     20105    0.013    0.000    0.013    0.000 keys.py:37(hashkey)
#      2379    0.013    0.000    0.048    0.000 rnn.py:627(check_forward_args)
#      2505    0.012    0.000    0.012    0.000 {method 'detach' of 'torch._C._TensorBase' objects}
#       610    0.012    0.000    0.012    0.000 {built-in method torch._ops.profiler._record_function_enter}
#       305    0.011    0.000    0.055    0.000 sgd.py:102(step)
#     15277    0.011    0.000    0.019    0.000 <string>:12(__new__)
#       305    0.010    0.000    0.010    0.000 {built-in method torch._C._nn.mse_loss}
#       305    0.010    0.000    0.010    0.000 {built-in method max}
#      7442    0.010    0.000    0.015    0.000 _VF.py:25(__getattr__)
#     10126    0.010    0.000    0.010    0.000 {method 'size' of 'torch._C._TensorBase' objects}
#      3230    0.009    0.000    0.012    0.000 {method 'format' of 'str' objects}
#       305    0.009    0.000    0.044    0.000 optimizer.py:189(zero_grad)
#      2379    0.009    0.000    0.125    0.000 rnn.py:183(_packed_sequence_init)
#       305    0.008    0.000    0.094    0.000 optimizer.py:83(wrapper)
#      2379    0.008    0.000    0.008    0.000 {method 'to' of 'torch._C._TensorBase' objects}
#      2379    0.008    0.000    0.443    0.000 rnn.py:323(pad_sequence)
#     13768    0.008    0.000    0.008    0.000 {method 'get' of 'dict' objects}
#     10980    0.008    0.000    0.009    0.000 _tensor.py:1001(grad)
#      2379    0.007    0.000    0.109    0.000 functional.py:1832(linear)
#      2379    0.007    0.000    0.007    0.000 rnn.py:615(get_expected_cell_size)
#      2379    0.007    0.000    1.118    0.000 ubc_rnn.py:86(prep_batch)
#       305    0.006    0.000    0.006    0.000 {built-in method stack}
#       364    0.006    0.000    0.375    0.001 std.py:1197(update)
#      1471    0.006    0.000    0.094    0.000 iostream.py:195(schedule)
#     18957    0.006    0.000    0.009    0.000 utils.py:330(<genexpr>)
#      2379    0.006    0.000    0.080    0.000 rnn.py:639(permute_hidden)
#       305    0.006    0.000    0.006    0.000 {method 'reduce' of 'numpy.ufunc' objects}
#      4758    0.005    0.000    0.074    0.000 rnn.py:20(apply_permutation)
#       538    0.005    0.000    0.014    0.000 {built-in method builtins.sum}
#      2379    0.005    0.000    0.009    0.000 rnn.py:198(check_input)
#      5000    0.004    0.000    0.004    0.000 rl_environment.py:259(<listcomp>)
#       610    0.004    0.000    0.016    0.000 profiler.py:434(__enter__)
#      2185    0.004    0.000    0.004    0.000 std.py:233(__call__)
#       368    0.004    0.000    0.052    0.000 iostream.py:384(write)
#     15105    0.004    0.000    0.004    0.000 rl_environment.py:98(current_player)
#       365    0.004    0.000    0.004    0.000 {built-in method now}
#       305    0.004    0.000   27.696    0.091 __init__.py:69(backward)
#       368    0.004    0.000    0.239    0.001 iostream.py:335(flush)
#      4758    0.004    0.000    0.007    0.000 rnn.py:223(check_hidden_size)
#     18591    0.004    0.000    0.004    0.000 {built-in method unicodedata.east_asian_width}
#       317    0.004    0.000    0.510    0.002 ubc_nfsp.py:162(step)
#      6900    0.003    0.000    0.003    0.000 {built-in method builtins.isinstance}
#       305    0.003    0.000    0.036    0.000 _functional.py:146(sgd)
#      1839    0.003    0.000    0.006    0.000 threading.py:1104(is_alive)
#       368    0.003    0.000    0.003    0.000 threading.py:215(__init__)
#       366    0.003    0.000    0.004    0.000 std.py:1445(format_dict)
#       732    0.003    0.000    0.004    0.000 utils.py:222(_is_ascii)
#       610    0.003    0.000    0.003    0.000 {built-in method torch._ops.profiler._record_function_exit}
#       305    0.003    0.000    0.065    0.000 grad_mode.py:25(decorate_context)
#       362    0.003    0.000    0.177    0.000 threading.py:263(wait)
#       431    0.003    0.000    0.003    0.000 grad_mode.py:119(__init__)
#       366    0.003    0.000    0.359    0.001 std.py:1463(display)
#       305    0.003    0.000    0.018    0.000 functional.py:3084(mse_loss)
#      3294    0.003    0.000    0.003    0.000 {built-in method torch._C._has_torch_function_variadic}
#       305    0.003    0.000    0.006    0.000 __init__.py:29(_make_grads)
#       317    0.003    0.000    0.003    0.000 __init__.py:70(__setitem__)
#       365    0.003    0.000    0.366    0.001 std.py:1324(refresh)
#       305    0.003    0.000    0.009    0.000 fromnumeric.py:70(_wrapreduction)
#       305    0.003    0.000    0.003    0.000 {built-in method ones_like}
#       305    0.003    0.000   27.698    0.091 _tensor.py:251(backward)
#       610    0.002    0.000    0.010    0.000 profiler.py:426(__init__)
#       368    0.002    0.000    0.180    0.000 threading.py:533(wait)
#       731    0.002    0.000    0.005    0.000 std.py:288(format_interval)
#      3660    0.002    0.000    0.003    0.000 _tensor.py:650(__hash__)
#       366    0.002    0.000    0.044    0.000 std.py:1149(__str__)
#       734    0.002    0.000    0.292    0.000 utils.py:143(inner)
#       305    0.002    0.000    0.004    0.000 functional.py:43(broadcast_tensors)
#       172    0.002    0.000    0.002    0.000 {method 'softmax' of 'torch._C._TensorBase' objects}
#       366    0.002    0.000    0.002    0.000 std.py:188(__format__)
#       369    0.002    0.000    0.003    0.000 std.py:104(acquire)
#       366    0.002    0.000    0.311    0.001 std.py:348(print_status)
#       366    0.002    0.000    0.294    0.001 std.py:342(fp_write)
#       610    0.002    0.000    0.053    0.000 _tensor.py:25(wrapped)
#       126    0.002    0.000    0.002    0.000 {method 'copy_' of 'torch._C._TensorBase' objects}
#       431    0.002    0.000    0.003    0.000 grad_mode.py:124(__enter__)
#       862    0.002    0.000    0.002    0.000 grad_mode.py:213(__init__)
#       610    0.002    0.000    0.051    0.000 _tensor.py:544(__rsub__)
#      2684    0.002    0.000    0.002    0.000 {method 'numel' of 'torch._C._TensorBase' objects}
#        63    0.002    0.000    0.005    0.000 module.py:1338(_load_from_state_dict)
#      2684    0.002    0.000    0.002    0.000 {built-in method builtins.iter}
#      1471    0.001    0.000    0.001    0.000 iostream.py:91(_event_pipe)
#       610    0.001    0.000    0.005    0.000 profiler.py:438(__exit__)
#       305    0.001    0.000    0.011    0.000 fromnumeric.py:2881(prod)
#       369    0.001    0.000    0.002    0.000 std.py:108(release)
#       305    0.001    0.000    0.001    0.000 {built-in method broadcast_tensors}
#       366    0.001    0.000    0.002    0.000 std.py:155(__init__)
#       368    0.001    0.000    0.005    0.000 threading.py:498(__init__)
#       366    0.001    0.000    0.001    0.000 {method 'sub' of '_sre.SRE_Pattern' objects}
#      1839    0.001    0.000    0.003    0.000 threading.py:1062(_wait_for_tstate_lock)
#       305    0.001    0.000    0.013    0.000 <__array_function__ internals>:2(prod)
#       369    0.001    0.000    0.001    0.000 {method 'acquire' of '_multiprocessing.SemLock' objects}
#      2299    0.001    0.000    0.001    0.000 {built-in method time.time}
#      7686    0.001    0.000    0.001    0.000 {built-in method builtins.ord}
#       368    0.001    0.000    0.001    0.000 {built-in method posix.getpid}
#       368    0.001    0.000    0.002    0.000 iostream.py:308(_is_master_process)
#       368    0.001    0.000    0.002    0.000 ubc_utils.py:28(single_action_result)
#       366    0.001    0.000    0.015    0.000 utils.py:333(disp_len)
#       366    0.001    0.000    0.013    0.000 utils.py:329(_text_width)
#      1044    0.001    0.000    0.001    0.000 {built-in method builtins.hasattr}
#      1830    0.001    0.000    0.001    0.000 {method 'requires_grad_' of 'torch._C._TensorBase' objects}
#       368    0.001    0.000    0.017    0.000 iostream.py:321(_schedule_flush)
#      3662    0.001    0.000    0.001    0.000 {built-in method builtins.id}
#       305    0.001    0.000    0.011    0.000 {built-in method numpy.core._multiarray_umath.implement_array_function}
#       344    0.001    0.000    0.001    0.000 numerictypes.py:286(issubclass_)
#      1828    0.001    0.000    0.001    0.000 {built-in method builtins.divmod}
#       172    0.001    0.000    0.002    0.000 numerictypes.py:360(issubdtype)
#       172    0.001    0.000    0.001    0.000 {method 'numpy' of 'torch._C._TensorBase' objects}
#       431    0.001    0.000    0.001    0.000 grad_mode.py:128(__exit__)
#       317    0.001    0.000    0.006    0.000 __init__.py:214(__setitem__)
#       730    0.001    0.000    0.001    0.000 {built-in method _thread.allocate_lock}
#      1840    0.001    0.000    0.001    0.000 threading.py:506(is_set)
#      1293    0.000    0.000    0.000    0.000 {built-in method torch._C.is_grad_enabled}
#       305    0.000    0.000    0.000    0.000 fromnumeric.py:71(<dictcomp>)
#       610    0.000    0.000    0.001    0.000 ubc_dqn.py:90(__len__)
#       362    0.000    0.000    0.001    0.000 threading.py:251(_acquire_restore)
#      1833    0.000    0.000    0.000    0.000 {method 'append' of 'collections.deque' objects}
#       368    0.000    0.000    0.001    0.000 threading.py:239(__enter__)
#       172    0.000    0.000    0.002    0.000 functional.py:1650(softmax)
#       305    0.000    0.000    0.000    0.000 _reduction.py:7(get_enum)
#       305    0.000    0.000    0.000    0.000 __init__.py:61(_tensor_or_tensors_to_tuple)
#       366    0.000    0.000    0.000    0.000 utils.py:57(__init__)
#        63    0.000    0.000    0.001    0.000 module.py:1249(_save_to_state_dict)
#     63/21    0.000    0.000    0.001    0.000 module.py:1286(state_dict)
#       516    0.000    0.000    0.000    0.000 {built-in method builtins.issubclass}
#       369    0.000    0.000    0.000    0.000 {method 'acquire' of '_thread.RLock' objects}
#       915    0.000    0.000    0.000    0.000 {built-in method torch._C._has_torch_function}
#       362    0.000    0.000    0.001    0.000 threading.py:254(_is_owned)
#       369    0.000    0.000    0.000    0.000 {method 'release' of '_multiprocessing.SemLock' objects}
#       369    0.000    0.000    0.000    0.000 {method 'release' of '_thread.RLock' objects}
#       368    0.000    0.000    0.000    0.000 threading.py:242(__exit__)
#       366    0.000    0.000    0.000    0.000 {built-in method builtins.max}
#       366    0.000    0.000    0.000    0.000 std.py:169(colour)
#       362    0.000    0.000    0.000    0.000 threading.py:248(_release_save)
#       862    0.000    0.000    0.000    0.000 {built-in method torch._C._set_grad_enabled}
#       366    0.000    0.000    0.000    0.000 {method 'update' of 'dict' objects}
#     63/21    0.000    0.000    0.005    0.000 module.py:1460(load)
#       366    0.000    0.000    0.000    0.000 utils.py:61(__format__)
#       431    0.000    0.000    0.000    0.000 _jit_internal.py:957(is_scripting)
#       368    0.000    0.000    0.000    0.000 {built-in method _imp.lock_held}
#       431    0.000    0.000    0.000    0.000 {method 'items' of 'dict' objects}
#       317    0.000    0.000    0.000    0.000 __init__.py:33(__setitem__)
#       368    0.000    0.000    0.000    0.000 {method '__enter__' of '_thread.lock' objects}
#       317    0.000    0.000    0.000    0.000 ubc_decorators.py:30(agent)
#        21    0.000    0.000    0.005    0.000 module.py:1425(load_state_dict)
#       362    0.000    0.000    0.000    0.000 {method 'release' of '_thread.lock' objects}
#       366    0.000    0.000    0.000    0.000 std.py:165(colour)
#       368    0.000    0.000    0.000    0.000 {built-in method builtins.abs}
#        63    0.000    0.000    0.000    0.000 module.py:1376(<dictcomp>)
#       305    0.000    0.000    0.000    0.000 fromnumeric.py:2876(_prod_dispatcher)
#       252    0.000    0.000    0.000    0.000 {method 'split' of 'str' objects}
#       317    0.000    0.000    0.000    0.000 __init__.py:136(getsizeof)
#       378    0.000    0.000    0.000    0.000 {method 'startswith' of 'str' objects}
#       368    0.000    0.000    0.000    0.000 {method '__exit__' of '_thread.lock' objects}
#         1    0.000    0.000   73.549   73.549 <string>:1(<module>)
#       126    0.000    0.000    0.000    0.000 parameter.py:129(is_lazy)
#       378    0.000    0.000    0.000    0.000 {method 'items' of 'collections.OrderedDict' objects}
#         1    0.000    0.000    0.002    0.002 std.py:846(__init__)
#        21    0.000    0.000    0.000    0.000 {method 'copy' of 'collections.OrderedDict' objects}
#       126    0.000    0.000    0.000    0.000 {method 'values' of 'collections.OrderedDict' objects}
#        63    0.000    0.000    0.000    0.000 module.py:1374(<dictcomp>)
#         1    0.000    0.000    0.000    0.000 std.py:560(__new__)
#         2    0.000    0.000    0.001    0.001 std.py:1264(close)
#         1    0.000    0.000    0.000    0.000 std.py:583(_decr_instances)
#         1    0.000    0.000    0.000    0.000 utils.py:282(_screen_shape_linux)
#         1    0.000    0.000   73.549   73.549 {built-in method builtins.exec}
#         3    0.000    0.000    0.000    0.000 _weakrefset.py:58(__iter__)
#        63    0.000    0.000    0.000    0.000 {method 'keys' of 'collections.OrderedDict' objects}
#         1    0.000    0.000    0.001    0.001 std.py:329(status_printer)
#         1    0.000    0.000    0.000    0.000 std.py:576(_get_free_pos)
#         2    0.000    0.000    0.000    0.000 std.py:1285(fp_write)
#         4    0.000    0.000    0.000    0.000 std.py:112(__enter__)
#         1    0.000    0.000    0.000    0.000 utils.py:162(__init__)
#         1    0.000    0.000    0.000    0.000 {built-in method fcntl.ioctl}
#         1    0.000    0.000    0.000    0.000 os.py:664(__getitem__)
#         1    0.000    0.000    0.000    0.000 _weakrefset.py:81(add)
#         4    0.000    0.000    0.000    0.000 std.py:115(__exit__)
#         2    0.000    0.000    0.000    0.000 _weakrefset.py:26(__exit__)
#         3    0.000    0.000    0.000    0.000 {method 'remove' of 'set' objects}
#         3    0.000    0.000    0.000    0.000 utils.py:101(wrapper_setattr)
#         3    0.000    0.000    0.000    0.000 {method 'add' of 'set' objects}
#         2    0.000    0.000    0.000    0.000 utils.py:171(__eq__)
#         1    0.000    0.000    0.000    0.000 utils.py:296(<listcomp>)
#         1    0.000    0.000    0.000    0.000 os.py:742(encode)
#         2    0.000    0.000    0.000    0.000 {method 'encode' of 'str' objects}
#         1    0.000    0.000    0.000    0.000 {built-in method utcfromtimestamp}
#         1    0.000    0.000    0.000    0.000 _monitor.py:94(report)
#         2    0.000    0.000    0.000    0.000 std.py:1156(__hash__)
#         1    0.000    0.000    0.000    0.000 utils.py:74(__eq__)
#         2    0.000    0.000    0.000    0.000 utils.py:136(disable_on_exception)
#         1    0.000    0.000    0.000    0.000 utils.py:215(_supports_unicode)
#         1    0.000    0.000    0.000    0.000 _weakrefset.py:106(remove)
#         2    0.000    0.000    0.000    0.000 {built-in method _weakref.proxy}
#         3    0.000    0.000    0.000    0.000 std.py:228(__init__)
#         1    0.000    0.000    0.000    0.000 std.py:579(<setcomp>)
#         1    0.000    0.000    0.000    0.000 std.py:657(get_lock)
#         1    0.000    0.000    0.000    0.000 std.py:1146(__del__)
#         2    0.000    0.000    0.000    0.000 _weakrefset.py:16(__init__)
#         2    0.000    0.000    0.000    0.000 _weakrefset.py:20(__enter__)
#         2    0.000    0.000    0.000    0.000 _weakrefset.py:52(_commit_removals)
#         3    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:997(_handle_fromlist)
#         1    0.000    0.000    0.000    0.000 {method 'difference' of 'set' objects}
#         2    0.000    0.000    0.000    0.000 std.py:1152(_comparable)
#         2    0.000    0.000    0.000    0.000 utils.py:88(__getattr__)
#         1    0.000    0.000    0.000    0.000 utils.py:105(__init__)
#         1    0.000    0.000    0.000    0.000 utils.py:231(_screen_shape_wrapper)
#         1    0.000    0.000    0.000    0.000 std.py:1300(<lambda>)
#         1    0.000    0.000    0.000    0.000 utils.py:201(_is_utf)
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}

# %%
import cProfile
cProfile.run('sample_train()', sort='cumtime')
# Out:
# 100%|██████████| 5000/5000 [01:17<00:00, 64.88it/s]
#          3162017 function calls (3156157 primitive calls) in 77.019 seconds
#
#    Ordered by: cumulative time
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.000    0.000   77.068   77.068 {built-in method builtins.exec}
#         1    0.000    0.000   77.068   77.068 <string>:1(<module>)
#         1    1.895    1.895   77.068   77.068 <ipython-input-345-73873dd4a314>:1(sample_train)
#     20297    1.747    0.000   60.482    0.003 ubc_dqn.py:279(step)
#       329    0.660    0.002   38.624    0.117 ubc_dqn.py:415(learn)
#       329    0.003    0.000   30.326    0.092 _tensor.py:251(backward)
#       329    0.004    0.000   30.323    0.092 __init__.py:69(backward)
#       329   30.312    0.092   30.312    0.092 {method 'run_backward' of 'torch._C._EngineBase' objects}
#     45651    2.150    0.000   16.567    0.000 ubc_rnn.py:55(reshape_infostate)
#     15297    0.828    0.000   11.919    0.001 ubc_dqn.py:339(add_transition)
#     91302   10.607    0.000   10.607    0.000 {built-in method tensor}
# 7695/2565    0.100    0.000    7.400    0.003 module.py:1096(_call_impl)
#      2565    0.100    0.000    7.327    0.003 ubc_rnn.py:100(forward)
#     20297    0.378    0.000    7.303    0.000 ubc_decorators.py:44(step)
#     30594    0.317    0.000    5.307    0.000 rl_environment.py:283(step)
#     40378    2.828    0.000    4.158    0.000 __init__.py:91(__contains__)
#     30594    4.047    0.000    4.145    0.000 rl_environment.py:224(get_time_step)
#      2565    0.077    0.000    3.620    0.001 rnn.py:661(forward)
#     20081    0.033    0.000    3.537    0.000 __init__.py:208(__getitem__)
#      2565    3.216    0.001    3.216    0.001 {built-in method lstm}
#      2565    1.983    0.001    2.315    0.001 ubc_rnn.py:114(<listcomp>)
#     91302    2.256    0.000    2.256    0.000 {method 'reshape' of 'torch._C._TensorBase' objects}
#     14948    0.275    0.000    2.232    0.000 ubc_dqn.py:378(_epsilon_greedy)
#      5000    1.001    0.000    1.643    0.000 rl_environment.py:325(reset)
#     81620    1.340    0.000    1.340    0.000 keys.py:16(__hash__)
#     26924    1.170    0.000    1.224    0.000 {method 'choice' of 'numpy.random.mtrand.RandomState' objects}
#      2565    0.008    0.000    1.217    0.000 ubc_rnn.py:86(prep_batch)
#      2565    0.025    0.000    1.209    0.000 ubc_rnn.py:121(pack_sequences)
#     20297    0.022    0.000    1.192    0.000 __init__.py:231(__update)
#     20297    1.166    0.000    1.170    0.000 {method 'move_to_end' of 'collections.OrderedDict' objects}
#     20081    1.162    0.000    1.167    0.000 __init__.py:64(__getitem__)
#     35594    0.240    0.000    1.005    0.000 rl_environment.py:370(_sample_external_events)
#     13336    0.063    0.000    0.765    0.000 rl_environment.py:133(__call__)
#      2565    0.074    0.000    0.673    0.000 rnn.py:253(pad_packed_sequence)
#     45651    0.529    0.000    0.529    0.000 {built-in method tile}
#      2565    0.008    0.000    0.487    0.000 rnn.py:323(pad_sequence)
#      2565    0.478    0.000    0.478    0.000 {built-in method torch._C._nn.pad_sequence}
#     61188    0.436    0.000    0.436    0.000 rl_environment.py:444(is_turn_based)
#     45651    0.432    0.000    0.432    0.000 {built-in method hstack}
#      5001    0.015    0.000    0.410    0.000 std.py:1159(__iter__)
#      2565    0.039    0.000    0.406    0.000 rnn.py:200(pack_padded_sequence)
#     45651    0.395    0.000    0.395    0.000 {method 'sum' of 'torch._C._TensorBase' objects}
#       367    0.006    0.000    0.393    0.001 std.py:1197(update)
#     10260    0.386    0.000    0.386    0.000 {method 'index_select' of 'torch._C._TensorBase' objects}
#       368    0.003    0.000    0.384    0.001 std.py:1324(refresh)
#       369    0.003    0.000    0.376    0.001 std.py:1463(display)
#     30594    0.023    0.000    0.355    0.000 rl_environment.py:439(num_actions_per_step)
#    170355    0.332    0.000    0.332    0.000 {method 'unsqueeze' of 'torch._C._TensorBase' objects}
#       369    0.002    0.000    0.328    0.001 std.py:348(print_status)
#      2565    0.325    0.000    0.325    0.000 {built-in method _pad_packed_sequence}
#       216    0.002    0.000    0.312    0.001 ubc_nfsp.py:162(step)
#       369    0.002    0.000    0.311    0.001 std.py:342(fp_write)
#       740    0.002    0.000    0.309    0.000 utils.py:143(inner)
#      2565    0.038    0.000    0.291    0.000 ubc_rnn.py:131(<listcomp>)
#       329    0.051    0.000    0.288    0.001 ubc_dqn.py:67(sample)
#       109    0.056    0.001    0.270    0.002 ubc_nfsp.py:140(_act)
# 247963/247305    0.062    0.000    0.270    0.000 {built-in method builtins.len}
#      2894    0.014    0.000    0.251    0.000 _tensor.py:632(__iter__)
#     15297    0.018    0.000    0.251    0.000 ubc_dqn.py:333(mapRange)
#       371    0.004    0.000    0.251    0.001 iostream.py:335(flush)
#     15297    0.233    0.000    0.233    0.000 ubc_dqn.py:189(mapRange)
#      2894    0.229    0.000    0.229    0.000 {method 'unbind' of 'torch._C._TensorBase' objects}
#    170684    0.132    0.000    0.209    0.000 _tensor.py:620(__len__)
#       371    0.003    0.000    0.204    0.001 threading.py:533(wait)
#       368    0.003    0.000    0.200    0.001 threading.py:263(wait)
#     45651    0.199    0.000    0.199    0.000 {built-in method permute}
#      3326    0.197    0.000    0.197    0.000 {method 'acquire' of '_thread.lock' objects}
#      2565    0.186    0.000    0.186    0.000 {built-in method cat}
#      5788    0.147    0.000    0.147    0.000 {built-in method zeros}
#      2565    0.015    0.000    0.137    0.000 linear.py:102(forward)
#      7695    0.062    0.000    0.135    0.000 rnn.py:156(_packed_sequence_init_args)
#      2565    0.009    0.000    0.134    0.000 rnn.py:183(_packed_sequence_init)
#      2565    0.008    0.000    0.118    0.000 functional.py:1832(linear)
#      2565    0.107    0.000    0.107    0.000 {built-in method torch._C._nn.linear}
#       329    0.009    0.000    0.100    0.000 optimizer.py:83(wrapper)
#     30703    0.092    0.000    0.092    0.000 {built-in method numpy.zeros}
#      1483    0.006    0.000    0.086    0.000 iostream.py:195(schedule)
#      2565    0.006    0.000    0.083    0.000 rnn.py:639(permute_hidden)
#      2565    0.077    0.000    0.077    0.000 {built-in method _pack_padded_sequence}
#      5130    0.006    0.000    0.077    0.000 rnn.py:20(apply_permutation)
#      1483    0.073    0.000    0.073    0.000 socket.py:474(send)
#      2565    0.014    0.000    0.073    0.000 rnn.py:190(invert_permutation)
#     14948    0.053    0.000    0.069    0.000 ubc_dqn.py:405(_get_epsilon)
#       329    0.003    0.000    0.069    0.000 grad_mode.py:25(decorate_context)
#      5130    0.028    0.000    0.068    0.000 rnn.py:63(__new__)
#      2565    0.068    0.000    0.068    0.000 {built-in method sort}
#     91917    0.065    0.000    0.065    0.000 rl_environment.py:92(last)
#       658    0.002    0.000    0.061    0.000 _tensor.py:25(wrapped)
#       658    0.002    0.000    0.059    0.000 _tensor.py:544(__rsub__)
#       329    0.012    0.000    0.058    0.000 sgd.py:102(step)
#       329    0.057    0.000    0.057    0.000 {built-in method numpy.array}
#       371    0.004    0.000    0.057    0.000 iostream.py:384(write)
#       658    0.057    0.000    0.057    0.000 {built-in method rsub}
#    183838    0.056    0.000    0.056    0.000 {built-in method torch._C._get_tracing_state}
#      2565    0.013    0.000    0.050    0.000 rnn.py:627(check_forward_args)
#     71446    0.048    0.000    0.048    0.000 {built-in method __new__ of type object at 0x9d12c0}
#       329    0.010    0.000    0.047    0.000 optimizer.py:189(zero_grad)
#     20297    0.035    0.000    0.047    0.000 ubc_decorators.py:17(__getattr__)
#       369    0.002    0.000    0.044    0.000 std.py:1149(__str__)
#     14948    0.042    0.000    0.042    0.000 {method 'rand' of 'numpy.random.mtrand.RandomState' objects}
#     13554    0.031    0.000    0.039    0.000 getlimits.py:366(__new__)
#       369    0.014    0.000    0.038    0.000 std.py:355(format_meter)
#       329    0.004    0.000    0.037    0.000 _functional.py:146(sgd)
#    309336    0.037    0.000    0.037    0.000 {method 'append' of 'list' objects}
#     35594    0.037    0.000    0.037    0.000 rl_environment.py:435(num_players)
#     15297    0.027    0.000    0.034    0.000 ubc_dqn.py:52(add)
#      1974    0.034    0.000    0.034    0.000 {method 'add_' of 'torch._C._TensorBase' objects}
#     15297    0.033    0.000    0.033    0.000 rl_environment.py:95(is_simultaneous_move)
#       329    0.029    0.000    0.029    0.000 ubc_dqn.py:435(<listcomp>)
#       329    0.025    0.000    0.025    0.000 ubc_dqn.py:433(<listcomp>)
#       329    0.025    0.000    0.025    0.000 ubc_dqn.py:432(<listcomp>)
#      2565    0.024    0.000    0.024    0.000 {method 'scatter_' of 'torch._C._TensorBase' objects}
#      2894    0.024    0.000    0.024    0.000 {built-in method arange}
#      2565    0.024    0.000    0.024    0.000 {built-in method as_tensor}
#    176143    0.022    0.000    0.022    0.000 {method 'dim' of 'torch._C._TensorBase' objects}
#       371    0.001    0.000    0.022    0.000 iostream.py:321(_schedule_flush)
#       329    0.022    0.000    0.022    0.000 ubc_dqn.py:436(<listcomp>)
#       329    0.021    0.000    0.021    0.000 ubc_dqn.py:439(<listcomp>)
#     10260    0.021    0.000    0.021    0.000 module.py:1164(__getattr__)
#       329    0.003    0.000    0.020    0.000 functional.py:3084(mse_loss)
#      1798    0.020    0.000    0.020    0.000 {built-in method argmax}
#     15406    0.011    0.000    0.019    0.000 <string>:12(__new__)
#       329    0.018    0.000    0.018    0.000 ubc_dqn.py:437(<listcomp>)
#      1974    0.018    0.000    0.018    0.000 {method 'zero_' of 'torch._C._TensorBase' objects}
#       329    0.018    0.000    0.018    0.000 ubc_dqn.py:440(<listcomp>)
#     28784    0.017    0.000    0.017    0.000 {built-in method builtins.getattr}
#       658    0.004    0.000    0.017    0.000 profiler.py:434(__enter__)
#     14949    0.017    0.000    0.017    0.000 {built-in method builtins.min}
#      8024    0.011    0.000    0.016    0.000 _VF.py:25(__getattr__)
#       369    0.001    0.000    0.015    0.000 utils.py:333(disp_len)
#    186914    0.015    0.000    0.015    0.000 {built-in method torch._C._has_torch_function_unary}
#       329    0.001    0.000    0.014    0.000 <__array_function__ internals>:2(prod)
#      2565    0.014    0.000    0.014    0.000 {built-in method empty_like}
#       478    0.004    0.000    0.014    0.000 {built-in method builtins.sum}
#      2673    0.013    0.000    0.013    0.000 {method 'detach' of 'torch._C._TensorBase' objects}
#       369    0.001    0.000    0.013    0.000 utils.py:329(_text_width)
#     20297    0.013    0.000    0.013    0.000 keys.py:37(hashkey)
#       658    0.013    0.000    0.013    0.000 {built-in method torch._ops.profiler._record_function_enter}
#      2565    0.013    0.000    0.013    0.000 rnn.py:209(get_expected_hidden_size)
#       329    0.001    0.000    0.013    0.000 {built-in method numpy.core._multiarray_umath.implement_array_function}
#      3278    0.010    0.000    0.012    0.000 {method 'format' of 'str' objects}
#       329    0.002    0.000    0.012    0.000 fromnumeric.py:2881(prod)
#       329    0.011    0.000    0.011    0.000 {built-in method torch._C._nn.mse_loss}
#       329    0.011    0.000    0.011    0.000 {built-in method max}
#       658    0.003    0.000    0.011    0.000 profiler.py:426(__init__)
#     10918    0.010    0.000    0.010    0.000 {method 'size' of 'torch._C._TensorBase' objects}
#       329    0.003    0.000    0.010    0.000 fromnumeric.py:70(_wrapreduction)
#     19113    0.006    0.000    0.010    0.000 utils.py:330(<genexpr>)
#      2565    0.005    0.000    0.010    0.000 rnn.py:198(check_input)
#     11844    0.008    0.000    0.009    0.000 _tensor.py:1001(grad)
#      2565    0.008    0.000    0.008    0.000 {method 'to' of 'torch._C._TensorBase' objects}
#      2565    0.008    0.000    0.008    0.000 rnn.py:615(get_expected_cell_size)
#     13608    0.007    0.000    0.007    0.000 {method 'get' of 'dict' objects}
#      5130    0.004    0.000    0.007    0.000 rnn.py:223(check_hidden_size)
#       329    0.007    0.000    0.007    0.000 {built-in method stack}
#      1854    0.003    0.000    0.007    0.000 threading.py:1104(is_alive)
#       329    0.003    0.000    0.006    0.000 __init__.py:29(_make_grads)
#       329    0.006    0.000    0.006    0.000 {method 'reduce' of 'numpy.ufunc' objects}
#       371    0.001    0.000    0.005    0.000 threading.py:498(__init__)
#       658    0.002    0.000    0.005    0.000 profiler.py:438(__exit__)
#       737    0.002    0.000    0.005    0.000 std.py:288(format_interval)
#       329    0.002    0.000    0.005    0.000 functional.py:43(broadcast_tensors)
#       738    0.003    0.000    0.005    0.000 utils.py:222(_is_ascii)
#        18    0.000    0.000    0.005    0.000 module.py:1425(load_state_dict)
#      5000    0.004    0.000    0.004    0.000 rl_environment.py:259(<listcomp>)
#     54/18    0.000    0.000    0.004    0.000 module.py:1460(load)
#      2203    0.004    0.000    0.004    0.000 std.py:233(__call__)
#        54    0.001    0.000    0.004    0.000 module.py:1338(_load_from_state_dict)
#     15297    0.004    0.000    0.004    0.000 rl_environment.py:98(current_player)
#     18744    0.004    0.000    0.004    0.000 {built-in method unicodedata.east_asian_width}
#       369    0.003    0.000    0.004    0.000 std.py:1445(format_dict)
#       368    0.004    0.000    0.004    0.000 {built-in method now}
#      3948    0.003    0.000    0.004    0.000 _tensor.py:650(__hash__)
#       216    0.000    0.000    0.004    0.000 __init__.py:214(__setitem__)
#       437    0.002    0.000    0.004    0.000 grad_mode.py:124(__enter__)
#      7335    0.004    0.000    0.004    0.000 {built-in method builtins.isinstance}
#       372    0.002    0.000    0.003    0.000 std.py:104(acquire)
#       437    0.003    0.000    0.003    0.000 grad_mode.py:119(__init__)
#       658    0.003    0.000    0.003    0.000 {built-in method torch._ops.profiler._record_function_exit}
#       371    0.003    0.000    0.003    0.000 threading.py:215(__init__)
#      3552    0.003    0.000    0.003    0.000 {built-in method torch._C._has_torch_function_variadic}
#       329    0.003    0.000    0.003    0.000 {built-in method ones_like}
#      1854    0.001    0.000    0.003    0.000 threading.py:1062(_wait_for_tstate_lock)
#       369    0.002    0.000    0.002    0.000 std.py:188(__format__)
#       874    0.002    0.000    0.002    0.000 grad_mode.py:213(__init__)
#       371    0.001    0.000    0.002    0.000 iostream.py:308(_is_master_process)
#       216    0.002    0.000    0.002    0.000 __init__.py:70(__setitem__)
#       372    0.002    0.000    0.002    0.000 std.py:108(release)
#       349    0.001    0.000    0.002    0.000 ubc_utils.py:28(single_action_result)
#         1    0.000    0.000    0.002    0.002 std.py:846(__init__)
#      2894    0.002    0.000    0.002    0.000 {method 'numel' of 'torch._C._TensorBase' objects}
#       369    0.001    0.000    0.002    0.000 std.py:155(__init__)
#       109    0.000    0.000    0.002    0.000 functional.py:1650(softmax)
#      2894    0.002    0.000    0.002    0.000 {built-in method builtins.iter}
#       437    0.001    0.000    0.002    0.000 grad_mode.py:128(__exit__)
#       329    0.002    0.000    0.002    0.000 {built-in method broadcast_tensors}
#      1483    0.001    0.000    0.001    0.000 iostream.py:91(_event_pipe)
#       108    0.001    0.000    0.001    0.000 {method 'copy_' of 'torch._C._TensorBase' objects}
#       369    0.001    0.000    0.001    0.000 {method 'sub' of '_sre.SRE_Pattern' objects}
#       109    0.001    0.000    0.001    0.000 {method 'softmax' of 'torch._C._TensorBase' objects}
#      2311    0.001    0.000    0.001    0.000 {built-in method time.time}
#      7749    0.001    0.000    0.001    0.000 {built-in method builtins.ord}
#       371    0.001    0.000    0.001    0.000 {built-in method posix.getpid}
#       372    0.001    0.000    0.001    0.000 {method 'acquire' of '_multiprocessing.SemLock' objects}
#         2    0.000    0.000    0.001    0.001 std.py:1264(close)
#       109    0.000    0.000    0.001    0.000 numerictypes.py:360(issubdtype)
#      1974    0.001    0.000    0.001    0.000 {method 'requires_grad_' of 'torch._C._TensorBase' objects}
#     54/18    0.000    0.000    0.001    0.000 module.py:1286(state_dict)
#      1074    0.001    0.000    0.001    0.000 {built-in method builtins.hasattr}
#         1    0.000    0.000    0.001    0.001 std.py:329(status_printer)
#      3950    0.001    0.000    0.001    0.000 {built-in method builtins.id}
#       368    0.000    0.000    0.001    0.000 threading.py:251(_acquire_restore)
#       218    0.000    0.000    0.001    0.000 numerictypes.py:286(issubclass_)
#       658    0.001    0.000    0.001    0.000 ubc_dqn.py:90(__len__)
#       371    0.000    0.000    0.001    0.000 threading.py:239(__enter__)
#      1843    0.001    0.000    0.001    0.000 {built-in method builtins.divmod}
#        54    0.000    0.000    0.001    0.000 module.py:1249(_save_to_state_dict)
#       329    0.001    0.000    0.001    0.000 fromnumeric.py:71(<dictcomp>)
#       368    0.000    0.000    0.001    0.000 threading.py:254(_is_owned)
#       739    0.001    0.000    0.001    0.000 {built-in method _thread.allocate_lock}
#       329    0.001    0.000    0.001    0.000 __init__.py:61(_tensor_or_tensors_to_tuple)
#      1855    0.000    0.000    0.000    0.000 threading.py:506(is_set)
#      1311    0.000    0.000    0.000    0.000 {built-in method torch._C.is_grad_enabled}
#       329    0.000    0.000    0.000    0.000 _reduction.py:7(get_enum)
#      1851    0.000    0.000    0.000    0.000 {method 'append' of 'collections.deque' objects}
#       371    0.000    0.000    0.000    0.000 threading.py:242(__exit__)
#       368    0.000    0.000    0.000    0.000 threading.py:248(_release_save)
#       987    0.000    0.000    0.000    0.000 {built-in method torch._C._has_torch_function}
#       369    0.000    0.000    0.000    0.000 utils.py:57(__init__)
#       109    0.000    0.000    0.000    0.000 {method 'numpy' of 'torch._C._TensorBase' objects}
#       372    0.000    0.000    0.000    0.000 {method 'release' of '_multiprocessing.SemLock' objects}
#       372    0.000    0.000    0.000    0.000 {method 'acquire' of '_thread.RLock' objects}
#       369    0.000    0.000    0.000    0.000 std.py:169(colour)
#       369    0.000    0.000    0.000    0.000 {built-in method builtins.max}
#       874    0.000    0.000    0.000    0.000 {built-in method torch._C._set_grad_enabled}
#       437    0.000    0.000    0.000    0.000 _jit_internal.py:957(is_scripting)
#       369    0.000    0.000    0.000    0.000 utils.py:61(__format__)
#       372    0.000    0.000    0.000    0.000 {method 'release' of '_thread.RLock' objects}
#       327    0.000    0.000    0.000    0.000 {built-in method builtins.issubclass}
#       369    0.000    0.000    0.000    0.000 {method 'update' of 'dict' objects}
#       371    0.000    0.000    0.000    0.000 {built-in method _imp.lock_held}
#       437    0.000    0.000    0.000    0.000 {method 'items' of 'dict' objects}
#         2    0.000    0.000    0.000    0.000 std.py:1285(fp_write)
#       371    0.000    0.000    0.000    0.000 {method '__enter__' of '_thread.lock' objects}
#       368    0.000    0.000    0.000    0.000 {method 'release' of '_thread.lock' objects}
#       371    0.000    0.000    0.000    0.000 {built-in method builtins.abs}
#       329    0.000    0.000    0.000    0.000 fromnumeric.py:2876(_prod_dispatcher)
#       369    0.000    0.000    0.000    0.000 std.py:165(colour)
#       216    0.000    0.000    0.000    0.000 __init__.py:33(__setitem__)
#       216    0.000    0.000    0.000    0.000 ubc_decorators.py:30(agent)
#       108    0.000    0.000    0.000    0.000 parameter.py:129(is_lazy)
#        54    0.000    0.000    0.000    0.000 module.py:1376(<dictcomp>)
#       371    0.000    0.000    0.000    0.000 {method '__exit__' of '_thread.lock' objects}
#       216    0.000    0.000    0.000    0.000 {method 'split' of 'str' objects}
#       216    0.000    0.000    0.000    0.000 __init__.py:136(getsizeof)
#         1    0.000    0.000    0.000    0.000 std.py:560(__new__)
#         1    0.000    0.000    0.000    0.000 std.py:583(_decr_instances)
#       324    0.000    0.000    0.000    0.000 {method 'startswith' of 'str' objects}
#         4    0.000    0.000    0.000    0.000 std.py:112(__enter__)
#         1    0.000    0.000    0.000    0.000 utils.py:282(_screen_shape_linux)
#        18    0.000    0.000    0.000    0.000 {method 'copy' of 'collections.OrderedDict' objects}
#       324    0.000    0.000    0.000    0.000 {method 'items' of 'collections.OrderedDict' objects}
#         1    0.000    0.000    0.000    0.000 std.py:576(_get_free_pos)
#         3    0.000    0.000    0.000    0.000 _weakrefset.py:58(__iter__)
#         4    0.000    0.000    0.000    0.000 std.py:115(__exit__)
#       108    0.000    0.000    0.000    0.000 {method 'values' of 'collections.OrderedDict' objects}
#         1    0.000    0.000    0.000    0.000 utils.py:162(__init__)
#         1    0.000    0.000    0.000    0.000 std.py:579(<setcomp>)
#         1    0.000    0.000    0.000    0.000 utils.py:296(<listcomp>)
#         1    0.000    0.000    0.000    0.000 _weakrefset.py:106(remove)
#        54    0.000    0.000    0.000    0.000 module.py:1374(<dictcomp>)
#         1    0.000    0.000    0.000    0.000 os.py:664(__getitem__)
#         3    0.000    0.000    0.000    0.000 {method 'remove' of 'set' objects}
#         1    0.000    0.000    0.000    0.000 _weakrefset.py:81(add)
#        54    0.000    0.000    0.000    0.000 {method 'keys' of 'collections.OrderedDict' objects}
#         1    0.000    0.000    0.000    0.000 {built-in method fcntl.ioctl}
#         2    0.000    0.000    0.000    0.000 _weakrefset.py:26(__exit__)
#         3    0.000    0.000    0.000    0.000 {method 'add' of 'set' objects}
#         1    0.000    0.000    0.000    0.000 utils.py:74(__eq__)
#         2    0.000    0.000    0.000    0.000 _weakrefset.py:20(__enter__)
#         2    0.000    0.000    0.000    0.000 utils.py:171(__eq__)
#         1    0.000    0.000    0.000    0.000 utils.py:215(_supports_unicode)
#         1    0.000    0.000    0.000    0.000 os.py:742(encode)
#         3    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:997(_handle_fromlist)
#         1    0.000    0.000    0.000    0.000 std.py:657(get_lock)
#         2    0.000    0.000    0.000    0.000 std.py:1152(_comparable)
#         2    0.000    0.000    0.000    0.000 std.py:1156(__hash__)
#         3    0.000    0.000    0.000    0.000 utils.py:101(wrapper_setattr)
#         1    0.000    0.000    0.000    0.000 utils.py:105(__init__)
#         2    0.000    0.000    0.000    0.000 utils.py:136(disable_on_exception)
#         1    0.000    0.000    0.000    0.000 _monitor.py:94(report)
#         3    0.000    0.000    0.000    0.000 std.py:228(__init__)
#         2    0.000    0.000    0.000    0.000 utils.py:88(__getattr__)
#         2    0.000    0.000    0.000    0.000 _weakrefset.py:16(__init__)
#         2    0.000    0.000    0.000    0.000 {method 'encode' of 'str' objects}
#         1    0.000    0.000    0.000    0.000 {built-in method utcfromtimestamp}
#         1    0.000    0.000    0.000    0.000 std.py:1146(__del__)
#         1    0.000    0.000    0.000    0.000 utils.py:201(_is_utf)
#         2    0.000    0.000    0.000    0.000 _weakrefset.py:52(_commit_removals)
#         1    0.000    0.000    0.000    0.000 {method 'difference' of 'set' objects}
#         2    0.000    0.000    0.000    0.000 {built-in method _weakref.proxy}
#         1    0.000    0.000    0.000    0.000 std.py:1300(<lambda>)
#         1    0.000    0.000    0.000    0.000 utils.py:231(_screen_shape_wrapper)
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
