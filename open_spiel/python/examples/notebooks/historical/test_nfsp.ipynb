# %%
# %load_ext autoreload
# %autoreload 2
# %pylab inline

import sys
import glob
import pandas as pd
import os
import seaborn as sns
from tqdm import tqdm_notebook as tqdm
from statsmodels.distributions.empirical_distribution import ECDF
from collections import defaultdict
import logging
logging.basicConfig(format='%(asctime)s %(levelname)s:%(message)s', level=logging.DEBUG, datefmt='%I:%M:%S')
logger = logging.getLogger()
logger.setLevel(logging.INFO)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# Populating the interactive namespace from numpy and matplotlib

# %%
# !python ../ubc_nfsp_example.py --alsologtostderr  -- \
    --filename parameters.json \
    --network_config_file /apps/open_spiel/open_spiel/python/examples/network_configs/config_example_mlp.yml \
    --eval_every 1 \
    --min_buffer_size_to_learn 100 \
    --output_dir neil \
# Out:
# I1124 01:52:08.350418 140271567796032 ubc_nfsp_example.py:137] Loading network parameters from /apps/open_spiel/open_spiel/python/examples/network_configs/config_example_mlp.yml
# I1124 01:52:08.354787 140271567796032 ubc_nfsp_example.py:155] Setting numpy and torch seed to 1234
# I1124 01:52:08.355414 140271567796032 ubc_nfsp_example.py:159] Network params: {'sl_model': 'mlp', 'sl_model_args': {'hidden_sizes': [128]}, 'rl_model': 'mlp', 'rl_model_args': {'hidden_sizes': [128]}, 'num_training_episodes': 3000000, 'eval_every': 1, 'replay_buffer_capacity': 20000, 'reservoir_buffer_capacity': 2000000, 'anticipatory_param': 0.1, 'seed': 1234, 'batch_size': 128, 'rl_learning_rate': 1e-05, 'sl_learning_rate': 0.01, 'min_buffer_size_to_learn': 100, 'learn_every': 8, 'optimizer_str': 'sgd', 'epsilon_start': 0.01, 'epsilon_end': 0.001}
# I1124 01:52:08.355532 140271567796032 ubc_nfsp_example.py:162] Loading clock_auction
# ...

# %%
# !python ../ubc_nfsp_example.py -- \
    --filename parking_1.json \
    --network_config_file /apps/open_spiel/open_spiel/python/examples/network_configs/config_example_rnn.yml \
    --checkpoint_dir /apps/open_spiel/open_spiel/python/examples/checkpoints/parking_1_rnn \
    --eval_every 5000
# Out:
# I1123 18:15:15.447663 139976358582080 ubc_nfsp_example.py:119] Loading network parameters from /apps/open_spiel/open_spiel/python/examples/network_configs/config_example_rnn.yml
# I1123 18:15:15.450676 139976358582080 ubc_nfsp_example.py:133] Setting numpy and torch seed to 1234
# I1123 18:15:15.451338 139976358582080 ubc_nfsp_example.py:137] Network params: {'sl_model': 'rnn', 'sl_model_args': {'hidden_size': 128, 'num_layers': 1}, 'rl_model': 'rnn', 'rl_model_args': {'hidden_size': 128, 'num_layers': 1}, 'num_training_episodes': 3000000, 'eval_every': 5000, 'replay_buffer_capacity': 20000, 'reservoir_buffer_capacity': 2000000, 'anticipatory_param': 0.1, 'seed': 1234, 'batch_size': 128, 'rl_learning_rate': 1e-05, 'sl_learning_rate': 0.01, 'min_buffer_size_to_learn': 1000, 'learn_every': 8, 'optimizer_str': 'sgd', 'epsilon_start': 0.01, 'epsilon_end': 0.001}
# I1123 18:15:15.451444 139976358582080 ubc_nfsp_example.py:140] Loading clock_auction
# ...
