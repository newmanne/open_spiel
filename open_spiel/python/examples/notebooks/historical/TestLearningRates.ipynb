# %%
# %load_ext autoreload
# %autoreload 2

import sys
import glob
import pandas as pda
import os
import seaborn as sns
# from tqdm import tqdm_notebook as tqdm
from tqdm import tqdm
import pickle
from statsmodels.distributions.empirical_distribution import ECDF
from collections import defaultdict
import logging
from open_spiel.python.examples.ubc_mccfr_cpp_example import action_to_bids
from open_spiel.python.examples.ubc_nfsp_example import policy_from_checkpoint, main
from open_spiel.python.examples.ubc_br import BR_DIR, make_dqn_agent
from open_spiel.python.examples.ubc_utils import *
from open_spiel.python.examples.ubc_decorators import CachingAgentDecorator
import cProfile, pstats
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# !python /apps/open_spiel/open_spiel/python/examples/ubc_br.py --alsologtostderr -- --experiment_dir /shared/outputs/jan25_small_gpu/mlp --br_player 1 --checkpoint checkpoint_500000 --num_training_episodes 2_000_000 --dry_run True --compute_exact_br True --report_freq 1000 --config /apps/open_spiel/notebooks/configs/jan13/lstm_deep_double.yml
# Out:
# I0128 18:51:36.045798 139911727171392 ubc_utils.py:91] Setting numpy and torch seed to 1234
# Parsing configuration from /shared/outputs/jan25_small_gpu/mlp/game.json
# Done config parsing
# I0128 18:51:36.050737 139911727171392 ubc_nfsp_example.py:163] Game loaded
# I0128 18:51:36.050919 139911727171392 rl_environment.py:195] Using game instance: turn_based_simultaneous_game
# I0128 18:51:36.051723 139911727171392 ubc_nfsp_example.py:173] Game has a state size of 226, 4 distinct actions, and 2 players
# I0128 18:51:36.051796 139911727171392 ubc_nfsp_example.py:174] Game has 2 products
# I0128 18:51:36.058071 139911727171392 ubc_nfsp.py:91] Creating NFSP using device: cuda for player 0
# I0128 18:51:36.058218 139911727171392 ubc_dqn.py:247] Double DQN activated for player 0
# I0128 18:51:36.058504 139911727171392 ubc_dqn.py:280] Creating DQN using device: cuda for player 0
# I0128 18:51:40.053769 139911727171392 ubc_nfsp.py:91] Creating NFSP using device: cuda for player 1
# ...
