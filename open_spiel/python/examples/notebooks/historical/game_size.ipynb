# %%
import pyspiel
import pickle
import numpy as np
import pandas as pd
from open_spiel.python.algorithms import cfr, outcome_sampling_mccfr, expected_game_score, exploitability, get_all_states_with_policy
from open_spiel.python.examples.ubc_mccfr_cpp_example import state_to_final
from open_spiel.python.algorithms import get_all_states
from tqdm import tqdm

# %%
params = dict()
params['filename'] = 'medium_game_2.json'
game = pyspiel.load_game_as_turn_based('clock_auction', params)

# %%
information_state_string_to_state = get_all_states.get_all_states(game, depth_limit=-1, include_terminals=False, include_chance_states=False, include_mean_field_states=False, to_string=lambda s: s.information_state_string(), stop_if_encountered=False)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-3-62673b5ae1d6> in <module>
# ----> 1 information_state_string_to_state = get_all_states.get_all_states(game, depth_limit=-1, include_terminals=False, include_chance_states=False, include_mean_field_states=False, to_string=lambda s: s.information_state_string(), stop_if_encountered=False)
#
# /apps/open_spiel/open_spiel/python/algorithms/get_all_states.py in get_all_states(game, depth_limit, include_terminals, include_chance_states, include_mean_field_states, to_string, stop_if_encountered)
#     139         include_mean_field_states=include_mean_field_states,
#     140         to_string=to_string,
# --> 141         stop_if_encountered=stop_if_encountered)
#     142
#     143   if not all_states:
#
# /apps/open_spiel/open_spiel/python/algorithms/get_all_states.py in _get_subgames_states(state, all_states, depth_limit, depth, include_terminals, include_chance_states, include_mean_field_states, to_string, stop_if_encountered)
#      87                            include_terminals, include_chance_states,
#      88                            include_mean_field_states, to_string,
# ---> 89                            stop_if_encountered)
#      90
#      91
#
# /apps/open_spiel/open_spiel/python/algorithms/get_all_states.py in _get_subgames_states(state, all_states, depth_limit, depth, include_terminals, include_chance_states, include_mean_field_states, to_string, stop_if_encountered)
#      87                            include_terminals, include_chance_states,
#      88                            include_mean_field_states, to_string,
# ---> 89                            stop_if_encountered)
#      90
#      91
#
# /apps/open_spiel/open_spiel/python/algorithms/get_all_states.py in _get_subgames_states(state, all_states, depth_limit, depth, include_terminals, include_chance_states, include_mean_field_states, to_string, stop_if_encountered)
#      87                            include_terminals, include_chance_states,
#      88                            include_mean_field_states, to_string,
# ---> 89                            stop_if_encountered)
#      90
#      91
#
# /apps/open_spiel/open_spiel/python/algorithms/get_all_states.py in _get_subgames_states(state, all_states, depth_limit, depth, include_terminals, include_chance_states, include_mean_field_states, to_string, stop_if_encountered)
#      87                            include_terminals, include_chance_states,
#      88                            include_mean_field_states, to_string,
# ---> 89                            stop_if_encountered)
#      90
#      91
#
# /apps/open_spiel/open_spiel/python/algorithms/get_all_states.py in _get_subgames_states(state, all_states, depth_limit, depth, include_terminals, include_chance_states, include_mean_field_states, to_string, stop_if_encountered)
#      87                            include_terminals, include_chance_states,
#      88                            include_mean_field_states, to_string,
# ---> 89                            stop_if_encountered)
#      90
#      91
#
# /apps/open_spiel/open_spiel/python/algorithms/get_all_states.py in _get_subgames_states(state, all_states, depth_limit, depth, include_terminals, include_chance_states, include_mean_field_states, to_string, stop_if_encountered)
#      87                            include_terminals, include_chance_states,
#      88                            include_mean_field_states, to_string,
# ---> 89                            stop_if_encountered)
#      90
#      91
#
# /apps/open_spiel/open_spiel/python/algorithms/get_all_states.py in _get_subgames_states(state, all_states, depth_limit, depth, include_terminals, include_chance_states, include_mean_field_states, to_string, stop_if_encountered)
#      87                            include_terminals, include_chance_states,
#      88                            include_mean_field_states, to_string,
# ---> 89                            stop_if_encountered)
#      90
#      91
#
# /apps/open_spiel/open_spiel/python/algorithms/get_all_states.py in _get_subgames_states(state, all_states, depth_limit, depth, include_terminals, include_chance_states, include_mean_field_states, to_string, stop_if_encountered)
#      87                            include_terminals, include_chance_states,
#      88                            include_mean_field_states, to_string,
# ---> 89                            stop_if_encountered)
#      90
#      91
#
# /apps/open_spiel/open_spiel/python/algorithms/get_all_states.py in _get_subgames_states(state, all_states, depth_limit, depth, include_terminals, include_chance_states, include_mean_field_states, to_string, stop_if_encountered)
#      87                            include_terminals, include_chance_states,
#      88                            include_mean_field_states, to_string,
# ---> 89                            stop_if_encountered)
#      90
#      91
#
# /apps/open_spiel/open_spiel/python/algorithms/get_all_states.py in _get_subgames_states(state, all_states, depth_limit, depth, include_terminals, include_chance_states, include_mean_field_states, to_string, stop_if_encountered)
#      87                            include_terminals, include_chance_states,
#      88                            include_mean_field_states, to_string,
# ---> 89                            stop_if_encountered)
#      90
#      91
#
# /apps/open_spiel/open_spiel/python/algorithms/get_all_states.py in _get_subgames_states(state, all_states, depth_limit, depth, include_terminals, include_chance_states, include_mean_field_states, to_string, stop_if_encountered)
#      87                            include_terminals, include_chance_states,
#      88                            include_mean_field_states, to_string,
# ---> 89                            stop_if_encountered)
#      90
#      91
#
# /apps/open_spiel/open_spiel/python/algorithms/get_all_states.py in _get_subgames_states(state, all_states, depth_limit, depth, include_terminals, include_chance_states, include_mean_field_states, to_string, stop_if_encountered)
#      87                            include_terminals, include_chance_states,
#      88                            include_mean_field_states, to_string,
# ---> 89                            stop_if_encountered)
#      90
#      91
#
# /apps/open_spiel/open_spiel/python/algorithms/get_all_states.py in _get_subgames_states(state, all_states, depth_limit, depth, include_terminals, include_chance_states, include_mean_field_states, to_string, stop_if_encountered)
#      87                            include_terminals, include_chance_states,
#      88                            include_mean_field_states, to_string,
# ---> 89                            stop_if_encountered)
#      90
#      91
#
# /apps/open_spiel/open_spiel/python/algorithms/get_all_states.py in _get_subgames_states(state, all_states, depth_limit, depth, include_terminals, include_chance_states, include_mean_field_states, to_string, stop_if_encountered)
#      87                            include_terminals, include_chance_states,
#      88                            include_mean_field_states, to_string,
# ---> 89                            stop_if_encountered)
#      90
#      91
#
# /apps/open_spiel/open_spiel/python/algorithms/get_all_states.py in _get_subgames_states(state, all_states, depth_limit, depth, include_terminals, include_chance_states, include_mean_field_states, to_string, stop_if_encountered)
#      87                            include_terminals, include_chance_states,
#      88                            include_mean_field_states, to_string,
# ---> 89                            stop_if_encountered)
#      90
#      91
#
# /apps/open_spiel/open_spiel/python/algorithms/get_all_states.py in _get_subgames_states(state, all_states, depth_limit, depth, include_terminals, include_chance_states, include_mean_field_states, to_string, stop_if_encountered)
#      87                            include_terminals, include_chance_states,
#      88                            include_mean_field_states, to_string,
# ---> 89                            stop_if_encountered)
#      90
#      91
#
# /apps/open_spiel/open_spiel/python/algorithms/get_all_states.py in _get_subgames_states(state, all_states, depth_limit, depth, include_terminals, include_chance_states, include_mean_field_states, to_string, stop_if_encountered)
#      87                            include_terminals, include_chance_states,
#      88                            include_mean_field_states, to_string,
# ---> 89                            stop_if_encountered)
#      90
#      91
#
# /apps/open_spiel/open_spiel/python/algorithms/get_all_states.py in _get_subgames_states(state, all_states, depth_limit, depth, include_terminals, include_chance_states, include_mean_field_states, to_string, stop_if_encountered)
#      87                            include_terminals, include_chance_states,
#      88                            include_mean_field_states, to_string,
# ---> 89                            stop_if_encountered)
#      90
#      91
#
# /apps/open_spiel/open_spiel/python/algorithms/get_all_states.py in _get_subgames_states(state, all_states, depth_limit, depth, include_terminals, include_chance_states, include_mean_field_states, to_string, stop_if_encountered)
#      87                            include_terminals, include_chance_states,
#      88                            include_mean_field_states, to_string,
# ---> 89                            stop_if_encountered)
#      90
#      91
#
# /apps/open_spiel/open_spiel/python/algorithms/get_all_states.py in _get_subgames_states(state, all_states, depth_limit, depth, include_terminals, include_chance_states, include_mean_field_states, to_string, stop_if_encountered)
#      87                            include_terminals, include_chance_states,
#      88                            include_mean_field_states, to_string,
# ---> 89                            stop_if_encountered)
#      90
#      91
#
# /apps/open_spiel/open_spiel/python/algorithms/get_all_states.py in _get_subgames_states(state, all_states, depth_limit, depth, include_terminals, include_chance_states, include_mean_field_states, to_string, stop_if_encountered)
#      87                            include_terminals, include_chance_states,
#      88                            include_mean_field_states, to_string,
# ---> 89                            stop_if_encountered)
#      90
#      91
#
# /apps/open_spiel/open_spiel/python/algorithms/get_all_states.py in _get_subgames_states(state, all_states, depth_limit, depth, include_terminals, include_chance_states, include_mean_field_states, to_string, stop_if_encountered)
#      87                            include_terminals, include_chance_states,
#      88                            include_mean_field_states, to_string,
# ---> 89                            stop_if_encountered)
#      90
#      91
#
# /apps/open_spiel/open_spiel/python/algorithms/get_all_states.py in _get_subgames_states(state, all_states, depth_limit, depth, include_terminals, include_chance_states, include_mean_field_states, to_string, stop_if_encountered)
#      87                            include_terminals, include_chance_states,
#      88                            include_mean_field_states, to_string,
# ---> 89                            stop_if_encountered)
#      90
#      91
#
# /apps/open_spiel/open_spiel/python/algorithms/get_all_states.py in _get_subgames_states(state, all_states, depth_limit, depth, include_terminals, include_chance_states, include_mean_field_states, to_string, stop_if_encountered)
#      87                            include_terminals, include_chance_states,
#      88                            include_mean_field_states, to_string,
# ---> 89                            stop_if_encountered)
#      90
#      91
#
# /apps/open_spiel/open_spiel/python/algorithms/get_all_states.py in _get_subgames_states(state, all_states, depth_limit, depth, include_terminals, include_chance_states, include_mean_field_states, to_string, stop_if_encountered)
#      87                            include_terminals, include_chance_states,
#      88                            include_mean_field_states, to_string,
# ---> 89                            stop_if_encountered)
#      90
#      91
#
# /apps/open_spiel/open_spiel/python/algorithms/get_all_states.py in _get_subgames_states(state, all_states, depth_limit, depth, include_terminals, include_chance_states, include_mean_field_states, to_string, stop_if_encountered)
#      87                            include_terminals, include_chance_states,
#      88                            include_mean_field_states, to_string,
# ---> 89                            stop_if_encountered)
#      90
#      91
#
# /apps/open_spiel/open_spiel/python/algorithms/get_all_states.py in _get_subgames_states(state, all_states, depth_limit, depth, include_terminals, include_chance_states, include_mean_field_states, to_string, stop_if_encountered)
#      87                            include_terminals, include_chance_states,
#      88                            include_mean_field_states, to_string,
# ---> 89                            stop_if_encountered)
#      90
#      91
#
# /apps/open_spiel/open_spiel/python/algorithms/get_all_states.py in _get_subgames_states(state, all_states, depth_limit, depth, include_terminals, include_chance_states, include_mean_field_states, to_string, stop_if_encountered)
#      87                            include_terminals, include_chance_states,
#      88                            include_mean_field_states, to_string,
# ---> 89                            stop_if_encountered)
#      90
#      91
#
# /apps/open_spiel/open_spiel/python/algorithms/get_all_states.py in _get_subgames_states(state, all_states, depth_limit, depth, include_terminals, include_chance_states, include_mean_field_states, to_string, stop_if_encountered)
#      87                            include_terminals, include_chance_states,
#      88                            include_mean_field_states, to_string,
# ---> 89                            stop_if_encountered)
#      90
#      91
#
# /apps/open_spiel/open_spiel/python/algorithms/get_all_states.py in _get_subgames_states(state, all_states, depth_limit, depth, include_terminals, include_chance_states, include_mean_field_states, to_string, stop_if_encountered)
#      87                            include_terminals, include_chance_states,
#      88                            include_mean_field_states, to_string,
# ---> 89                            stop_if_encountered)
#      90
#      91
#
# /apps/open_spiel/open_spiel/python/algorithms/get_all_states.py in _get_subgames_states(state, all_states, depth_limit, depth, include_terminals, include_chance_states, include_mean_field_states, to_string, stop_if_encountered)
#      87                            include_terminals, include_chance_states,
#      88                            include_mean_field_states, to_string,
# ---> 89                            stop_if_encountered)
#      90
#      91
#
# /apps/open_spiel/open_spiel/python/algorithms/get_all_states.py in _get_subgames_states(state, all_states, depth_limit, depth, include_terminals, include_chance_states, include_mean_field_states, to_string, stop_if_encountered)
#      87                            include_terminals, include_chance_states,
#      88                            include_mean_field_states, to_string,
# ---> 89                            stop_if_encountered)
#      90
#      91
#
# /apps/open_spiel/open_spiel/python/algorithms/get_all_states.py in _get_subgames_states(state, all_states, depth_limit, depth, include_terminals, include_chance_states, include_mean_field_states, to_string, stop_if_encountered)
#      87                            include_terminals, include_chance_states,
#      88                            include_mean_field_states, to_string,
# ---> 89                            stop_if_encountered)
#      90
#      91
#
# /apps/open_spiel/open_spiel/python/algorithms/get_all_states.py in _get_subgames_states(state, all_states, depth_limit, depth, include_terminals, include_chance_states, include_mean_field_states, to_string, stop_if_encountered)
#      83   else:
#      84     for action in state.legal_actions():
# ---> 85       state_for_search = state.child(action)
#      86       _get_subgames_states(state_for_search, all_states, depth_limit, depth + 1,
#      87                            include_terminals, include_chance_states,
#
# KeyboardInterrupt:

# %%
print(len(information_state_string_to_state))
