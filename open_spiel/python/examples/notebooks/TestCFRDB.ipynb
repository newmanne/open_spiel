# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
import os
import pickle
os.environ["DJANGO_ALLOW_ASYNC_UNSAFE"] = "true"

# %%
# !python /apps/cluster_open_spiel/web/auctions/manage.py cfr --filename may23_compressed.json --network_config_file cfr_may20_23/mccfr --experiment_name cfrtest --overwrite_db True --eval_every 9999 --eval_zero false --total_timesteps 200 --use_wandb false --report_freq 100
# Out:
# [2023-05-24 00:05:59,724] {ubc_utils.py:44} INFO - Setting numpy and torch seed to 1234
# [2023-05-24 00:05:59,724] {cfr_utils.py:27} INFO - Reading config from /apps/open_spiel/notebooks/configs/cfr_may20_23/mccfr.yml
# {'solver_type': 'cfr', 'solver': 'mccfr', 'sampling_method': 'external'}
# [2023-05-24 00:05:59,725] {cfr.py:57} INFO - Network params: {'solver_type': 'cfr', 'solver': 'mccfr', 'sampling_method': 'external', 'seed': 1234, 'total_timesteps': 200, 'use_wandb': 0}
# ...

# %%
EquilibriumSolverRunCheckpoint.objects.last().evaluation.samples.keys()

# %%
Experiment.objects.get(name='cfrtest').delete()

# %%
policy = pickle.loads(EquilibriumSolverRunCheckpoint.objects.last().policy)

# %%
policy.player_ids

# %%
policy.action_probabilities?
