# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

import sys
import glob
import pandas as pd
import os
import seaborn as sns

from tqdm import tqdm
from statsmodels.distributions.empirical_distribution import ECDF
from collections import defaultdict
import pickle
import re
import json
from pathlib import Path


from open_spiel.python.algorithms.exploitability import nash_conv, best_response
from open_spiel.python.examples.ubc_plotting_utils import *
from open_spiel.python.examples.ubc_sample_game_tree import sample_game_tree, flatten_trees, flatten_tree
from open_spiel.python.examples.ubc_clusters import projectPCA, projectUMAP, fitGMM, projectTSNE

from auctions.webutils import *



# import bokeh
# from bokeh.layouts import row, column
# from bokeh.plotting import figure, show, output_file, save
# from bokeh.io import output_notebook
# from bokeh.models import HoverTool, ColumnDataSource, ColorBar, LogColorMapper, LinearColorMapper
# from bokeh.transform import linear_cmap, log_cmap
# from bokeh.palettes import Magma256
os.environ["DJANGO_ALLOW_ASYNC_UNSAFE"] = "true"

output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1002">Loading BokehJS ...</span>
#     </div>

# %%
# from plotly.offline import download_plotlyjs, init_notebook_mode, iplot
# init_notebook_mode(connected=True)

# %%
import holoviews as hv
from holoviews import opts, dim
hv.extension('bokeh')
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Input In [6], in <module>
# ----> 1 import holoviews as hv
#       2 from holoviews import opts, dim
#       3 hv.extension('bokeh')
#
# File ~/.pyenv/versions/3.8.2/envs/venv/lib/python3.8/site-packages/holoviews/__init__.py:12, in <module>
#       8 __version__ = str(param.version.Version(fpath=__file__, archive_commit="$Format:%h$",
#       9                                         reponame="holoviews"))
#      11 from . import util                                       # noqa (API import)
# ---> 12 from .annotators import annotate                         # noqa (API import)
#      13 from .core import archive, config                        # noqa (API import)
#      14 from .core.boundingregion import BoundingBox             # noqa (API import)
#
# File ~/.pyenv/versions/3.8.2/envs/venv/lib/python3.8/site-packages/holoviews/annotators.py:10, in <module>
#       6 from inspect import getmro
#       8 import param
# ---> 10 from panel.pane import PaneBase
#      11 from panel.layout import Row, Tabs
#      12 from panel.util import param_name
#
# File ~/.pyenv/versions/3.8.2/envs/venv/lib/python3.8/site-packages/panel/__init__.py:1, in <module>
# ----> 1 from . import layout # noqa
#       2 from . import links # noqa
#       3 from . import pane # noqa
#
# File ~/.pyenv/versions/3.8.2/envs/venv/lib/python3.8/site-packages/panel/layout/__init__.py:1, in <module>
# ----> 1 from .accordion import Accordion # noqa
#       2 from .base import Column, ListLike, ListPanel, Panel, Row, WidgetBox # noqa
#       3 from .card import Card # noqa
#
# File ~/.pyenv/versions/3.8.2/envs/venv/lib/python3.8/site-packages/panel/layout/accordion.py:5, in <module>
#       1 import param
#       3 from bokeh.models import Column as BkColumn, CustomJS
# ----> 5 from .base import NamedListPanel
#       6 from .card import Card
#       9 class Accordion(NamedListPanel):
#
# File ~/.pyenv/versions/3.8.2/envs/venv/lib/python3.8/site-packages/panel/layout/base.py:13, in <module>
#      11 from ..io.model import hold
#      12 from ..io.state import state
# ---> 13 from ..reactive import Reactive
#      14 from ..util import param_name, param_reprs
#      16 _row = namedtuple("row", ["children"])
#
# File ~/.pyenv/versions/3.8.2/envs/venv/lib/python3.8/site-packages/panel/reactive.py:35, in <module>
#      31 from .models.reactive_html import (
#      32     ReactiveHTML as _BkReactiveHTML, ReactiveHTMLParser
#      33 )
#      34 from .util import edit_readonly, escape, updating
# ---> 35 from .viewable import Layoutable, Renderable, Viewable
#      37 LinkWatcher = namedtuple("Watcher", Watcher._fields+('target', 'links', 'transformed', 'bidirectional_watcher'))
#      40 class Syncable(Renderable):
#
# File ~/.pyenv/versions/3.8.2/envs/venv/lib/python3.8/site-packages/panel/viewable.py:27, in <module>
#      25 from .config import config, panel_extension
#      26 from .io.embed import embed_state
# ---> 27 from .io.loading import start_loading_spinner, stop_loading_spinner
#      28 from .io.model import add_to_doc, patch_cds_msg
#      29 from .io.notebook import (
#      30     ipywidget, render_mimebundle, render_model, show_embed, show_server
#      31 )
#
# File ~/.pyenv/versions/3.8.2/envs/venv/lib/python3.8/site-packages/panel/io/__init__.py:28, in <module>
#      25     panel_logger.setLevel(config.log_level)
#      27 if 'django' in sys.modules:
# ---> 28     from . import django
#
# File ~/.pyenv/versions/3.8.2/envs/venv/lib/python3.8/site-packages/panel/io/django.py:3, in <module>
#       1 from urllib.parse import urlparse
# ----> 3 from bokeh.server.django.consumers import DocConsumer, AutoloadJsConsumer
#       5 from .resources import Resources
#       6 from .server import (
#       7     autoload_js_script, server_html_page_for_session
#       8 )
#
# File ~/.pyenv/versions/3.8.2/envs/venv/lib/python3.8/site-packages/bokeh/server/django/__init__.py:5, in <module>
#       2 from bokeh.util.dependencies import import_required
#       4 # Bokeh imports
# ----> 5 from .apps import DjangoBokehConfig
#       6 from .routing import autoload, directory, document
#       7 from .static import static_extensions
#
# File ~/.pyenv/versions/3.8.2/envs/venv/lib/python3.8/site-packages/bokeh/server/django/apps.py:29, in <module>
#      26 from django.conf import settings
#      28 # Bokeh imports
# ---> 29 from .routing import Routing, RoutingConfiguration
#      31 #-----------------------------------------------------------------------------
#      32 # Globals and constants
#      33 #-----------------------------------------------------------------------------
#      35 __all__ = (
#      36     'DjangoBokehConfig',
#      37 )
#
# File ~/.pyenv/versions/3.8.2/envs/venv/lib/python3.8/site-packages/bokeh/server/django/routing.py:27, in <module>
#      25 # External imports
#      26 from channels.http import AsgiHandler
# ---> 27 from django.conf.urls import url
#      28 from django.urls.resolvers import URLPattern
#      30 # Bokeh imports
#
# ImportError: cannot import name 'url' from 'django.conf.urls' (/home/ubuntu/.pyenv/versions/3.8.2/envs/venv/lib/python3.8/site-packages/django/conf/urls/__init__.py)

# %%
import plotly.graph_objects as go

fig = go.Figure(data=[go.Sankey(
    node = dict(
      pad = 15,
      thickness = 20,
      line = dict(color = "black", width = 0.5),
      label = ["A1", "A2", "B1", "B2", "C1", "C2"],
      color = "blue"
    ),
    link = dict(
      source = [0, 1, 0, 2, 3, 3], # indices correspond to labels, eg A1, A2, A1, B1, ...
      target = [2, 3, 3, 4, 4, 5],
      value = [8, 4, 2, 8, 4, 2]
  ))])

fig.update_layout(title_text="Basic Sankey Diagram", font_size=10)
fig.show()

# %%
import pandas as pd

# %%
df = pd.read_csv('data.csv').set_index(['round', 'cluster_from'])

# %%
list(map(str,df.index.values))
# Out:
# ['(1.0, -1)',
#  '(2.0, 1)',
#  '(3.0, 2)',
#  '(3.0, 9)',
#  '(3.0, 10)',
#  '(3.0, 17)',
#  '(3.0, 18)',
#  '(3.0, 19)',
#  '(4.0, 0)',
#  '(4.0, 3)',
#  '(4.0, 7)',
#  '(4.0, 8)',
#  '(4.0, 12)',
#  '(4.0, 14)',
#  '(4.0, 16)',
#  '(4.0, 19)',
#  '(5.0, 0)',
#  '(5.0, 4)',
#  '(5.0, 5)',
#  '(5.0, 6)',
#  '(5.0, 7)',
#  '(5.0, 11)',
#  '(5.0, 13)',
#  '(5.0, 16)',
#  '(6.0, 4)',
#  '(6.0, 5)',
#  '(6.0, 6)',
#  '(6.0, 13)',
#  '(6.0, 15)',
#  '(6.0, 16)',
#  '(7.0, 4)',
#  '(7.0, 5)',
#  '(7.0, 6)',
#  '(7.0, 13)',
#  '(7.0, 15)',
#  '(7.0, 16)',
#  '(8.0, 4)',
#  '(8.0, 6)',
#  '(8.0, 13)',
#  '(8.0, 15)',
#  '(9.0, 4)']
