# %%
# %load_ext autoreload
# %autoreload 2
# %pylab inline

import sys
import glob
import pandas as pd
import os
import seaborn as sns
from tqdm import tqdm_notebook as tqdm
from statsmodels.distributions.empirical_distribution import ECDF
from collections import defaultdict
import logging
logging.basicConfig(format='%(asctime)s %(levelname)s:%(message)s', level=logging.DEBUG, datefmt='%I:%M:%S')
logger = logging.getLogger()
logger.setLevel(logging.INFO)
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
# !python ../ubc_deep_cfr_pytorch.py \
    --nn_file /apps/open_spiel/open_spiel/python/examples/network_configs/deep_cfr.yml
# Out:
# I1120 01:45:40.564497 140342752679744 ubc_deep_cfr_pytorch.py:51] Loading network parameters from /apps/open_spiel/open_spiel/python/examples/network_configs/deep_cfr.yml
# I1120 01:45:40.566757 140342752679744 ubc_deep_cfr_pytorch.py:66] Setting numpy and torch seed to {}
# I1120 01:45:40.568509 140342752679744 ubc_deep_cfr_pytorch.py:70] Network params: {'policy_network_layers': [128], 'advantage_network_layers': [128], 'num_iterations': 300, 'num_traversals': 40, 'learning_rate': 1e-05, 'batch_size_advantage': None, 'batch_size_strategy': None, 'policy_network_train_steps': 1, 'advantage_network_train_steps': 1, 'reinitialize_advantage_networks': True, 'memory_capacity': 10000000, 'seed': 1234}
# I1120 01:45:40.568606 140342752679744 ubc_deep_cfr_pytorch.py:73] Loading clock_auction
# Reading from env variable CLOCK_AUCTION_CONFIG_DIR. If it is not set, there will be trouble.
# CLOCK_AUCTION_CONFIG_DIR=/apps/open_spiel/configs
# ...

# %%
# !python ../ubc_mccfr_cpp_example.py --filename parameters.json --iterations 1000

# %%
# !jq '' /apps/open_spiel/configs/parking_1.json
